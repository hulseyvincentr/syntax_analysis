# %% [markdown]
# ## This code takes in .csv outputs from the TweetyBERT decoder, then saves the data into cell arrays inside of .mat files, which can be then input into Jeff Markowitz's probabalistic suffix tree (PST). PST pipeline can be found here: https://github.com/jmarkow/pst

# %%
import json
import pandas as pd
import ast
from datetime import datetime

class temp:
    def __init__(self):
        # Define the path to the JSON file
        recording_file_path_name = '/Users/mirandahulsey-vincent/Documents/allPythonCode/syntax_analysis/data_inputs/DOI_study/USA5508/DOI_USA5508_decoded_database.json'

        # Read the JSON file
        print(f"Reading JSON file: {recording_file_path_name}")
        with open(recording_file_path_name, 'r') as f:
            decoder_data = json.load(f)['results']  # Adjusted to extract the 'results' key

        # Print the total number of songs (assuming each item in 'results' is a song)
        print(f"Total songs in JSON: {len(decoder_data)}")

        # Convert to DataFrame
        decoder_dataframe = pd.DataFrame(decoder_data)
        decoder_dataframe['syllable_onsets_offsets_ms'] = decoder_dataframe['syllable_onsets_offsets_ms'].apply(self.parse_json_safe)
        decoder_dataframe['syllable_onsets_offsets_timebins'] = decoder_dataframe['syllable_onsets_offsets_timebins'].apply(self.parse_json_safe)

        self.dataframe = decoder_dataframe

    def return_dataframe(self):
        return self.dataframe


    def parse_json_safe(self, s):
            """
            Safely parse a string representation of a JSON object.
            Handles extra quotes and converts single quotes to double quotes.
            """
            if isinstance(s, dict):
                return s  # If it's already a dictionary, return it as is
            
            if pd.isna(s):
                return {}
            
            # Remove surrounding single quotes
            s = s.strip()
            if s.startswith("''") and s.endswith("''"):
                s = s[2:-2]
            elif s.startswith("'") and s.endswith("'"):
                s = s[1:-1]
            
            if not s:
                return {}
            
            try:
                # First, attempt to parse using json
                s_json = s.replace("'", '"')
                return json.loads(s_json)
            except json.JSONDecodeError:
                try:
                    # If json fails, attempt using ast.literal_eval
                    return ast.literal_eval(s)
                except (ValueError, SyntaxError) as e:
                    print(f"Error parsing string: {s}\nError: {e}")
                    return {}
    
TEMP = temp()

decoder_dataframe = TEMP.return_dataframe()

print(decoder_dataframe.head)
# Out:
# Reading JSON file: /Users/mirandahulsey-vincent/Documents/allPythonCode/syntax_analysis/data_inputs/DOI_study/USA5508/DOI_USA5508_decoded_database.json
# Total songs in JSON: 16689
# <bound method NDFrame.head of                                        file_name  song_present  \
# 0       USA5508_45547.42460255_9_12_11_47_40.wav         False
# 1       USA5508_45547.44088145_9_12_12_14_48.wav         False
# 2       USA5508_45547.44240304_9_12_12_17_20.wav         False
# 3       USA5508_45547.45080348_9_12_12_31_20.wav         False
# 4       USA5508_45547.45230683_9_12_12_33_50.wav         False
# ...                                          ...           ...
# 16684  USA5508_45595.63970474_10_30_17_46_10.wav         False
# 16685  USA5508_45595.64130755_10_30_17_48_50.wav         False
# 16686  USA5508_45595.64189267_10_30_17_49_49.wav         False
# 16687  USA5508_45595.64458876_10_30_17_54_18.wav         False
# 16688   USA5508_45595.64854736_10_30_18_0_54.wav         False
#
#       syllable_onsets_offsets_ms syllable_onsets_offsets_timebins
# 0                             {}                               {}
# 1                             {}                               {}
# 2                             {}                               {}
# 3                             {}                               {}
# 4                             {}                               {}
# ...                          ...                              ...
# 16684                         {}                               {}
# 16685                         {}                               {}
# 16686                         {}                               {}
# 16687                         {}                               {}
# 16688                         {}                               {}
#
# [16689 rows x 4 columns]>

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import json

# Load the CSV and JSON creation_date data
save_output_to_this_file_path = '/Users/mirandahulsey-vincent/Documents/allPythonCode/syntax_analysis/data_inputs/DOI_study/USA5506'
# USE IF THE DECODER OUTPUT A CSV FILE:
#recording_file_path_name = '/Users/mirandahulsey-vincent/Documents/allPythonCode/syntax_analysis/DECODER_csvs_and_jsons/USA5509_decoded.csv'
#decoder_dataframe = pd.read_csv(recording_file_path_name)
#USE IF THE DECODER OUTPUT IS A .JSON FILE:
# recording_file_path_name = '/Users/mirandahulsey-vincent/Documents/allPythonCode/syntax_analysis/DECODER_sham_lesions/USA5271_decoded.json'
# print(f"Reading JSON file: {recording_file_path_name}")
# with open(recording_file_path_name, 'r') as f:
#     decoder_data = json.load(f)['results']  # Adjusted to extract the 'results' key
# # Convert to DataFrame
# decoder_dataframe = pd.DataFrame(decoder_data)

path_to_json_file_with_dates = '/Users/mirandahulsey-vincent/Documents/allPythonCode/syntax_analysis/data_inputs/DOI_study/USA5508/DOI_USA5508_creation_data.json'


with open(path_to_json_file_with_dates, 'r') as f:
    json_data = json.load(f)
    # Extract surgery date and format it
json_surgery_date = json_data['treatment_date']  # Assuming single treatment date
date_obj = datetime.strptime(json_surgery_date, "%Y-%m-%d")
surgery_date = date_obj.strftime("%Y.%m.%d")  # Adjust to year-first format for consistency
print(f"Surgery date: {surgery_date}")
# Extract subdirectory creation dates from JSON data
subdirectory_dates = {subdir: data['subdirectory_creation_date'] for subdir, data in json_data['subdirectories'].items()}


# Function to extract date, time, and animal_id from the file name
def find_recording_dates_and_times(recording_file_path_name):
    try:
        file_name = recording_file_path_name.split('/')[-1]
        split_file_name_by_underscores = file_name.split('_')
        animal_id = split_file_name_by_underscores[0]
        month = split_file_name_by_underscores[2].zfill(2)
        day = split_file_name_by_underscores[3].zfill(2)
        date = f"{month}.{day}"
        hour = split_file_name_by_underscores[4].zfill(2)
        minute = split_file_name_by_underscores[5].zfill(2)
        second = split_file_name_by_underscores[6].replace('.wav', '').zfill(2)
        return animal_id, date, hour, minute, second
    except IndexError:
        print(f"Error: Unexpected format in file name {recording_file_path_name}")
        return None, None, None, None, None

# Function to update the date with year from the JSON file
def update_date_with_year(row, subdirectory_dates):
    month_day = row['Date']
    month = month_day.split('.')[0]
    for subdir, date in subdirectory_dates.items():
        year, json_month, json_day = date.split('-')
        if json_month == month:
            # Return the date in the format YYYY.MM.DD
            return f"{year}.{month_day}"
    return None

# Function to create a table and filter data where song_present is True
def make_table(input_data_frame, subdirectory_dates):
    only_song_data = input_data_frame[input_data_frame['song_present'] == True].reset_index(drop=True)
    num_files_with_song = only_song_data.shape[0]
    
    organized_data_frame = only_song_data.copy()
    organized_data_frame['Animal ID'] = [None] * num_files_with_song
    organized_data_frame['Date'] = [None] * num_files_with_song
    organized_data_frame['Hour'] = [None] * num_files_with_song
    organized_data_frame['Minute'] = [None] * num_files_with_song
    organized_data_frame['Second'] = [None] * num_files_with_song

    for i, row in only_song_data.iterrows():
        recording_file_path_name = row['file_name']
        try:
            animal_id, date, hour, minute, second = find_recording_dates_and_times(recording_file_path_name)
            organized_data_frame.at[i, 'Animal ID'] = animal_id
            organized_data_frame.at[i, 'Date'] = date
            organized_data_frame.at[i, 'Hour'] = hour
            organized_data_frame.at[i, 'Minute'] = minute
            organized_data_frame.at[i, 'Second'] = second
        except Exception as e:
            print(f"Error processing file {recording_file_path_name}: {e}")
            continue

    # Apply the year correction to the date
    organized_data_frame['Date'] = organized_data_frame.apply(lambda row: update_date_with_year(row, subdirectory_dates), axis=1)
    
    # Convert the updated 'Date' column to a proper datetime object for further handling
    organized_data_frame['Date'] = pd.to_datetime(organized_data_frame['Date'], format='%Y.%m.%d', errors='coerce')
    
    print(f"First rows of organized_data_frame with updated dates: {organized_data_frame.head(3)}")
    return organized_data_frame

# Generate the organized data table
organized_data_frame = make_table(decoder_dataframe, subdirectory_dates)

# Find the unique dates from the recording
def find_unique_recording_dates(data_frame):
    # Extract the unique values from the 'Date' column
    unique_dates = data_frame['Date'].dt.strftime('%Y.%m.%d').unique()  # Convert back to string for display purposes
    return unique_dates

# Example usage
unique_dates = find_unique_recording_dates(organized_data_frame)
print("Unique recording dates:", unique_dates)

# ### Clean syllable labels formatting, then find the unique syllable labels in the dataframe
# def clean_and_convert_to_dict(row):
#     try:
#         # Strip leading and trailing single quotes and whitespace
#         row_cleaned = row.strip("''").strip()
#         # Replace single quotes with double quotes for valid JSON syntax
#         row_cleaned = row_cleaned.replace("'", '"')
#         # Convert the cleaned string to a dictionary
#         return json.loads(row_cleaned)
#     except json.JSONDecodeError as e:
#         print(f"JSON decoding failed for row: {row}\nError: {e}")
#         return None  # Return None or some default value if decoding fails

# Apply the function to all rows in the 'syllable_onsets_offsets_ms' column
organized_data_frame['syllable_onsets_offsets_ms_dict'] = organized_data_frame['syllable_onsets_offsets_ms']

# Now 'syllable_onsets_offsets_ms_dict' contains the cleaned and converted dictionaries
# Create a set to store all unique syllable labels
unique_syllable_labels = set()

# Iterate through each row in the 'syllable_onsets_offsets_ms_dict' column
for row in organized_data_frame['syllable_onsets_offsets_ms_dict']:
    if row:  # Check if the row is not None or empty
        # Add the keys (syllable labels) to the set
        unique_syllable_labels.update(row.keys())

# Convert the set to a sorted list (optional, for easier viewing)
unique_syllable_labels = sorted(unique_syllable_labels)

# Print or return the unique syllable labels
print("Unique syllable labels:", unique_syllable_labels)
# Out:
# Surgery date: 2024.10.21
# First rows of organized_data_frame with updated dates:                                   file_name  song_present  \
# 0    USA5508_45548.32222481_9_13_8_57_2.wav          True
# 1    USA5508_45548.32654069_9_13_9_4_14.wav          True
# 2  USA5508_45548.44913589_9_13_12_28_33.wav          True
#
#                           syllable_onsets_offsets_ms  \
# 0  {'9': [[0.0, 666.5079365079365], [7226.3492063...
# 1  {'30': [[0.0, 331.9047619047619], [844.6031746...
# 2                  {'8': [[0.0, 2048.095238095238]]}
#
#                     syllable_onsets_offsets_timebins Animal ID       Date  \
# 0  {'9': [[0.0, 247], [2678.0, 2949]], '8': [[246...   USA5508 2024-09-13
# 1  {'30': [[0.0, 123], [313.0, 502], [966.0, 1017...   USA5508 2024-09-13
# 2                                {'8': [[0.0, 759]]}   USA5508 2024-09-13
#
#   Hour Minute Second
# 0   08     57     02
# 1   09     04     14
# 2   12     28     33
# Unique recording dates: ['2024.09.13' '2024.09.14' '2024.09.15' '2024.09.16' '2024.09.17'
#  '2024.09.18' '2024.09.19' '2024.09.20' '2024.09.23' '2024.09.24'
#  '2024.09.25' '2024.09.26' '2024.09.27' '2024.10.01' '2024.10.02'
#  '2024.10.03' '2024.10.04' '2024.10.05' '2024.10.06' '2024.10.07'
#  '2024.10.08' '2024.10.10' '2024.10.11' '2024.10.12' '2024.10.13'
#  '2024.10.14' '2024.10.15' '2024.10.16' '2024.10.17' '2024.10.18'
#  '2024.10.19' '2024.10.20' '2024.10.21' '2024.10.22' '2024.10.23'
#  '2024.10.24' '2024.10.25' '2024.10.26' '2024.10.27' '2024.10.28'
#  '2024.10.29' '2024.10.30']
# Unique syllable labels: ['0', '1', '10', '11', '12', '13', '15', '16', '17', '18', '19', '2', '21', '22', '23', '24', '25', '28', '29', '3', '30', '4', '5', '6', '8', '9']

# %% [markdown]
# ### Get the syllable order for ONE song

# %%
# import json
# import re

# # Assuming this is the string you've printed
# sample_one_song = organized_data_frame['syllable_onsets_offsets_ms'][0]

# # Remove the extra outer single quotes and replace single quotes with double quotes
# cleaned_sample = sample_one_song.strip("''")
# cleaned_sample = re.sub(r"'", '"', cleaned_sample)

# # Now try to load it as JSON
# try:
#     sample_one_song_dict = json.loads(cleaned_sample)
#     print("Successfully parsed JSON.")
# except json.JSONDecodeError as e:
#     print(f"JSONDecodeError: {e}")

# # Now you can proceed with your original logic
# syllable_times = []

# # Loop through each syllable label and its corresponding onset/offset pairs
# for syllable_label, times in sample_one_song_dict.items():
#     for onset_offset in times:
#         syllable_times.append([syllable_label, onset_offset[0], onset_offset[1]])

# # Convert the onset and offset times to floats if needed
# syllable_times_array = np.array([[syllable_label, float(onset), float(offset)] 
#                                  for syllable_label, onset, offset in syllable_times])

# # Sort the array by the onset times (second column)
# syllable_times_array_sorted = syllable_times_array[syllable_times_array[:, 1].argsort()]

# # Display the sorted result
# syllable_times_array_sorted

# %%
import numpy as np

# Assuming this is the first row of your DataFrame
sample_one_song = organized_data_frame['syllable_onsets_offsets_ms'][0]

# Check if sample_one_song is already a dictionary
if isinstance(sample_one_song, dict):
    sample_one_song_dict = sample_one_song
    print("Successfully accessed the dictionary.")
else:
    print("The sample_one_song variable is not a dictionary. Please check its format.")

# Now you can proceed with your original logic
syllable_times = []

# Loop through each syllable label and its corresponding onset/offset pairs
for syllable_label, times in sample_one_song_dict.items():
    for onset_offset in times:
        syllable_times.append([syllable_label, onset_offset[0], onset_offset[1]])

# Convert the onset and offset times to floats if needed
syllable_times_array = np.array([[syllable_label, float(onset), float(offset)] 
                                 for syllable_label, onset, offset in syllable_times])

# Sort the array by the onset times (second column)
syllable_times_array_sorted = syllable_times_array[syllable_times_array[:, 1].argsort()]

# Display the sorted result
syllable_times_array_sorted
# Out:
# Successfully accessed the dictionary.
# array([['9', '0.0', '666.5079365079365'],
#        ['3', '2871.1111111111113', '3945.0793650793653'],
#        ['0', '3945.0793650793653', '4522.539682539683'],
#        ['15', '4522.539682539683', '6605.714285714286'],
#        ['24', '6605.714285714286', '6959.20634920635'],
#        ['8', '666.5079365079365', '2871.1111111111113'],
#        ['18', '6959.20634920635', '7107.619047619048'],
#        ['17', '7107.619047619048', '7226.349206349207'],
#        ['9', '7226.349206349207', '7957.619047619048'],
#        ['8', '7957.619047619048', '8537.77777777778'],
#        ['11', '8537.77777777778', '8969.523809523811'],
#        ['5', '8969.523809523811', '8988.4126984127'],
#        ['8', '8988.4126984127', '9541.587301587302'],
#        ['1', '9541.587301587302', '10434.761904761905']], dtype='<U32')

# %%
# import json
# import re
# import numpy as np

# # Assuming this is the string you've printed
# sample_one_song = organized_data_frame['syllable_onsets_offsets_ms'][0]

# # Remove the extra outer single quotes and replace single quotes with double quotes
# cleaned_sample = sample_one_song.strip("''")
# cleaned_sample = re.sub(r"'", '"', cleaned_sample)

# # Now try to load it as JSON
# try:
#     sample_one_song_dict = json.loads(cleaned_sample)
#     print("Successfully parsed JSON.")
# except json.JSONDecodeError as e:
#     print(f"JSONDecodeError: {e}")

# # Now you can proceed with your original logic
# syllable_times = []

# # Loop through each syllable label and its corresponding onset/offset pairs
# for syllable_label, times in sample_one_song_dict.items():
#     for onset_offset in times:
#         syllable_times.append([syllable_label, onset_offset[0], onset_offset[1]])

# # Convert the onset and offset times to floats if needed
# syllable_times_array = np.array([[syllable_label, float(onset), float(offset)] 
#                                  for syllable_label, onset, offset in syllable_times])

# # Sort the array by the onset times (second column)
# syllable_times_array_sorted = syllable_times_array[syllable_times_array[:, 1].argsort()]

# # Extract only the syllable labels in order of onset times
# syllable_order = syllable_times_array_sorted[:, 0]

# # Display the syllable order array
# syllable_order

# %% [markdown]
# ## Find the syllable order for each song, and add to the dataframe

# %%
# import json
# import re
# import numpy as np
# import pandas as pd

# # Function to generate syllable order from a single song data (syllable_onsets_offsets_ms)
# def get_syllable_order(sample_one_song):
#     # Clean the input and parse it as JSON
#     cleaned_sample = sample_one_song.strip("''")
#     cleaned_sample = re.sub(r"'", '"', cleaned_sample)
    
#     try:
#         sample_one_song_dict = json.loads(cleaned_sample)
#     except json.JSONDecodeError as e:
#         print(f"JSONDecodeError: {e}")
#         return None

#     syllable_times = []
    
#     # Loop through each syllable label and its corresponding onset/offset pairs
#     for syllable_label, times in sample_one_song_dict.items():
#         for onset_offset in times:
#             syllable_times.append([syllable_label, onset_offset[0], onset_offset[1]])

#     # Convert the onset and offset times to floats
#     syllable_times_array = np.array([[syllable_label, float(onset), float(offset)] 
#                                      for syllable_label, onset, offset in syllable_times])

#     # Sort the array by onset times (second column)
#     syllable_times_array_sorted = syllable_times_array[syllable_times_array[:, 1].argsort()]

#     # Extract only the syllable labels in order of onset times
#     syllable_order = syllable_times_array_sorted[:, 0]
    
#     return syllable_order

# # Function to iteratively find syllable orders for each row in the DataFrame
# def find_syllable_orders(organized_data_frame):
#     syllable_orders = []

#     for i, row in organized_data_frame.iterrows():
#         sample_one_song = row['syllable_onsets_offsets_ms']
#         syllable_order = get_syllable_order(sample_one_song)
#         if syllable_order is not None:
#             syllable_orders.append(syllable_order)
#         else:
#             syllable_orders.append([])  # In case of a parsing error, append an empty array

#     # Add a new column for the syllable orders
#     organized_data_frame['syllable_order'] = syllable_orders
    
#     return organized_data_frame

# # Assuming you've already loaded the data and updated the table
# organized_data_frame = make_table(decoder_dataframe, subdirectory_dates)

# # Now find syllable orders for each song in the organized_data_frame
# organized_data_frame_with_orders = find_syllable_orders(organized_data_frame)

# # Output the first few rows with syllable orders
# print(organized_data_frame_with_orders[['syllable_order']])

# %% [markdown]
# ## Map each syllable label to a letter instead of a number (1->A, etc. This is necessary so we can tell labels '1' and '2' apart from '12' once they all get concatonated  into a string)

# %% [markdown]
# ### Test this code for ONE song

# %%
# import json
# import re
# import numpy as np

# # Define a function to map syllable labels to unique characters
# def map_labels_to_characters(syllable_orders):
#     # Get all unique syllable labels across all rows
#     unique_labels = sorted(set(sum(syllable_orders, [])))  # Flatten the list of lists and get unique elements
    
#     # Create a mapping from each unique label to a unique character (uppercase, lowercase, digits)
#     available_chars = [chr(i) for i in range(65, 91)] + [chr(i) for i in range(97, 123)] + [chr(i) for i in range(48, 58)]  # A-Z, a-z, 0-9
#     if len(unique_labels) > len(available_chars):
#         raise ValueError("Too many unique labels to map to single characters!")
    
#     label_to_char = {label: available_chars[i] for i, label in enumerate(unique_labels)}
    
#     # Replace each label in the syllable order with its corresponding character
#     syllable_orders_mapped = []
#     for order in syllable_orders:
#         mapped_order = ''.join([label_to_char[label] for label in order])
#         syllable_orders_mapped.append(mapped_order)
    
#     return syllable_orders_mapped, label_to_char

# # Example syllable order (as shown in the sample)
# syllable_orders = [
#     ['8', '21', '22', '21', '22', '21', '22', '21', '26', '23', '2', '3', '26', '5', '11', '14']
# ]

# # Map the labels and get the string representation
# syllable_orders_mapped, label_to_char = map_labels_to_characters(syllable_orders)

# # Output the mapped syllable orders and the label-to-character mapping
# print("Mapped syllable order:", syllable_orders_mapped)
# print("Label-to-character mapping:", label_to_char)

# %%
import json
import re
import numpy as np
import pandas as pd

# Function to generate syllable order from a single song data (syllable_onsets_offsets_ms)
def get_syllable_order(sample_one_song):
    # Check if sample_one_song is already a dictionary
    if isinstance(sample_one_song, dict):
        sample_one_song_dict = sample_one_song
    elif isinstance(sample_one_song, str):
        # If it's a string, attempt to clean and parse it as JSON
        cleaned_sample = sample_one_song.strip("''")
        cleaned_sample = re.sub(r"'", '"', cleaned_sample)
        
        try:
            sample_one_song_dict = json.loads(cleaned_sample)
        except json.JSONDecodeError as e:
            print(f"JSONDecodeError: {e}")
            return None
    else:
        # If it's neither a dict nor a string, return None
        print(f"Unexpected data type: {type(sample_one_song)}")
        return None

    syllable_times = []
    
    # Loop through each syllable label and its corresponding onset/offset pairs
    for syllable_label, times in sample_one_song_dict.items():
        for onset_offset in times:
            syllable_times.append([syllable_label, onset_offset[0], onset_offset[1]])

    # Convert the onset and offset times to floats
    syllable_times_array = np.array([[syllable_label, float(onset), float(offset)] 
                                     for syllable_label, onset, offset in syllable_times])

    # Sort the array by onset times (second column)
    syllable_times_array_sorted = syllable_times_array[syllable_times_array[:, 1].argsort()]

    # Extract only the syllable labels in order of onset times
    syllable_order = syllable_times_array_sorted[:, 0]
    
    return syllable_order

# Function to iteratively find syllable orders for each row in the DataFrame
def find_syllable_orders(organized_data_frame):
    syllable_orders = []

    for i, row in organized_data_frame.iterrows():
        sample_one_song = row['syllable_onsets_offsets_ms']
        syllable_order = get_syllable_order(sample_one_song)
        if syllable_order is not None:
            syllable_orders.append(syllable_order)
        else:
            syllable_orders.append([])  # In case of a parsing error, append an empty array

    # Add a new column for the syllable orders
    organized_data_frame['syllable_order'] = syllable_orders
    
    return organized_data_frame

# Assuming you've already loaded the data and updated the table
# organized_data_frame = make_table(decoder_dataframe, subdirectory_dates)

# Now find syllable orders for each song in the organized_data_frame
organized_data_frame_with_orders = find_syllable_orders(organized_data_frame)

# Output the first few rows with syllable orders
print(organized_data_frame_with_orders[['syllable_order']])
# Out:
#                                          syllable_order
# 0       [9, 3, 0, 15, 24, 8, 18, 17, 9, 8, 11, 5, 8, 1]
# 1        [30, 16, 30, 9, 8, 30, 8, 30, 3, 0, 30, 30, 8]
# 2                                                   [8]
# 3                                         [16, 3, 0, 8]
# 4                 [8, 3, 0, 15, 17, 28, 13, 17, 24, 30]
# ...                                                 ...
# 4572                                             [8, 1]
# 4573             [8, 5, 0, 15, 8, 18, 17, 18, 17, 8, 5]
# 4574               [16, 8, 11, 24, 3, 16, 24, 5, 0, 17]
# 4575  [8, 1, 11, 2, 24, 2, 24, 2, 24, 2, 24, 2, 24, ...
# 4576               [16, 24, 16, 24, 16, 24, 8, 3, 5, 0]
#
# [4577 rows x 1 columns]

# %% [markdown]
# ### Do this for EVERY song in the dataframe

# %%
# import json
# import re
# import numpy as np
# import pandas as pd

# # Function to generate syllable order from a single song data (syllable_onsets_offsets_ms)
# def get_syllable_order(sample_one_song):
#     # Clean the input and parse it as JSON
#     cleaned_sample = sample_one_song.strip("''")
#     cleaned_sample = re.sub(r"'", '"', cleaned_sample)
    
#     try:
#         sample_one_song_dict = json.loads(cleaned_sample)
#     except json.JSONDecodeError as e:
#         print(f"JSONDecodeError: {e}")
#         return None

#     syllable_times = []
    
#     # Loop through each syllable label and its corresponding onset/offset pairs
#     for syllable_label, times in sample_one_song_dict.items():
#         for onset_offset in times:
#             syllable_times.append([syllable_label, onset_offset[0], onset_offset[1]])

#     # Convert the onset and offset times to floats
#     syllable_times_array = np.array([[syllable_label, float(onset), float(offset)] 
#                                      for syllable_label, onset, offset in syllable_times])

#     # Sort the array by onset times (second column)
#     syllable_times_array_sorted = syllable_times_array[syllable_times_array[:, 1].argsort()]

#     # Extract only the syllable labels in order of onset times
#     syllable_order = syllable_times_array_sorted[:, 0]
    
#     return syllable_order

# # Function to map syllable labels to unique characters
# def map_labels_to_characters(syllable_orders):
#     # Flatten the list of syllable orders (since syllable_orders is a list of lists)
#     flat_syllable_orders = [label for sublist in syllable_orders for label in sublist]
    
#     # Get all unique syllable labels
#     unique_labels = sorted(set(flat_syllable_orders))
    
#     # Create a mapping from each unique label to a unique character (uppercase, lowercase, digits)
#     available_chars = [chr(i) for i in range(65, 91)] + [chr(i) for i in range(97, 123)] + [chr(i) for i in range(48, 58)]  # A-Z, a-z, 0-9
#     if len(unique_labels) > len(available_chars):
#         raise ValueError("Too many unique labels to map to single characters!")
    
#     label_to_char = {label: available_chars[i] for i, label in enumerate(unique_labels)}
    
#     # Replace each label in the syllable order with its corresponding character
#     syllable_orders_mapped = []
#     for order in syllable_orders:
#         mapped_order = ''.join([label_to_char[label] for label in order])
#         syllable_orders_mapped.append(mapped_order)
    
#     return syllable_orders_mapped, label_to_char

# # Function to iteratively find syllable orders for each row and map them
# def find_mapped_syllable_orders(organized_data_frame):
#     syllable_orders = []

#     for i, row in organized_data_frame.iterrows():
#         sample_one_song = row['syllable_onsets_offsets_ms']
#         syllable_order = get_syllable_order(sample_one_song)
#         if syllable_order is not None:
#             syllable_orders.append(syllable_order)
#         else:
#             syllable_orders.append([])  # In case of a parsing error, append an empty array

#     # Map the syllable orders to unique characters
#     syllable_orders_mapped, label_to_char = map_labels_to_characters(syllable_orders)

#     # Add new columns for both the raw syllable orders and the mapped syllable orders
#     organized_data_frame['syllable_order'] = syllable_orders
#     organized_data_frame['mapped_syllable_order'] = syllable_orders_mapped
    
#     return organized_data_frame, label_to_char

# # Assuming you've already loaded the data and updated the table
# organized_data_frame = make_table(decoder_dataframe, subdirectory_dates)

# # Now find and map syllable orders for each song in the organized_data_frame
# organized_data_frame_with_orders, label_to_char = find_mapped_syllable_orders(organized_data_frame)

# # Output the first few rows with both syllable orders and mapped syllable orders
# # Output only the 'syllable_order' and 'mapped_syllable_order' columns
# print(organized_data_frame_with_orders[['syllable_order', 'mapped_syllable_order']])

# print("Label-to-character mapping:", label_to_char)

# # Output only the 'syllable_order' and 'mapped_syllable_order' columns
# print(organized_data_frame_with_orders[['syllable_order', 'mapped_syllable_order']].head(2))
# print("Label-to-character mapping:", label_to_char)

# %%
import json
import re
import numpy as np
import pandas as pd

# Function to generate syllable order from a single song data (syllable_onsets_offsets_ms)
def get_syllable_order(sample_one_song):
    # Check if sample_one_song is already a dictionary
    if isinstance(sample_one_song, dict):
        sample_one_song_dict = sample_one_song
    elif isinstance(sample_one_song, str):
        # If it's a string, attempt to clean and parse it as JSON
        cleaned_sample = sample_one_song.strip("''")
        cleaned_sample = re.sub(r"'", '"', cleaned_sample)
        
        try:
            sample_one_song_dict = json.loads(cleaned_sample)
        except json.JSONDecodeError as e:
            print(f"JSONDecodeError: {e}")
            return None
    else:
        # If it's neither a dict nor a string, return None
        print(f"Unexpected data type: {type(sample_one_song)}")
        return None

    syllable_times = []
    
    # Loop through each syllable label and its corresponding onset/offset pairs
    for syllable_label, times in sample_one_song_dict.items():
        for onset_offset in times:
            syllable_times.append([syllable_label, onset_offset[0], onset_offset[1]])

    # Convert the onset and offset times to floats
    syllable_times_array = np.array([[syllable_label, float(onset), float(offset)] 
                                     for syllable_label, onset, offset in syllable_times])

    # Sort the array by onset times (second column)
    syllable_times_array_sorted = syllable_times_array[syllable_times_array[:, 1].argsort()]

    # Extract only the syllable labels in order of onset times
    syllable_order = syllable_times_array_sorted[:, 0]
    
    return syllable_order

# Function to map syllable labels to unique characters
def map_labels_to_characters(syllable_orders):
    # Flatten the list of syllable orders (since syllable_orders is a list of lists)
    flat_syllable_orders = [label for sublist in syllable_orders for label in sublist]
    
    # Get all unique syllable labels
    unique_labels = sorted(set(flat_syllable_orders))
    
    # Create a mapping from each unique label to a unique character (uppercase, lowercase, digits)
    available_chars = [chr(i) for i in range(65, 91)] + [chr(i) for i in range(97, 123)] + [chr(i) for i in range(48, 58)]  # A-Z, a-z, 0-9
    if len(unique_labels) > len(available_chars):
        raise ValueError("Too many unique labels to map to single characters!")
    
    label_to_char = {label: available_chars[i] for i, label in enumerate(unique_labels)}
    
    # Replace each label in the syllable order with its corresponding character
    syllable_orders_mapped = []
    for order in syllable_orders:
        mapped_order = ''.join([label_to_char[label] for label in order])
        syllable_orders_mapped.append(mapped_order)
    
    return syllable_orders_mapped, label_to_char

# Function to iteratively find syllable orders for each row and map them
def find_mapped_syllable_orders(organized_data_frame):
    syllable_orders = []

    for i, row in organized_data_frame.iterrows():
        sample_one_song = row['syllable_onsets_offsets_ms']
        syllable_order = get_syllable_order(sample_one_song)
        if syllable_order is not None:
            syllable_orders.append(syllable_order)
        else:
            syllable_orders.append([])  # In case of a parsing error, append an empty array

    # Map the syllable orders to unique characters
    syllable_orders_mapped, label_to_char = map_labels_to_characters(syllable_orders)

    # Add new columns for both the raw syllable orders and the mapped syllable orders
    organized_data_frame['syllable_order'] = syllable_orders
    organized_data_frame['mapped_syllable_order'] = syllable_orders_mapped
    
    return organized_data_frame, label_to_char

# Assuming you've already loaded the data and updated the table
# Example: organized_data_frame = make_table(decoder_dataframe, subdirectory_dates)

# Now find and map syllable orders for each song in the organized_data_frame
organized_data_frame_with_orders, label_to_char = find_mapped_syllable_orders(organized_data_frame)

# Output the first few rows with both syllable orders and mapped syllable orders
# Output only the 'syllable_order' and 'mapped_syllable_order' columns
print(organized_data_frame_with_orders[['syllable_order', 'mapped_syllable_order']])

# Print label-to-character mapping
print("Label-to-character mapping:", label_to_char)

# Display the first 2 rows as an example
print(organized_data_frame_with_orders[['syllable_order', 'mapped_syllable_order']].head(2))
# Out:
#                                          syllable_order  \
# 0       [9, 3, 0, 15, 24, 8, 18, 17, 9, 8, 11, 5, 8, 1]
# 1        [30, 16, 30, 9, 8, 30, 8, 30, 3, 0, 30, 30, 8]
# 2                                                   [8]
# 3                                         [16, 3, 0, 8]
# 4                 [8, 3, 0, 15, 17, 28, 13, 17, 24, 30]
# ...                                                 ...
# 4572                                             [8, 1]
# 4573             [8, 5, 0, 15, 8, 18, 17, 18, 17, 8, 5]
# 4574               [16, 8, 11, 24, 3, 16, 24, 5, 0, 17]
# 4575  [8, 1, 11, 2, 24, 2, 24, 2, 24, 2, 24, 2, 24, ...
# 4576               [16, 24, 16, 24, 16, 24, 8, 3, 5, 0]
#
#                       mapped_syllable_order
# 0                            ZTAGPYJIZYDWYB
# 1                             UHUZYUYUTAUUY
# 2                                         Y
# 3                                      HTAY
# 4                                YTAGIRFIPU
# ...                                     ...
# 4572                                     YB
# 4573                            YWAGYJIJIYW
# 4574                             HYDPTHPWAI
# 4575  YBDLPLPLPLPLPYBLPMLPLPTLPLPLPLYAIGYGY
# 4576                             HPHPHPYTWA
#
# [4577 rows x 2 columns]
# Label-to-character mapping: {'0': 'A', '1': 'B', '10': 'C', '11': 'D', '12': 'E', '13': 'F', '15': 'G', '16': 'H', '17': 'I', '18': 'J', '19': 'K', '2': 'L', '21': 'M', '22': 'N', '23': 'O', '24': 'P', '25': 'Q', '28': 'R', '29': 'S', '3': 'T', '30': 'U', '4': 'V', '5': 'W', '6': 'X', '8': 'Y', '9': 'Z'}
#                                     syllable_order mapped_syllable_order
# 0  [9, 3, 0, 15, 24, 8, 18, 17, 9, 8, 11, 5, 8, 1]        ZTAGPYJIZYDWYB
# 1   [30, 16, 30, 9, 8, 30, 8, 30, 3, 0, 30, 30, 8]         UHUZYUYUTAUUY

# %% [markdown]
# ## Now, sort the data by into different groups (e.g. by days, by pre vs. post lesion group), then export them into .mat files

# %% [markdown]
# ### Test: Get all the arrays from one day of recording:

# %%
# import pandas as pd

# # Filter the DataFrame for the first day of recording
# def get_first_day_songs(organized_data_frame):
#     # Find the first day of recording
#     first_day = organized_data_frame['Date'].min()
    
#     # Filter the DataFrame for the first day
#     first_day_data = organized_data_frame[organized_data_frame['Date'] == first_day]
    
#     return first_day_data

# # Generate a 1xN cell array where each cell contains the mapped syllable order for the first day
# def generate_first_day_cell_array(organized_data_frame):
#     # Get the filtered data for the first day
#     first_day_data = get_first_day_songs(organized_data_frame)
    
#     # Extract the mapped syllable orders into a list (which acts as a cell array)
#     mapped_syllable_orders = first_day_data['mapped_syllable_order'].tolist()
    
#     # Create a 1xN cell array (as a list of lists for flexibility)
#     cell_array = [mapped_syllable_orders]
    
#     return cell_array

# # Assuming organized_data_frame_with_orders contains the data
# first_day_cell_array = generate_first_day_cell_array(organized_data_frame_with_orders)

# # Output the result
# print("1xN cell array of mapped syllable orders for the first day of recording:")
# print(first_day_cell_array)

# %% [markdown]
# ### Get the syllable string arrays from each day of recording

# %%
import pandas as pd

# Function to get the unique dates in the DataFrame
def get_unique_dates(organized_data_frame):
    return sorted(organized_data_frame['Date'].unique())

# Function to generate a cell array for each day of recording
def generate_cell_arrays_for_each_day(organized_data_frame):
    # Get all unique dates
    unique_dates = get_unique_dates(organized_data_frame)
    
    # Iterate through each unique date
    for date in unique_dates:
        # Filter the DataFrame for the current date
        day_data = organized_data_frame[organized_data_frame['Date'] == date]
        
        # Extract the mapped syllable orders into a list (which acts as a cell array)
        mapped_syllable_orders = day_data['mapped_syllable_order'].tolist()
        
        # Create a 1xN cell array (as a list of lists for flexibility)
        cell_array = [mapped_syllable_orders]
        
        # Print the date and the corresponding cell array
        print(f"Recording Date: {date}")
        print("1xN cell array of mapped syllable orders for the day:")
        print(cell_array)
        print("\n")

# Assuming organized_data_frame_with_orders contains the data
generate_cell_arrays_for_each_day(organized_data_frame_with_orders)
# Out:
# Recording Date: 2024-09-13 00:00:00
# 1xN cell array of mapped syllable orders for the day:
# [['ZTAGPYJIZYDWYB', 'UHUZYUYUTAUUY', 'Y', 'HTAY', 'YTAGIRFIPU', 'Y', 'Y', 'YTUYBCDYU', 'YTVG', 'YTAGAG', 'ZTWYDYDGU', 'HUYLHPHPGPUYPAUB', 'HYTWYB', 'ZYVBYZCUYDY', 'YDY', 'Y', 'HUJGUL', 'Y', 'ZWYTY', 'YU']]
#
#
# Recording Date: 2024-09-14 00:00:00
# 1xN cell array of mapped syllable orders for the day:
# [['YTBAPFGPNHNHBLNHPHPHPUYUBUBUYUBYTABABGZYTAGYJGYTAVGJGAGJPQYUBYDTTAGYZBYDY', 'YAGHTUYUYDYTVUYZCZCZCUPAUGTYUYBGHGVJQGQJGYTABUYDYAGBPHYZYWYT', 'UUDTAGYHTAUYBYUYNHVYZAGCPUZCY', 'WZGIGYYDWYBU', 'YUZ', 'HDTZABYUYUYGBUYTAGJGJY', 'YPGYZGJYDWYWYABGPYUYUYCZUHU', 'YDTAY', 'ARIJGYTAGYCDWYWYGBNHNHUYDYTGAG', 'C', 'DBGY', 'YGVWTAGPHPUYWYA', 'C', 'Y', 'HYAGIJRGUYBULPHUYATTABUGYWDT', 'HYTABYWYTUGVVZYUHPHPUZUYDYDYD', 'YDYTAHPHPYTGVGIFIJRGIQIUAGPHUY', 'HDYGYUDWYTBZHY', 'ZUYTAGCLPQLQHD', 'YUZC', 'VQZCUDWYP', 'YTUG', 'HAPGJUYUWYTAVGBYYDYTATAGYVT', 'VCUYGUZ', 'YDYBYBGRGP', 'Y', 'YUHUYZCDWYUYUYUYUYVUHVY', 'HPGUYUZPNHPLG', 'HNYHJG', 'HVZ', 'ZZUHGYZCUYBUHCPGUYDWUY', 'UYH', 'ZTAGYD', 'YYTADYWYWYWTAGVYBLU', 'YT', 'YB', 'YPZGHPHPWDTAGJGHY', 'HVGVGUPGPGTDYTA', 'YGYDWTAGYNHYPGYWYTBZV', 'UYBDYTAGPLPL', 'ZWTDCYGUY', 'HY', 'PGYHPTAGYWTVA', 'YB', 'HYDYB', 'YHVUJGYZWYTC', 'VTYAGUDBY', 'YHPHPUUPGUYDTYAGYUYBUYTZBUYZCDYB', 'YU', 'YYW', 'YTAGPYWDWDY', 'YAT', 'YB', 'YYUD', 'Y', 'ZY', 'ZDTUW', 'Y', 'YYDYBAIGJGTAGYWTBVG', 'YW', 'YDW', 'YTAGJY', 'PYUWTAGPUYU', 'HPUYPHPZCUYD', 'HYBLPHPHPGVGZPUYDYUPGBWYTAVCUYDYDWTAGNHJGUYU', 'PYGWTAVGPG']]
#
#
# Recording Date: 2024-09-15 00:00:00
# 1xN cell array of mapped syllable orders for the day:
# [['UDYY', 'YPHPNJFHGYWYTAGJIGYWYWYWDTBGJYTZALHPHUUYTABYH', 'YYWDYUGJGJPHPHUFGYDYTBPUYTHAYPGUYH', 'UYDUYYUUVYZGYPJPJBYWYWYCZCB', 'YYDTYGVHGYB', 'YAGAGTPHQPGPYUZHNH', 'YTAGJGUYWYBAGUVYYUZ', 'Y', 'HWYYTAGPQPJPRJGUGUVY', 'YBUGPVCYTAJGJFGYWDTAGVY', 'VPGPYWDYTALPJGPPUYHGVPHPHPHHYDYUYYTAGV', 'HNTHAGPJGVYTABPUYPUDUDY', 'HAGBPGJQIZJUCYTGYD', 'VCUYTZAG', 'HGQYGVUYUZCDYA', 'Y', 'YDBTAYUYTUAGIYJY', 'YYD', 'UWYAGRGYAGJGYBGUYYDYTAGPGRGY', 'YCDYBZ', 'YTA', 'VYB', 'UPH', 'YDYAGP', 'Y', 'HPUVYNHUZCDTPAGNH', 'Y', 'YTAGVHLUYZCDYB', 'Y', 'ZWDYTAYZCDWDWYBYCWADVGIGIPUY', 'HAUZCDYUGVZDYB', 'HUPHPVY', 'YTAB', 'YB', 'DDYBHPUYYTAVY', 'YYUYHBGPYDYTTAJGPJGYUYHJUYDATGVRGUYWAGJG', 'HU', 'YTAPUYUZDCDWAGUY', 'Y', 'YYAGPGUYBGVUPGZCDYTAYD', 'VGYWYWYBZUHPHPHPHYYWUUYDYA', 'YB', 'HGZUDWDWYWATUP', 'YTAGPYBT', 'PLJQPYVATYNHP', 'HTUTU', 'HPHPVYBAYDYG', 'YTYW', 'YLPBHPYUGZHNHYWYTB', 'NPGPYDTAVGPGYUNZHCDWYHAGHUY', 'YTAG', 'DTAGYUDWYYWY', 'YHPG', 'UTYDY', 'YB', 'VUZYG', 'PPYVQUYBVYPTGYBYLUCDTAG', 'YYD', 'YPHPVZH', 'YAB', 'YTYA']]
#
#
# Recording Date: 2024-09-16 00:00:00
# 1xN cell array of mapped syllable orders for the day:
# [['UBYTAGPYDYT', 'ZYCD', 'BYBYUZGLBWYTAGJPHPYYCYD', 'YDYBZC', 'UDYBZC', 'HPYTAYGDY', 'YTYAYAGPUYWDTBLPLPYUTAGJGYUDWYAGNHDPHPHPNHNHGRFPWD', 'HPHPHPUPUY', 'PGZ', 'HPYTAGPY', 'YDTUAGVZPGYZCDYCDWYUABGYBZUY', 'VTDYPHPZYUDYHBUVGUPY', 'HATBLPLGVWYUYUYTAGYPJPHUTAPIPY', 'YYBUZCDAGPDY', 'YUYPHPHPGVPGYTAGSUYBYULPHPJPJGYTDYBAGJFJHPHPLJLUGZCUPJFIJFGJGYHGBPNHNHPJYB', 'PYTD', 'VYTAGJP', 'PDHYHGPPGHPYTAGJGIJRJYWYWYWYWYWY', 'YTYWDC', 'ZYBCYD', 'YB', 'YG', 'YBGV', 'CYJPJFJPYBUYUWYTGJGZCDYBAUDYUHNHPHPVG', 'Y', 'YCDZ', 'YB', 'YGPGZCDUHPHPRJGJGYWYTA']]
#
#
# Recording Date: 2024-09-17 00:00:00
# 1xN cell array of mapped syllable orders for the day:
# [['UUYTYAGPYDYTAB', 'T', 'HUAUBABGY', 'YWYAGPYDWYTAUPJGDUVGPUYBY', 'VBVPYYWYAGPYDTYBYAGYATWYTAIPGUHY', 'DATYY', 'HTYGNHPHPFGVYWDTAGIFIPYTUYDHUHGYDTAGWPIPUYPYWYWYAPJGYPHTAGPY', 'HNHPHPGPYTA', 'HTAGQPYHVTBUZCZUYGJATUDUHNHPHPYJGUYGPGPNHNHNHOPOPUY', 'HUYUYUZCVHPGPVYTZCDABY', 'T', 'HTAGPGYVBYTAGJPY', 'WBYDTAIGYJRIPHPNHPGJGJPBJYDYAPLPLPLYTAHJFGPQPJQYPNHPDUYGPTYWYTUY', 'HWYWYUYBUHPUGYJWYWYTAGRFJGJPZGYUY', 'Y', 'ZYBUHPGYPUYWAGPJRPJBHUUGCPQPYTDD', 'HPGY', 'YAJFPGJRJPGJTYUYDYBAGJGPHYT', 'YYBUTAGPHPUPGYD', 'ZTCD', 'HTAUYPBYHPWYTAGUVPGZCDYAGY', 'ZDYBC', 'YBU', 'HPNHPYDTARGJGOPU', 'YT', 'PYTAGJRPU', 'HNGVZYDYDHYPNBHP', 'YB', 'VZUYBG', 'ZTAFGUYCTADDY', 'ZDY', 'HVGUYZCUHPDYBYUPGYTA', 'YBDTAGFIPYAB', 'Y', 'PHPPHPH', 'NHYNHA', 'VHPNHPY', 'HQUZP', 'YBUYUZCDYWA', 'HGDNHTYPP', 'PTAGQGYTOPLPLPJFGFGPGYUY', 'YUZHBYDTDAJFIJIPYAGIWPAFGPOPOPOPOPVWY', 'YCUYUZT', 'YTUVG', 'YTAPGPDTA', 'YTAGPYB', 'YDT', 'VDYBP', 'C', 'Y', 'ZTWYCBD']]
#
#
# Recording Date: 2024-09-18 00:00:00
# 1xN cell array of mapped syllable orders for the day:
# [['Y', 'YYD', 'Y', 'ZTCBLPNHNHDPU', 'HYCDYTAVHUYWZYWYA', 'HJPUPHWDYZUVUYTPVGIFIPNGDYHAP', 'HUYTA', 'YA', 'UYWTY', 'ZAFIFIJIGJGIJIYWY', 'HUYHBUPYWDAQIUPQZCYN', 'ZBYDTYTCAGFIJFGJGLPLPHPHWYWDYWYAYYH', 'HNHPQOPUYPHPU', 'YPHPUYZCDHYB', 'YTBPFGI', 'HTBYTAIJIGYWYWY', 'HHHPUVPGYYTAGDWYBPGJPHPHPHUNY', 'YWDT', 'Y', 'YTA', 'YDTARGPYWYAB', 'HVPHPGYAYDYUH', 'HJUPNVHYTDYAJFGJFG', 'YGPVPA', 'ZTYBYPHPU', 'YWYTYBU', 'U', 'HV', 'YT', 'YTB', 'HPYBUYWYWYANHGJIF', 'PZCDWYTQAPV', 'HNHPUYATB', 'YTYBBPIGYWA', 'ZTCD', 'HNHVY', 'HFGYWATBPUPLPLPLYHSUSUP', 'YUQFQIQJQFIJFIJGUBYGVGZUYBWT', 'YGJGFGIJRFGJPYWYAIGJPIJIPIJPGPJPUYTTAAGJIPYB', 'YWDY', 'YAUYBWYWAYAYUZVGYT']]
#
#
# Recording Date: 2024-09-19 00:00:00
# 1xN cell array of mapped syllable orders for the day:
# [['YDWYADBLQPIPIPIPIGZYYBZGIJIGPYTC', 'HGYBPUYNWYHTAP', 'YB', 'YB', 'HPYTDY', 'YBUYTAY', 'YB', 'YB', 'YAGPUYBBGVHPHPYDW', 'ZIJIPVYBUYUAJIJGBTPHPHPHPHYUYYPGPGJ', 'VYUTAWYDYJGIJIGQUYWYTBAGJAPYU', 'HGYTNHABP', 'YBUYW', 'ZWYAPFGJFPYUWYTAPJFATACYGIGJFIJUYDBY', 'HHFJIFIGDYAIGFGFIJIJQJPYPYHVYTAN', 'HPFPGVQVPUYTAP', 'YYBUYUDB', 'HPV', 'VYATWYAPJIJIPS', 'ZGIVPYHUYDTAOGJFPTBPHPYHYUA', 'HNHNH', 'YTADYAB', 'YABUHPYT', 'UDYY', 'HZC', 'YBWAGIGJGAYPQPQYA', 'YTAGQIPY', 'YTDAUYT', 'YB', 'ZTACD', 'HYB', 'Y', 'HYDTAB', 'HPHPYTAFGFIJFIJIFIJPIRIPIJIG', 'YYWYTPUAWYTBPLPLPGI', 'HPHPY', 'HUYTAYDWYPOPLUNYPUH', 'YDTAZPYATC', 'HPHP', 'DC', 'CU', 'PYTAGJPYB', 'YTAGPYB', 'HYTAPGHIPIFIPP', 'Y', 'HDTAGJIJILIJPLPYTAGJRPYW', 'PUYPTGHPPHYDTA', 'YCDGYAGAGAGYJYY', 'YUATYGIFGFGJGJPYBAY', 'YB', 'YCDTAZ', 'HNHPUYGYTA']]
#
#
# Recording Date: 2024-09-20 00:00:00
# 1xN cell array of mapped syllable orders for the day:
# [['ZTD', 'GHPHUYP', 'YATAYHT', 'YDTW', 'YUB', 'ZTYBCD', 'ZTAWYBCAGPDU', 'HUZCDTAGJFJIJIJIGPYT', 'ZWYWYWACD', 'TYGJGA', 'HHZCDYN', 'HBUY', 'Y', 'YB', 'ZYTBCD', 'Y', 'YTA', 'Y', 'WAT', 'YBPLP', 'YAGJPYBD', 'ZDWAGJFYCY', 'YWB', 'ZTCD', 'ZCY', 'YWDWDWAWAG', 'YUDYBAZ', 'YDWYTAGIGIG', 'Y', 'CDY', 'T', 'YB', 'YGB', 'YTB', 'ZYBCD']]
#
#
# Recording Date: 2024-09-23 00:00:00
# 1xN cell array of mapped syllable orders for the day:
# [['ZYWTAACGYBDGV', 'YGIJGJGBGYWA', 'HPHPHPYTAGIJI', 'UCYYWUAYUZ', 'HNHPHPGYUYTBP', 'HGYWYDNYHP', 'YBT', 'ZWYBYCUZVYDB', 'ZTYCAIGYD', 'HYQPUYDWYAYPTAJIGJGJFIJIFIJIP', 'ZAWYBGCYDT', 'YB', 'HPHPHPYDTBLPLPHPI', 'HYV', 'HGIJIDGYYBZHPGYCA', 'HYPYWYAIFIGJIJIP', 'ZTAGCD', 'NYZNHCDTHBWYTAU', 'YCDTALPZ']]
#
#
# Recording Date: 2024-09-24 00:00:00
# 1xN cell array of mapped syllable orders for the day:
# [['YBY', 'ZYWYTTACGYBDGI', 'HAHGPYNBHVPYNHPT', 'ZYBCYDTA', 'Y', 'HGYPPHPHYPWAH', 'VWDTAIJIGY', 'YYDTAGU', 'PPHUHPL', 'U', 'UYUYUY', 'OYWYAP', 'HYPBNHYPGVU', 'YT', 'HOPOPOPY', 'HOPQOPYDYB', 'ZACFIJFIPIPIGDPYWDYY', 'HNHPYAGA', 'YTYG', 'YAIFIFIJFIJIPYWYB', 'YBY', 'HUYTAGJFIPIU', 'HHYWDVGN', 'Y', 'YGPHPHPHZDTYHZ', 'YW', 'HGPVYZCDTAIJIGPYWYWA', 'Y', 'ZCYTD', 'PWDTYB', 'VPUYA', 'YBPHPHPYWYTB', 'Y', 'PBUY', 'HPHPYWYTB', 'PTY', 'PTY', 'PUHWYWYWYWYWDTY', 'ZTYCBD', 'CTYHVD', 'ZYCD', 'ZBYDCY', 'ZTACD', 'YWAGIJIJPJPYDYBVAIGIJIJFIJFY', 'VAFIJIJFGIJGPYGIR', 'HYTPAQGJPOIPIP', 'PYPWYTQP', 'YTAY', 'HFIJPQGYUWYOPQPOPVUYPFIJIYDYTA', 'YGIJFGYBULUPGPYBWYAGIJIJFIPYYGYWDTA', 'HTYANHPYBGVYD', 'YBUY', 'YPOPGYDYTA', 'HPNYHWYWYANHFIJFIJFI', 'HPLPLPYTAPYATYB', 'PWQYOAOPPY', 'YYWYAB', 'PAGYAGVYWT', 'ZGTYBCYDA', 'ZAYBCYUPVYWDT', 'HWAGPJHPYTGY', 'HYAJAJPFGP', 'HPQPUZCDYA', 'YDTW', 'CTD', 'YYDTZCYC', 'YB', 'YT', 'CBYWDYAY', 'YTAG', 'YT', 'HPHPHPOYWDPH', 'PUYBQAOPGIJFIJFIU', 'YAYTBYUYU', 'VGJIJIJFIJIGGTLPLPLYPFIJFJYWYYA', 'GBY', 'HPOPOPQPQPIYWY', 'OWYWYDWODAPIJIJPFGPGJIJIJIYY', 'HOQOPQOPYBNH', 'PTAQPOPIJIJIJGYQY', 'YTDWYWYAB', 'YGPUTAIGPYWYA', 'QPDYTABY', 'PWYDYBPWYTYAYGJIJIPQPY', 'PDTOBPOPOPY', 'HPHPHPOPY', 'PYPQTOVO', 'POPAIFIJIPYIGYDY', 'PYODPAQOP', 'HYT', 'HDYY', 'ZDYYTA', 'YBWTABLPLPLPLPLPYDY', 'PTABOYYPHPHPYD', 'YAW', 'YDYTAGVY', 'YBY', 'HOPQGYDYBNH', 'YOPHPHPYTDYBLPUU', 'HPHPHPLPQPYBY', 'YLPLPLPYDTAAIPYDWYB', 'PDYOPTAOYGIJIJIJFIPQPY', 'HPHPYTYGYGY', 'YTAFIJFIJFIGJIPQPYBPLPLPLPTDYWYAJIJIJIJIPLPLPLPLPY', 'PY', 'YBY', 'YTBCGYD', 'YPYTAHZ', 'YB', 'YYBUVYWYB', 'PPQOPYPQTOOAPYQO', 'HGPYTAIJFIPJPFIPU', 'ZTAGCYDWAB', 'OIYWPDYAG', 'PFIJIJIPYDYPNHPHPHYGYDWAFJ', 'YB', 'YYBT', 'ZAGYTBCPHNHDPNHPYW', 'YYBD', 'PYYW']]
#
#
# Recording Date: 2024-09-25 00:00:00
# 1xN cell array of mapped syllable orders for the day:
# [['YB', 'HTYBGJIGIAYBGYD', 'YU', 'YB', 'YWYTAPHPLPLPJIJIJIGVY', 'ZTCYGUGUGUD', 'HGIJGIPYDTYBLPLPLPLPLYWAGJIJIYBPHPHPHPYWA', 'HBY', 'YT', 'YTB', 'U', 'YTDAIG', 'HYNH', 'YTAGYDWA', 'ZWYBLPLPLPLYPYTAIJIJIJIJIJIUYUYUWDTBLPTACGDJIJIJIPY', 'VZCY', 'PTYYBPHPG', 'HHIYPPDYAB', 'YB', 'YIJIJFIPYBPLPLPLPTAGIPIYWA', 'YAGYWBDYZHNHYT', 'YB', 'YTAG', 'YAGJIJAIFIJPJLJPLPLPLPYPUPY', 'Y', 'YB', 'ZIJIGTYWAGADGYDWYAGJFIJ', 'HPHPHPHUYB', 'YB', 'CTYBD', 'YTWAGYB', 'HPHPYWALPLP', 'HIJFIJFIPYDYBPPHPYWAG', 'HYHPHPHPNHYWT', 'YTAGJQ', 'HP', 'HYUWAGJIJIGIJGYDWPAIJFIJFIP', 'YUYWYT', 'PGYIJFGIJ', 'PYTAQOIJIJIPOPJIPYQOP']]
#
#
# Recording Date: 2024-09-26 00:00:00
# 1xN cell array of mapped syllable orders for the day:
# [['YBTAGYWAPLPLPLPYYZCDTAGY', 'HTPDWAY', 'YYDYDAZC', 'HPYT', 'YTABYWAGIJIY', 'YBUY', 'YTYB', 'YCYZ', 'YTAGJFIJFIFIPY', 'HYTAIGIAIJIJIJGU', 'YBYPHPHPHPHY', 'YT', 'ZTCD', 'HPHPHPYWYBPU', 'HNHPYTDWAGY', 'HDYYBLPUZCYDAIJIJIGYT', 'YTAGIJIPYWYAGIJIJIJFIJIADTAGY', 'ZDYBYC', 'PTUYDYYAIJIJIJIP', 'YB', 'YBY', 'YB', 'HPZYTGIJIA', 'HNHPHPLPYTAI', 'HNHPYTIJIJIGYWYD', 'HQDWASPYAIPJIJIGY', 'ZUYCNH', 'HVHPOYTAGNYWDY', 'ZWACD', 'Y', 'HWAGY', 'HPHPYTY', 'HPOPYD', 'HNHPNHPYTYWYA', 'PWAIJIJFIJIYWYTOATAPIJIJIJIJIOJIGPPOPY', 'HPHPOPYDYTAG', 'HPOPYWY', 'DYT', 'TWDYGTPNHPHYWAAGY', 'YCYDYBVYZDY', 'HPHPYWYB', 'HA', 'YB', 'HVYAGYWYB', 'YTAGIJFG', 'HBY', 'YAGJIJIJIJUYDYT', 'YT', 'CTD', 'PHAGJFIJIYWYAGIPBYWAYGPIJIJIJIY', 'ZTYBCUGYD', 'ZTGYDWAYTCAIPYD', 'ZYTCD', 'HAGY', 'YBYWAG', 'HNHYPNHDWPYAGHJIP', 'HAFIJFIJIJIGYDYALPLPPNHPYDYT', 'HDYAPLYPLPIJIWAFIJIJIJIJIGPY', 'HPNHPYDAFIJIJIJIG', 'ZGPIJIJIJIGYTNHWYA', 'YDYT', 'ZYCTAGJIJIJID', 'HPYWYDYBUIJFIJFI', 'HPQOPUY', 'PIPYTYOP', 'PSP', 'PGJQPQYFITJAGJ', 'HYPWYHPHPYWAIFP', 'YAGIJI', 'PYWY', 'HPQOPOPOPYWYAI', 'ZTYUYCBD', 'HBY', 'YWAGYPOPYBYGTY', 'HPHPOPOYAG', 'HPYAG', 'HPHPUYDYA', 'HNHPYUYDY', 'U', 'OPBY', 'YTAGIJIJI', 'PAIJISY', 'HPYHPAIGA', 'Y', 'HLPLPLPLPYWYNHPOPOPYWYTA', 'HPQPYAIJI', 'HQOPPHYPTUYGIU', 'YIJIUWYBLPLPLPYWYWA', 'HQOPQOPQPOPOYUHPHPOPQPYP', 'HPGY', 'ZDTAGUC', 'Y', 'ZYBGTYCBYDDWAG', 'HCDYBYDWAZG', 'HWYAGNHPYBPLPLPLY', 'YWYAG', 'YB', 'HPWAYGFGJIJIGYDWATYQGPIJIYD', 'YDTBZC', 'PPYPWYTAGJIJIGOO', 'OWYOPPBY', 'HJIJIJPPYHPWYBHPHPPFJIGHNHPOPYBAGJIJI', 'YPNHPYUTH', 'HY', 'HTYY', 'YYHUPOPYWYAIGUUYWYTYHPHPHPOPYBVGVGU', 'HPHPYB', 'YWYB', 'PPAOPYO', 'HOPQOPYWAIGFGI', 'HPOPUYDY', 'PWYY', 'HPHPHPYT']]
#
#
# Recording Date: 2024-09-27 00:00:00
# 1xN cell array of mapped syllable orders for the day:
# [['TGA', 'ZUYTCAGYDB', 'ZYDTAYVYWYTACGYPHP', 'HPQPYWYA', 'HJIHPPYWYWANHGNFJHIJIPYWYTLPINHPYAPIJI', 'ZTCAIJIJIPDYDT', 'VCDWTYPHPHUYZ', 'HPHNHPQOPYDYB', 'HWYAIJIGYGBLPLPYDYAGYTGY', 'YTA', 'HJIJIJIYWYPAQFGIJGJIOJIPPYWYBLPLPLPLPJIJI', 'HPWALPLPLPQYOPWYYWYNAHPIJIPIPNHY', 'PVOPPYDYYHTOAQDOYIGPIJIJIG', 'HPOPOQOPOPOUYWY', 'YB', 'HNHPNHPYTDY', 'HOPQOPOYTB', 'HOPYDYOTAP', 'HBTAVYPYWY', 'YIJIJIGPYTAIJIJIPUYA', 'YHPUYTYBVNGHP', 'HNHHPOUYTUYN', 'OY', 'YTDYA', 'YVYDWATGBVYWA', 'ZTACGD', 'ZYTDC', 'NNHHY', 'YYDWYAGWYATYWAGPIFIFIJIFP', 'YB', 'UYTUYBVOU', 'ZTBCYADGH', 'Y', 'YTD', 'HNHPYTAGPJIJI', 'HBWAGYUYWY', 'YAGIFIJIJIJIJIJIP', 'YTAGP', 'HY', 'HNHPYWYTY', 'C', 'POWAPGUIJIJFIJFIY']]
#
#
# Recording Date: 2024-10-01 00:00:00
# 1xN cell array of mapped syllable orders for the day:
# [['HNHPHPHPYCDY', 'YT', 'U', 'HGIFIJIJIYWAGIJIJIYWYIJIJIJIJIJIPHPUYTWA', 'HIJIJIGYBVJIJIPHPYTA', 'YHNHPHPYZ', 'HYZCDTYG', 'HPIGPYWPNAHGPIJIJIJIYHWPATHYPGJFIJFIJFIJIPYYTBY', 'TIUHPHYDYAYG', 'YDCYTDBVTYUBZYPHPHY', 'HTHPQPYTPYP', 'ZDTYC', 'HOPYNHWYOPQP', 'YTDWY', 'ZTCD', 'YAGYWDYBBYT', 'HPHPNPYZCDTY', 'HYTAGPYTAWY', 'ZTYBCPHPHPDYWYA', 'Y', 'ZTYCBYGD', 'Y', 'HPLPLPLPIJIJIYWYWAYHPPAHWDPTYB', 'HPYWD', 'YVGDYWYWYAIJIJIJIGYTAGZYB', 'YBYU', 'YAGYWD', 'HU', 'ZTYD', 'HGNYHPNBHVYAGIJIJIJFGJGJSPHPYTA', 'OAOPPBQPYLPLPLPYPY', 'YGYGYWYDTA', 'HAGIJIJIYJGPYWALPLPLPYTABQPQNYHWOPY', 'HNHNHPNHPHPHYU', 'YDYT', 'YYPHPHPHPHYT', 'HYUYWYP', 'YIJIPYWYATYPHPHPYDYAG', 'HJIJIJIHGVYPNHWYNHPHPYPDYHAPI', 'YAFIJIJFIJIJIJITYHPHPHPY', 'YTYBUD', 'YTY', 'YB', 'YGBVYWYA', 'ZTCD', 'H', 'ZTYCD', 'CYTBYD', 'ZWTYBCVPHPDY', 'HPFIQJIJIJIJIOJIPJIYGJIJIJIPYWA', 'HGJPQOPYAWYTY', 'PAY', 'YFIFIJPJPJPIFIJIPYUYTWYHPYAIJFI', 'ZDTYC', 'YTPY', 'YHYHV', 'YAGPQOPOPYBPHP', 'YFIJYBVYWTYG', 'DAT', 'YYWABYDTAG', 'ZAWYBTLPLPYNHCPHPHPHPYD', 'HYWYPYDYAGJIJIJIJIP', 'HAWYYTB', 'HPHPYTAWY', 'YWTYBPMLPLPLPLPIJIJIJIYWYBLPLPLPIBVYDYDYDYA', 'YB', 'UCDATZAGYDY', 'NHPWAQPIAIFIFIPIYBLPLPLPLPMLEPY', 'HPQPOPQOPIJIYWYBLPU', 'PY', 'HOPOPQOPYBVP', 'YIFIJIJFATYZCDYAG']]
#
#
# Recording Date: 2024-10-02 00:00:00
# 1xN cell array of mapped syllable orders for the day:
# [['ZAGTCHPHPYD']]
#
#
# Recording Date: 2024-10-03 00:00:00
# 1xN cell array of mapped syllable orders for the day:
# [['CTD', 'Y', 'HGIJIJIJIYWYAYPHPHPYWA', 'OQOWPAGY', 'HGPIJIJIJQIYOPPLPQLPLOPLPIPJFIJIOYBMLPLPLPQPYWA', 'Y', 'VPQOPYWYAWYBLPLPL', 'HQOPOYDYAO', 'PYDYAIJFIJIJIJIJIJPO', 'ZHNHYWTYBPLPLPYTAGYYUPHP', 'ZTCAWYD', 'HYWYAFIJFIJIJIJIYYWYBGFIJI', 'HOPOPOYWAOPGIJIJIJIPJP', 'HWYBVHGIPJIJFIJFIJFIPIYQOPOYWTYGIFIJFIPPY', 'HBZCDYBYPHPY', 'ZDTACGYWY', 'HPHPHPYTWY', 'HPHPHPLPLY', 'HGFGJFIJIJIJIPPIPNYHWYAYBIFIJIFIJIYWA', 'ZAGIJIJIJIATYCHPHPYDW', 'HGIJIJIPIPYAPNHGPIJIJPHYPWOPOYTWA', 'YB', 'Y', 'HQOPYWYQP', 'ZDYTACWYG', 'YAIJIJIJUYT', 'OWYAGIFIJIJIJIJGYUHYTPAJIYJFIJIJPY', 'HYAPYWQPD', 'HPOYAWYPQO', 'YB', 'PY', 'HJFIJIJIJIGPPHPHPOPOPYDTAIJFI', 'YDTZC', 'HTYY', 'Y', 'PWABPYIJIJIJIGY', 'HPQOPOPYWAU', 'HFIJIJIJINHJYWPDHPYWYTYG', 'YT', 'HLPYOPWYQPOPYWYAUYOPLPLPLP', 'HP', 'ZGYWTTAYCPHPYDA', 'CBTAGVYPHPDHPY', 'HAWTYGY', 'HPHPYWYB', 'ZAGIDJIJIYWYTYBYLPLPBPHPHPCLPLPLYW', 'ZTCD', 'YAGYYDTTYPHPHPYW', 'YBYPHPHPYWA', 'PIJIGYWATAYWAGIJ', 'PGYTYAIJIJIYWA', 'HPHPHPYWAUPHPHPQPYWYGPY', 'YIJIJIFIPYWYBTAWDYGIJ', 'YYYWDYNHAW', 'Y', 'HWYGIJIJFIJFIYWAIJIJIJIJIPQOPQOYDYTYA', 'PPYWYAIJIJFIJIFIJIYWYAIFIYJFIJFIJFIJIPYAWAUGIJFIJFIJIJFIJI', 'HPQPOPUYGY', 'HGIJIJIOJIJIJIPQOPNHOPOPYTA', 'HGJIJIJIJIJIFIJPIPHUYWTPHPVYBNV', 'HYLPLPLPIFIJIJRCYDYAWYB', 'HYDYB', 'ZCD', 'HPNHPHPYBYWY', 'ZIFIJIJIJIYWWYACIGYDWA', 'YZDTYPHPHPYC', 'ZYBCD', 'ZDYAWUYYG', 'HNHPYB', 'YDTWYAWY', 'U', 'HIJIPYOWPYQOPQOPOYBYDYG', 'PYWAOIGQOP', 'ZCD', 'OWPAOPYTY', 'PUY', 'HHYDYAWYN', 'YWYBGBGIJIJIJIYGYDYAT', 'HFIJIJIJIJYWYAYNYTAIAIFIJIJIJ', 'HHYAWN', 'HUYWAYPLPLPLPYTYWAIFIJFIJIJI', 'PPWYOPOY', 'HALPLPLPLPLPPYQOPOPOPYAYWY']]
#
#
# Recording Date: 2024-10-04 00:00:00
# 1xN cell array of mapped syllable orders for the day:
# [['HZCDTYAUGY', 'U', 'YBLPLPLPYDTZAGYC', 'HNHPHYBU', 'VPQPYT', 'YCUZ', 'PY', 'HPYWAPOPJFJFIJIQPQ', 'ZYTWHNHA', 'HLPLPLPLPLYWYYPHPHPYWYB', 'ZYZNHPHVPHPYD', 'HGIJIJIYPHPYTWY', 'HJIJIJIJIPYWAGPHPOPQOPYWAG', 'OBPPMLPYMLPB', 'VY', 'HPOPOYNHT', 'HYWAPNOHPOPYWYAIJIJIJIP', 'HPYWYAWY', 'ZYBYGPHPYD', 'ZTYBCYHUHUHD', 'HZCY', 'PYALPLPLPLPLOPYWYTPLPLPLPPWAIJFIJIJIPY', 'HAPLPLPHLPPYWAYTDWAGIY', 'HYBV', 'HBHPYPYPWAHPGYYWAGWTVUY', 'UPQPYYZ', 'YGPYWDYHTLPLPLPLPIJIJIJIYWYYZCYWYTA', 'PAIJIJIGY', 'U', 'YCDTYBZ', 'ZDTCAWAGY', 'PYT', 'YDYWAGJIHJINHJIJIPQPYWAZY', 'HPYBPOPQOP', 'OIGDTYOPAWYAP', 'HFIJIJIJIJIJQPQPYWNYNHHNHPOPOPQOPYTYG', 'YDYTWA', 'CTD', 'YAWYBYPHPHPNHY', 'HWAIJIJIJIJPIAHPHPYWAGY', 'Y', 'HWYGIJIPQPYWAPNLPHLPLPLPYPWYYDYTA', 'HYWYIGIPQOPOYBVG', 'HLPLPLPQYPOPWDYWATYPWAOP', 'Y', 'Y', 'YZCYTAWT', 'HPYWAG', 'YTWYGIJIJIJU', 'HPOPYWAY', 'YBVGIJIJIPYAHPY', 'HGIJIJIPYWYPHPYDYWA', 'HJIPPQPOPOPOYWAIJIJI', 'YAIJIJFIJFIJIJIPYWAIFIJFIJFIJIJIJFIBVHPHPYW', 'HPHPYWPAGFIJFIJFIJUYYTYBV', 'YDY', 'YWYTY', 'HPHPOPOPY', 'YCYZ', 'YNHPYUYBH', 'Y', 'HAPYWDYYBVYWPH', 'PWYBLPLPLPIUWYTLPLPLPLPYY', 'YAWY', 'Y', 'YB', 'HNPHPHYWA', 'HQPHYWYBNUP', 'HHOQOPUYWADYN', 'HP', 'HQWOPHOYATWNAOY', 'HYDWYP', 'YT', 'YHNHPHPYUYZWYWY', 'YAYCWYDTHNHYZW', 'HDNTYBNHHPHYZCDWAWY', 'HNHPHPYTAWA', 'HBPNPHPNHPYWANWYH', 'U', 'YWTAWYG', 'ZGYPOYWHANHWY', 'HNHHPYTN', 'HCY', 'YDT', 'HOPUY', 'ZDTYYBC', 'HPHPNYHWYPH', 'YBYWA', 'YTD', 'ZDTCWY', 'ZNWHYAWTYTHYNH', 'YDYAWAGJIJI', 'HOPQONPOUHPHNH', 'HHNBVOY', 'HPHPHPLYWAWY', 'HYHPHPHPYWYANW', 'HPLPUYPHPHPOPYWYBLPL', 'HOPYNBHPNHP', 'HTAWYAJFIJIUPHPUYWAY', 'U', 'OPOYWPYQAOWPDQO', 'HPNHHPQOPOYWYANH', 'HPNHPNHOQOPOYWAWYB', 'ZC', 'YWYAWY', 'HPOPOPOPOPY', 'HQOP', 'HOQOPQOPOPYBPLPLPLPLPYW', 'HYWA', 'HY', 'ZPHPYWAWTCAGYBD']]
#
#
# Recording Date: 2024-10-05 00:00:00
# 1xN cell array of mapped syllable orders for the day:
# [['HPHPYB', 'YAWYVGJIJFIJIPYWYBLPLPLPLPLPYWYAWYBLPLPLPLPLPYW', 'YIJIPCYWALPLPLPYDBLPLPLPLPYWYYBPLPLPLPLPYWYAWAGJFGJGTJFGJFIJIAWZYVP', 'HJIJIYYWYBLPLPLPYWALPLPLPYWAIJIJIJFIJGYWYATYTAWNHAPIJI', 'YB', 'HWAWYPOBPLPLPLPLPYBLPLPLPLPY', 'PJIPYWYOPDTYUYBGJI', 'HAGIJIJIJIPYBWTYCDWYUGYYWY', 'YDYAWY', 'HNHPHPOPYWYA', 'ZWYDWTACIJIJIGY', 'HWYTBLPLPLPYPHPYHPYWA', 'YJIJITGYWYAPYWYHPHPYWA', 'Y', 'HPYTAF', 'HYTPHPHPYZCYPHPHPHP', 'HYDTAWY', 'YWYTBVCYWYGJGJFGJFGJQPDYWTYYAGYZ', 'HJIJIJIJFIPYWYTYAWYYG', 'HPOYPYWYZCDTYBPLPLPLPLPY', 'HALPLPLPLPLPYPUYPHPYBLPLPLPYYWYBPLPLPLPLPYWYDTLPLPLPLPLPYW', 'YAIFIJFIJIJFIJFIJIJIYDYZTUPOPQOPYCW', 'HUZCPQOP', 'VHPHPYOU', 'YPOPYTH', 'HPHPQOPQOPOPOPYWAJIJIY', 'HOPPYQOPWAYBNYWAHPIJIJIJIG', 'ZAWDAFIJIJIJPYTHCYWY', 'PYHPTHYUP', 'ZPHPHYDWTAWAWLPLPLPYWAGCYZYB', 'POPTAFIJIJIJIY', 'ZIJIJIGYDWAPLPLPLPYPWOPYYTCA', 'YIJIJIJIJIJYHWYPYWT', 'ZYBDLPLPLPYWYAIJIJITJIJIJIPQPQPIJIGYCBYPYT', 'CTD', 'ZLPYWAGIJIJGIGIJIPTYCWAWYBPLPLPLPYHPHPHPYDB', 'HYNBHPPLPLPLPIQIPHYPWYTYAJAJAIJIJIJIGYWYAZGJGIJICDYWAW', 'Y', 'HHZHPHYDYNY', 'HPOYAWYPVH', 'YWYHPYBLPLPLPY', 'HBLPLPLPPLPYDHTJIJFIJFIJIJYWOAPOYVYNWY', 'PLPLPLPLPYWYTYYPIJIJIJIAWUYTUHYB', 'CYYTYPHPHPYDB', 'YYWYALPLPDYWYBPLPLPLPTYYWAG', 'HPYHBLPPLPLPLPLPFIJIHPJIY', 'UJIJIPYWAWYBPLPLPLPYWATIJFIPAYWYG', 'HWPAIJFIJFIJIJIPYUWYYDYBHPHPY', 'YWYBPUBVYWA', 'HAHWTYBVNHNHYNWY', 'HYGIJIJIJIYWTLNHPQOPQOPQOPOYAW', 'HGIJIJIPYWYNGHIPJIJIJIYWHYAPQOPOYAWA', 'HHAHIJIJIJPIJIJIJFIJIHNJIUHNHOPONPYNTHWP', 'YCDTUZ', 'CYWYAGIJIJYWYBHNHPYBTV', 'U', 'YCUZ', 'ZYCD', 'HHNHPOPYY', 'ZDLPLPYWYALPLPLTPLPYYCGYZYWTB', 'CGYDYGTIJIJIJPYBAWYHPYDWA', 'HPBHPHPHPY', 'HYBPHP', 'ZVYWAGTCHPHPYBD', 'HWAIZJIJIJIJIFIJIYWACGJFIJIJIPYWDAGJIJIATYBYVY', 'ZWYTHNHCPNHPYDA', 'PWYGIJPYDYPAQWPLPLPLPLPYIJIJIJIYHWA', 'HYPGHPHP', 'ZDCC', 'ZDWTYBCV', 'HYAWTZCYDYDYBVYYW', 'ZDC', 'ZYTCD', 'YGYAYWYBVYZCYWA', 'HZCDYTY', 'HY', 'PPYWAUZVYZCWYYGJGIJIJIJ', 'YCWTYBPLPLPDIJIJIJIJIYWYGIJIJIJIJIPYIJIJIJIYWAPLPLPLPYWYAPLPLPLPYTWAIJIZHYWA', 'HNVYZCDYBVY', 'HJIJIJIJIPQPYWUQPNHOPOPYWAFI', 'ZDTAC', 'YYWAZC', 'HQPOPYBP', 'HPHPYZCT', 'HNVGIJIYJIJIYHWAAWYPHPB', 'ZDTC', 'YACWTYDYBZVYW', 'PWQAOPY', 'ZBDVYWAWTAGIJFIHNHPCYVY', 'CYBDHNHPHPY', 'YYBCLPLPLPYYBVYZWA', 'HLPLPLPLPYWPYAIJFIJIJGIJIJIYWYTW', 'HYWAIJIJIJIJISYZCTAWA', 'HOPYPOP', 'HHPYP', 'HPLPLPLPPQPOPNHQOPYTYB', 'YWYAWYWAIJIJIJFIPY', 'YVYWA', 'HPAIJIJIJIQOPOQOPYWLPLPLPY', 'CTHPHPHPDYNHY', 'Y', 'YBCVHPHPYDWAWTYTZYPHPHPY', 'ZTCD', 'ZDYTC', 'PYTLPLPLPLPYWYBLPLPLPYBVQPOYPWYO', 'HQPOPOYTPAWLPMLPLPLU', 'AYT', 'Y', 'YTYGJIJIJIJIJA', 'YCZ', 'HJIJIPYWAIJIJINPJIGYPWYYHTHPHP', 'HWAIJIJIJIGPOPQOPQYTYD', 'HWLPLPLPLPYWALPLPLPLPYHWYDWAINJINJIJIUYY', 'YCYBZV', 'HZCPHPYBVY', 'HLPMLPLPLPIJIFIJIPYWYAIJIJIJIJIJFIJIJIJIPPYHPWALPLPLPLPYWOPYAW', 'HUYBPVG', 'HPYHWAIJIGPUPYNTH', 'YACDTAGUYZW', 'HWYNUYHBVY', 'ZDTYC', 'YTYBPLP', 'ZDTC', 'ZJIADTACWAIGJI', 'HNPHHPYWAWY', 'ZPDLPYWAIJIJIGYTCHPHPHPYB', 'HIYHPWYAIJIWAYPNHGP', 'HHPHPYWAWYP', 'H', 'HJIYWAIJIJIJIJINHPOPQOPOYVGIPIJIFI', 'YTY', 'CTD', 'HAFICPYWADYTAGZYUW', 'YWYBHYWA', 'YTACDYBZHYW', 'POPGQPY', 'PIJIJIJIGYOWAIJIAPBQVPYYWA', 'HPYAWYA', 'HNHNHPOPQPY', 'HWPAHIJIPJIFIJIJIJIJIYBVPY', 'PPWYOGPQPYO', 'YCUHPYZ', 'YACWDWAZGY', 'ZWAGYWYTYCBVYD', 'HPHPYZCT', 'HPGYDHYAWTYBNV', 'ZDVYWAGTCHPHPHPYB', 'ZGDYWCYBTHPNHPYWA', 'ZTCD', 'ZVYWAGTFIJIJIYWAHCPHPYDB', 'CTAWD', 'YIJIJIJIPYWWTAWAGYWZA', 'CTYBVYZCD', 'HPHPYWA', 'HN', 'HLPLPLPLPLPYWAPNHPQOPYWYB', 'HPOPUYWY', 'HNHOPQOPQOPQOPOUYA', 'YCDTYZWU', 'HHPYTN', 'HZYCDYYAIJPIJIJIJP', 'ZY', 'HQPOPQOPNYHWYPUPIJIJIJIJIQ', 'HYWPLPLPLPOLPPYQOAPIJFIQJFIOJFIJIJUYPYBPLPLP', 'HGYWYBDZPYWYAGTFIJIJIJIPYWYBAYWAC', 'ZIJIDJIJIJIYWATCHNHPHPYWA', 'HLNPLPJIHJIYWPLPLPLPUPYTAWLP', 'YAGDZTHPHPHPYCW', 'YDYBZC', 'HPQOPQOPOYWAY', 'PGYBVYWUA', 'H', 'HPQOPYBLPLU', 'HOPQHOPQOPYWYPN', 'ZHYWAIJIJIJICJIJIYWA', 'YTAWY', 'PYOPQOPO', 'HPQUPQOPO', 'HIJIJIJIJIJIYAOPQOPQOPOYWTA', 'UYU', 'HWHYOPQOPOYWAIJIFINJFIJIFIJY', 'Y', 'CTAD', 'YWYZBC', 'HDYPYZCWAWY', 'HWTYBUZCDWAPGHYY', 'HWAIJIJIJIJIJIPHYWYPYWAIJIJIJIJIYN', 'YDTZYWAC', 'ZCGYTHPHPYDWA', 'PYBPLPLPLPLPYWATYWBVYYWT', 'YGYWTYBHPYWA', 'HWAIJFIJIFIJIPYWZ ...
#
#
# Recording Date: 2024-10-06 00:00:00
# 1xN cell array of mapped syllable orders for the day:
# [['HGYWYDYWA', 'HBLPLPLPLPLPYPWYBLPLPLPLPYNHPYTAWY', 'HGIJIJIJIYDYHBLPLPLPLPYYWATYBLPLPLPLPLPYWYPHPYNWA', 'YTYZC', 'YYWYCBPYWAIJFGJAIJIJIPYDWYGJIJFIJIJIJIJIYWWDYBLPLPLPLPYBAVYIZJIJIJIPOPQPOPQOP', 'HYTALPLPNHPHPYDWYAW', 'ZAIJIJIJIPDYWYTYVGIJFIJIJIYWYTCHPYW', 'ZDLPLPLPYWYYCAWTB', 'HJIJIJIJIOPOPYWOYPBNLPLPLOPPYYHPTHAPGJI', 'OWOPOPOPYPBUY', 'YWYUHPHPYZCYWAIJIJIJIJIPYWDYTAGY', 'HIJIJFIJFIJIPYWYPHPYA', 'C', 'OWYWTYYAFIJIJIJIJIGIPY', 'PAWYLB', 'HJFIJIFIJIJIPYYWYGIJIJIJIJIPQOPYWYTAPWAQPIOPJIJI', 'HOPNOYHPUPQ', 'ZDTYC', 'YCZ', 'HJIJIGYNHPHPNYZCYAI', 'YTYG', 'HAWYQOPQOPYBPLPLPLPLPLPYHP', 'YWAICDYTPLPLPZLPY', 'PBVPZYWYCWPAYIJIJIYDYH', 'PBVOYYZC', 'PWAZYPCWAYGVYH', 'HYTLPYLPLPYZCYGIJIJIYW', 'HYWALPLPLPYP', 'Y', 'HAGVYWAGIFIJFIJIPHPHPYNHWYT', 'U', 'HYWPTYHP', 'HGIJIJIJFIJPYPWYOPYZYTA', 'YDYZTHC', 'HVPOPOPOPYWATY', 'HGYHPWYBYPLPLPLPYPYWYBLPLPLPYWYTATAAPNHIGJPIJIJI', 'CAGYWAGTYDYPHPHPYD', 'HWPANHPGIHJIGIJIJPIHYZCDWAGY', 'ZDGYTCHPHPYWA', 'PZHCDPTHYPHP', 'YTBV', 'PU', 'ZGYZCYBVTCHYPHPYDWA', 'AJIJIJIJIPGQPOPYWY', 'YTYW', 'HAIJIJIJIJIJIPYZPNHPHPYDYT', 'HPHPYWTPQOP', 'PQOPQPOPOPYPBHPH', 'YWYTDAWAGIJIJIJIPSPYZBVGYC', 'U', 'HNYHWAFIPJIJIJIQPHP', 'HOPYPNHWPALPLPLPHP', 'Y', 'PYYIGFIJIPIPQPYOWBLPLPLPYPWYTAPLPLPLPLPYJIJIJIJIJIGOPYW', 'YBHY', 'ZDTACGYWA', 'HHPYAWPAIJIJI', 'HPANQJOFIJIPHYGPIJIJIYWO', 'CATNHYPHDPYW', 'YGBVYWA', 'YBV', 'Y', 'HYYGIJIJIJIYWALPLPLPYWYWAGYD', 'HWLMLPLPYBLPLPPLPIJIFIJIJIYWYAQOPPLPLPLPUYQOWPYOYTYA', 'PWTYAGY', 'HZPNHPY', 'HYPWYQOP', 'YAWYTHNHPHPYT', 'HWAHPFIJFIJIJIJIGYBLPLPYP', 'ZYTAYGIJIJIJIJQPYWYPLPLPLPYWDYBPHLPLPPLPYHPYCWAW', 'CBTAGYPHPYD', 'HPYZYWYBLPYPH', 'HNWHYYWYGVYPWA', 'YVYZCDWYZ', 'HPHYWAN', 'ZDYVPCYB', 'YGYWAIJIJIJIJIGYWYPYTANHY', 'YCUZ', 'HPHPY', 'PY', 'CTD', 'ZTACHBD', 'U', 'ZDYWACJIJIJIJIJIP', 'HNYHPHPPYHWHAPIJFIJIFIJIJIGYWYNBV', 'HYLNPQOPHOPYNHWAPT', 'PYWAIJIJIJIJIWAYIJIJIJIJIP', 'PPYWYBLPLPYAIJIJIJIJIPYBLPLPLPYWYALPLPLPLPYQTOPAGIY', 'HJIJIJIPYOPWAQPLPLPLPLPLPYWYAGYJIJIJIJIJIJIPYWPLPLPLPLPPYWYTHYPWAIJIJIJI', 'HYWYAPOPYWLPLPLPLP', 'HOPOPYPOP', 'HNAGYHWPYHPYWAIGYW', 'YGBVYPHPY', 'ZDCTHYWA', 'Y', 'ZCUVYZCDYB', 'HPHPYDYBVY', 'YWA', 'PBVIJIYWAWTYGPYY', 'ZWAGDTYCBYPHPHPHPY', 'HIJIFIJIJIJIJIYDYTYGIFIJIJIJIJISZDTWAG', 'ZDTYWCA', 'ZPYZCNH', 'Y', 'YGYWY', 'HQOPYNHP', 'CTD', 'YB', 'PJFIJIPYBLPLPLPLPGYYWAI', 'HIJIJIGPOPYA', 'U', 'Y', 'ZYBVCPFIJIJIG', 'HPHPY', 'HPQPOPQOPOPYBV', 'ZDTC', 'HHYWLPLPLPQOPQPOPQPOPPYHNP', 'HYYWADTWYG', 'ZTC', 'HIJIJIJIJIYWAWYPHPHPYWA', 'HWYQGOIPJIJIJIJIYWNOAPIJIHQOPOYBPPY', 'HYWAHFIJIOPQOPOPQOPYNTPNAHVP', 'YYCNHPYBZPQPYW', 'U', 'HHOPYWLPLPLPLYPNHNP', 'HPQOPYWLPMLPL', 'HJFIGPYWAFIJFIJISPHPYTWYIJFI', 'PYBVYG', 'YCDYBVZ', 'HWANHIPJQPYHPHPOPYGVY', 'HWAHIFINJIHAPHPOPYBVYN', 'ZJYHTPOPOPYAWCIJUIJIJIJI', 'YCDYTHPZYA', 'HCNHDYBNZ', 'PIJIJIJIJIYWDYGOFIJFIJYPGYWYA', 'HYWPYYWAIJIJIJIJIP', 'U', 'CTNHPHPHPYBD', 'HBHPYWZACNYBVPYUY', 'PYB', 'YVDYZAWTYCB', 'HYPWHYPBPLPLPLPLPYYWYIGUWAGNHI', 'HNHPHPYB', 'ZDIJIPYWYBTLPLPLPLPYWYAIJIJIJIJIYPCGYWA', 'HPHPY', 'ZDYC', 'HIJIJIJIGHFIJFIJIJIJIYWNHYPHPOPOPYNWA', 'YYZCD', 'CTD', 'YGYWYABYPHPUYWA', 'ZTHCD', 'YAWYBLPLPLPYWTYTHNHY', 'YZ', 'QJIJIPZYWYBPLPLPYDYPAWYYGIJIJIJI', 'YZCDTU', 'UYDTYBZ', 'ZYCBD', 'HPHPYZC', 'CTD', 'YGDYBPHPYWA', 'Y', 'CTHYWDA', 'HZCDWY', 'AYWATYG', 'CTYD', 'ZTCD', 'YAGIFIJIJIJIYWALPLPLPLPYBWYHPHPYW', 'ZDTC', 'HHIJIJIJIJIJIPNYYWYBLPLPLPYNHCDYPNHWAN', 'HWYPAQHPIJRYVGNJRIJIJIY', 'ZLPLPLPYPIFIJIDGTHPHPYCWYB', 'HJIYPWLPMLPHLPLPPYWYPIFIJIJIJIYAIJIJIJIPPHIJI', 'CD', 'YWAGYWAIJIJIJIGBHPHPY', 'YB', 'PGWTYHPHPYWA', 'HPYNNHGPHNH', 'POPBWAYLP', 'HYNHPHPOPNYHAW', 'HYPWAHPYWYBPPLPLHPLP', 'HPYTA', 'OPOY', 'YWBTBVY', 'PAQOIPJIGOQOPOYPWQOAPIJIJIJIYQOWP', 'HPHPQOPOY', 'HHPHPOPQOPOYUYAWPY', 'ZCTHPHPHPYD', 'HIJIYWYHNHPHPYGYFIJ', 'YB', 'HYBYWAGYW', 'ZLPLPLPLPYWYTHYYWA', 'YBHPHPUYWYB', 'CTD', 'YBU', 'PYALPLPLPLPLPYWABPQHPPYWAT', 'YGIJIFIJIJIFIJIYWAFIJIJIUTHYA', 'HAIJIJIJLPLPLPLPYWYALPLPLPYIPYWYBWNBHLPLPLPPYWHYY', 'YB', 'HJIJIJIJIYWPHYBPPLPLPLPLPYYWYAGJGIGIJIJIPQPYWYPYDYAIJI', 'YB', 'HPYDYPNH', 'POPY']]
#
#
# Recording Date: 2024-10-07 00:00:00
# 1xN cell array of mapped syllable orders for the day:
# [['PJGJFIAYAG', 'HHPHPHNPY', 'HTALPPLPLPLPYHWPYBLPYLPLPYWYAY', 'HGJIGYHPBLPLPLPYWAJFIJIYGIGYDYAGPYWYALPLPLPLPUWAIJIJIPGFIJI', 'HBPLPQLPLPLPYOPTYYBLPLPLPLPLPYWYALPLPLPYWY', 'ZHPHPYCUY', 'YPQPYWLPLPLPLPYBPLPLPYWAITJIJIGPYWYBWLHPHPHJIJFIJFI', 'YWYBPLPLPLPYWYAIJIJFIJIJIYDTHY', 'YTAIJIJIYTYBLPLPLPYWY', 'HLPLPNLYWYAOPGFJFJQFIJFIJOIYHPQOPOYWYBLPLPLP', 'YW', 'HNHPHPQOPQYT', 'PPHPLPLPYWYAIJIJIJFIJIFIGYPQOPYWYAYB', 'HIJIJFIFIJFYWLPIJIYDYBLPLPLYPYWYAIJIJQYWYTA', 'HWHYOPOPYNWAIGIFIJIJPGIY', 'NOYUYDWYWYVGNJFIJIJFJFOPOPYWYHPHPHQOPYWHNHP', 'HNHPHPQOPQY', 'HIJFIJFIYTALPLPLPLPLPLYPHWPAIJIJRIJIJIFIPYGJIOPOPYWTYVG', 'HWYTAYYZCUYBPLPLPLPY', 'YWACGIJIYWDYTYBZLPLPY', 'ZWDY', 'GWATPAPIJIYJIFIJIY', 'HPQOPYHPHP', 'HPHPYHNHYWY', 'HWAIJIJIJIJIPYBPLPPLPLPHPOYTHY', 'HJIJINJIPQPYHPHWYPYDYAFIJIJIJIJI', 'HLPLPLPLPYWALPLPLPLPYWPYHPYWYB', 'HWYYBPY', 'HQPOPNYHTPNHP', 'PLPLPHLPYUAYYNZHCUYNHZYB', 'YT', 'YGPYWAIBPYDYA', 'HIFIPYHPYNWA', 'HNHHPYNBVYZ', 'ZIGIJGNIJIJIHPYCYZYDYNTH', 'HHNTY', 'HYDYTAPJFIJIFIJIJQIGP', 'HHPNYHBNHP', 'HPHPYPH', 'PAWLPLPLPLPLPLPYWYBAIJFJFGJIJIJIGVGIJIJOPYY', 'HLPYWBYLPLPLPYWAGJIJIZJIGPOPIJGYWUYWALPLPLP', 'PWYBLPLPLPLYTYYGIJIJIJIY', 'HPLPLPYWYAPLPLPLPYTYBLPLPLPYWYPPHPQNPYDYBHPH', 'HLPLPYNHPZCHDYPTBYLP', 'YAGJGJGPYBLPLPYW', 'JJYIIJI', 'YB', 'HPYZYWT', 'HYZCDYBPHPY', 'HY', 'HGIFIJFIGYYBLPLPLPLPYWYAGIGIGJGJIJIPYWADYTWA', 'HPHPY', 'YATYBPLPLPLPDLPYWYYBLPLPLPLPYW', 'ZYC', 'YUYZ', 'HHYPHPHNPYWYBLPLP', 'HNHPHPYB', 'HU', 'ZBYPHIPYWAWYBCLPLPLPLPYWYBLPLPLPIPYWWYBLPLPLPLPYWYAGDY', 'YTHY', 'ZHBUHPYHPYWATYBZCDCTBLPMLPLPIY', 'YACYDBLPLPLPLPLPLPYWYAYWYBLPLPLPLPLPYW', 'HZCYWYAY', 'YLPLPLPLPYWAGJIJIJIPBYWALPLPLPIJIJIJIGYWYLPLPLPLPYWYB', 'HPNH', 'U', 'YBPLPLPLPYGYWTY', 'YWTAIP', 'PBLPLPLPLPY', 'PYOPQ', 'YWTAWY', 'HLPLPLPLPMLPYWYAPHPYDTYB', 'HHPNHYWATPHP', 'PQVYWYAWQYYBLPLPLPLPYAWDYQOBPLPLPLPLPIQJIJOIPP', 'POPBY', 'YHUBVYWA', 'YC', 'PBY', 'PCYWYQBZLPU', 'HYWZYCDTYAWAIJIJIJIJI', 'YAWTY', 'PAGY', 'ZDTC', 'YATYBPHPYW', 'PYBPLPU', 'ZDAGTYBVYCW', 'YBVYWA', 'YGIJIJIYWAPBYPUWPYA', 'VWYYBWAIJIY', 'PYDTAIJIJIJIJPIYWAYWAGIP', 'HPOPOPYWYB', 'PY', 'ZDTC', 'ZDTCYB', 'YCDTYBZ', 'U', 'YCDTYBZ', 'HPLPUYNHWPAYLPLPLPLPYCDWATYB', 'PBLPLPLPLPLPLPYYWY', 'ZATUBPCJIJIJFGYYWY', 'YWYBLPLWPLPIYWYAZATYBLPLPLPYC', 'UCUYZ', 'PDTYBQPY']]
#
#
# Recording Date: 2024-10-08 00:00:00
# 1xN cell array of mapped syllable orders for the day:
# [['ZDTHC', 'ZDYPHPUC', 'YYBCLPLPLPLPYWADGJIJIJIJIYTYZAW', 'HYWYAIJIPYG', 'HWAIJFIJFIJIPPHYPTYYDTYBLPLPLPLPY', 'HYWYYBLPLPLPLPYAWYAJIJIJIP', 'HYNPWHT', 'ZGIJIJNHIJIYWYUPYBLPLPLPLPLPLYWAIJIJIJIPYBPLPLPLPHYPWYAYGJIJIJIJIGIJIPCTA', 'HJIJIJIYWATWYAIJIYJI', 'ZDWAIJIJIGYTWYBPLPLPLPLPYWYABPLYPLPYWYALPMLPLPLYWACFIJIJIJIBJILPMLPMLPY', 'YCYTYWZYD', 'HPLPLPLPYWTYPQOPYTYB', 'YYWYCDYTAHIZJIJIG', 'HHYNTNHYWPLUPIGIJIJIJIY', 'U', 'PWAY', 'HJIJIJIJIJYWYPOPQOPYTA', 'HIJHIJIJIYPBLPLPLOPYPWYAYIJIAWAGNIJIJIG', 'Y', 'YHPQOPYWHAGIJFIJIJIYBPPLPHLPLPYPOPOPOPOPQOPYWYBP', 'HWAHFIJIJIJIJIYWYPOPOYBNVY', 'HIPJIJIQPYWAQPOPGIJIJIYYWYTWYA', 'PYATHYUWY', 'HUYWYAIJIJIJIJIPYWPYHPYWYBLPLP', 'YTY', 'YCZ', 'HPLPLPLPLPYWAPQIJIJIOYPYTAL', 'YTAGFIJIJIJFIJY', 'HPHPQOPYWYNH', 'HLPLPLPLPYWYAFIJIJIJIJIPQOPYWYTLPHLPLPYDYYVGJIJIJIJIZCYWZTYCB', 'YTWA', 'HAYJGIJIJIJI', 'YCZ', 'POVPOYOPTOPY', 'POWPAIJYIJIGYWALPLPLPYTWLPLPLPLPYQ', 'HWLPLPLPLPIJFIJYDYUNHPHPQOPQOPYA', 'HPQPY', 'HLPLPLPYWYVPFIJIYDPTYBLQPLPPLPLPLPYWOAPIFIJIJOIJIGPPYTYB', 'Y', 'YLPYCUPNHYZCYZBLPLPLPLP', 'ZGYIJIJIYWYHCYA', 'HNH', 'HGIJFIJIJIGPVYYWALPLPLPLPUYWYPHNPHPYWTHY', 'YCDTZ', 'HJIJIGAYCYWAGI', 'HWYALPLPLPLPYBLPLPLPLPIAGIJIJIJIY', 'ZWADGTYGCIJIJIPIY', 'ZWDATCHY', 'HVYAIJIGIJIJIJIYWAPLYPLPLPYDTYVYB', 'ZIFIYDWAUTYCBYGFIG', 'HAIJIJIJIJIPHPYW', 'HYC', 'ZJIJIJIJIPDYTWLPLPLPLPLPYBLPLYPCTAGJI', 'OQBOPLPLPLPPLPLPLPLPLPYLPY', 'PCDWLPLPY', 'HWALPLPLPLPLPYBVPGIJIY', 'OIFIJFIJFIJPYYDWYOPTPYWOPA', 'PYWYAIJIJIJIJIY', 'OPLPLPLPYWAIJIJIYBOLPPLPNHPYPWYYBLPLPL', 'ZVDYWAGTYCHYB', 'HJIJIGYZCDTAGJI', 'HPHPHPYWA', 'PYTAWY', 'ZDCTHUY', 'YBVY', 'HWAYPLPLPLPYTALPLPLPLYPYDYNHTPBHVPY', 'ZDTYBVCYHP', 'HIJIJIJIHJYWYPHPHPYWNA', 'HJIJIJIVPYALPYLPLPLPWPAQPGIJIJI', 'HPLPLPLHPYPWTAIYWYYWTPYHPBLPL', 'HIJIJIJIJIJIJINHPQPYWTYWA', 'ZDTC', 'YTYCBPYWDYAGRYFIJIJIYWBBVZYW', 'HWAGYYBYPY', 'HYTAPLPUY', 'PWYVYWYBHPPLPLPLPLPLPLPLY', 'H', 'OCPIY', 'ZDC', 'HWYTYAPLPLPLPYWAZIJIJIJIJIJIJIJIGYCDYBVPY', 'PTY', 'ZDTCUY', 'HY', 'YHWAIJIJIJIJFIJIPHPYBVNY', 'ZAIJIJGYBTPLPLPLPYACHYDW', 'HPPIYBPLPLPYYPWHNAPTYGIHH', 'HPHPY', 'YHPQWLPOLPPLPLPLPYWLPLPLPLPLHPYQ', 'YWLPLPLPLPLPYBBPLPLPLPLPY', 'HIJIJIPYWAIJ', 'HIJINJIJIHPPYWHYPGIJIJIUOPOPOYWA', 'HIJIJIGPYWYGIJIYWAPHPOPQOPYWA', 'ZDBVYTTABCVY', 'ZCTD', 'ZWAGTYWYTFGCHYVYZDY', 'YWDYAGYABPLPLPLPYWYBPLPLPLPYWBAVY', 'YBVYWA', 'HPHPHPYZCDYWA', 'AIJIJIJIYWY', 'TYHB', 'PY', 'ABIJIJIJIGY', 'PY', 'HPHPYT', 'HPHPYWA', 'PYW', 'APLPLPLPLPYJIJIJIPQPYDYAILPL', 'VYB', 'YWYT', 'HPYPWHPLPLPLPPLPLYOPYDYALPLPLPL', 'PWAYFIJIJIJIPYAIJITYWLPLPLPLPLPLPY', 'POPOPYTWAQ', 'CTHPHPYD', 'AIJIJIGYDYA', 'PAIJIJIJIJIYDYBYVYW', 'HJIJIJIPYNWHAI', 'HHPHPYWYNHBP', 'HYDYBV', 'ZDTYC', 'HYGYYWHAPLPLPLPYDYGYPHWNP', 'HAGNHPHPYWT', 'HWHDYPGJGIJIAQPYNWANH', 'HGIJFIJIYDPYQGPYZCDYWA', 'HIPNHPHPOYWA', 'HPNPHPOPYT', 'HIPHPHPYWA', 'YBVY', 'HPHPYBVY', 'HY', 'PUDWTYYBP', 'HPYWTHY', 'HWAPHPHPQOPYBVY', 'YBVPY', 'HPOPYDUY', 'HPIJIJIJIHJIJIPPYHPAIGHPFGYTA', 'ZVGTYWAIJFIJIJIGYHYDCB', 'CTD', 'ZIJIPYWALPLPLTPYWYBPLPLPLPLPYWYALPLPLPLPLPYWYBLPLPHCPHPYWDA', 'HPLPLPYNHYDTAWAL', 'HYPHP', 'QBPPLPLPLPUYQWOPAQIOOPJIY', 'Y', 'HDWYTAY', 'PDYBQPY', 'HOPYWPHP', 'PYWYYTWAIJIP', 'YJIJIJIYWYWTAIJIJIJI', 'HOPQOPYPOP', 'YCDTZ', 'ZWADTCHPHPY', 'HPWAHYGIJIJIJIJINBHNPNPHY', 'HHPYWYBPLP', 'HHPYWAPI', 'PWYYAIJIYWYBPLPLPLPLPYWBVGY', 'YDY', 'HPHHPYNPH', 'HPNH', 'HLPLPLPLPQOPOPQPNYWPAIJIJIJIPHYWYBPLP', 'Y', 'HPHPOPQOPY', 'HLPLPYWYPQPOPYDYWLPLP', 'HWLPMLPLPLPIJIHOPQOPQPYTAN', 'YCZ', 'ZDCTHPHPHPY', 'YCDTYZWA', 'YWYCDWAGYZ', 'HYWYPBHP', 'YCUZ', 'YCYDYTWZ', 'YWADIJIJFIJIJIJIGYAIJIJFIJFIPOPOPOPY', 'HWAPHPHPOPYVY', 'HZUCDYY', 'ZDCC', 'HHPYBNHNHP', 'YFIFGIYWYBPEPHPYWA', 'HPYBLPLPLPYPH', 'YDTAWY', 'U', 'HPLPLPLPYHWYYWAWNYB', 'YZC', 'H', 'HPHPHYWY', 'YCWYWZT', 'HWAGJIJIJIJIPJIHJIYWPAYWYGJIJIJIJIY', 'ZDTCAIJIJIY', 'YCDYTZH', 'YDTZC', 'HMLNPLPLHPYPYDTYBLPP', 'HPWHAPIJIJIHJIJIGPYWYYBVY', 'YCDTYWAIJI', 'HPOPOQOPOPOYB', 'YDTHYWY', 'YZC', 'HJIAOQOPOPYWAGRIJI']]
#
#
# Recording Date: 2024-10-10 00:00:00
# 1xN cell array of mapped syllable orders for the day:
# [['HPHPYB', 'ZLPLPLPLPYYIPGJUTYPCYWA', 'ZWYADWYBLPLPYYWYVYPIJGPYWYTYTBLPLPLPLYTALPLPLPYWYYALPLPLPIJIYWWYBLPLPLPLPYWYCULPLPLPLPLPY', 'YPYDYWAIJIJIJIJFIJIYWYTALPLPLPLPYBLPLPLPLPWTYGHY', 'ZPDYWAGJFGJGJFIJIGYWWYYCTAFIJFIJFIJIJI', 'YOPYBPYWYCDTZALPLPLPOP', 'HYWAIJIOPJIJIJIJIJIQPOYPWYQOBPLPLPYWAFIJIJIJIYJIGWAIJIJIJIJIG', 'HPLPYWPYAQPOPIJIJIJIJGYOPWYQOPQPOPQPOPYDYTWLPLPL', 'HAIPOPYWLPLPOPHYWYPYDYNWY', 'HIJIJIYWYAPLPLBYDYTA', 'YCDYTYUZ', 'YJIJIGPOPYAIJIJIPYWYUTYWAIJI', 'YPHPCQPYTBYDTWYAZIJIJIJIY', 'HPHPY', 'HHOPOPQOPYWN', 'YLPLPLPYNHWAIGJGYWYBYLPLPLPLPLPYWYDTYAOPIZJIJIUYW', 'PJIJIJIYWYBPLPLPLPYWYTYAI', 'HIJIJIGYPYWAIJIJIFIJIPJINJIJIJHIYPNHPOPQOPYTA', 'HHPYCN', 'YYDWAIJIJIJIPOPYW', 'HPOPYTVQ', 'HIJIJIJIJIOPOPOPQOPQYAIJIJIJIJIPOPYWPALPLOPLPPLPYPYDQYNHDYTA', 'HAIJIJIJIPYQPOPYNHTALPLPLPYPQOPQPOPOPYW', 'ZDYCTAY', 'HUYVPPHHIAUPOPOPYDYTWNY', 'HAIJIJFIJIJIGPOPYWALPLPLPYPYVYDY', 'HYBVYDYWAIJIGYDYWAIGPOPOPYWPHPYNHPHPYW', 'NPOPHQOPOPOYBVY', 'HYZCDYTYB', 'HNHPHPYZ', 'ZDYTC', 'HJFIJIPNHPOPYWYAIJIJI', 'ZYWADIJIGYTHYCUPHP', 'HYU', 'YDYTZYWAC', 'HYU', 'U', 'HYNH', 'HHPOPYTALPLPLPLPPLPY', 'ZDTYC', 'ZOPDYWYTYYTCAIJIJIG', 'HOPALPLPLPLPLPQLPPLOPYPWYYWALPLPLPPY', 'HDWALPLPPLPLPIFIJIJIJIYPYWYYTNWYVHY', 'HPPHYQPWAYTYALPLPLPL', 'QPOQTOPVOY', 'ZWYTDALPLPLPYPYPIJIJIJIGTYCBVY', 'YBVYZCYU', 'ZLPLYPLPLPLPYBCVYZCDYDA', 'POPYOPTQP', 'YWYBPLPLPLPYTALPLPLPLPLPYBVYPHPY', 'PPBLPLOPLPLPYLPLPOYWY', 'QWYPTYMLPLPLPOLPLPLPY', 'Y', 'YWALPLPLPLPYWYAPYBVGY', 'HJIVJIJIYYWTAGI', 'ZIJIJIYDWALPLPLPYBPLPLPLPLTPYWYBPLPLPLPYWYCYWAG', 'YGYDBPLPLPLPYWAIJITJIGPYZWAGFICJI', 'HCDZ', 'HYYWYVYBLPLPLPYPIFIJIJIJIJIGPYWYTWLPLPLPLP', 'HPQOPNHOPQPOPOPYBPLPLPMLPLPY', 'ZYYAOPIJIJIJIQPYWABTCAIJIJIJIP', 'HJIJHIPPIGHYPQOPTYTYTYTYHPYPNHWAPIJI', 'HPYPIYDYLPLNPOLPPLPLPUQOPHIYDYGIJIJIJIJIJIG', 'HPOPOPY', 'OYWYVPIYWOPTYGYIJIJIJIPP', 'HIJIJIJIYDYAJIJIJIPOPYPYWYG', 'HLPYPHWYAIJIJIJIPOPYWYYTYNBLPLPLPLP', 'HYZCDTY', 'HOPYDYPQOPYWAIFIJIJIP', 'YWYT', 'HYWYPYDYBV', 'HLPLPLPLPLPYWPAHLPPLPLPLPYYTWA', 'ZADIJIJIGYWAGIPYTBPLPLPLPYCWYBPLPLPLPYAGYW', 'HLPLPNLPYPHHPYDYTYWA', 'HHPHPYDYN', 'HNHPHOPOPYPHP', 'HPOPYWYBLPLPLPLPLPLPLY', 'H', 'HJIJIJIJIJIJIGPNPHYPWYOPQOPOPYWAI', 'HOP', 'PJIPPOPYOWYYWTOPAIJIJIJIJIJIO', 'HPLPLPQPIUYWYPHPOPYWNTHB', 'HNHPHPYZCY', 'HPIPIYWAU', 'HJIYWYPYWAIJIJIJIJI', 'HIFIJIJIYPHPHPOPOPYWVG', 'HP', 'NHIPYWYAPLPLPLPLPLPUPOPNYHWTYA', 'YAFIJICPOPDYVHNHUYUZDWT', 'HHPYWYNPH', 'CYD', 'ZDIGYBLPLPYTWYBPLPLPLPLPLPYWAGIGIGIJIJIYCHYWA', 'ZDTC', 'ZDYCBVY', 'HNHPHYWAPIJIU', 'HPIJIPHPYBYLPLPLPYWYAZIJFIJFIJIJIJIJYCYTWPAH', 'HIPYWYALPLPLPLPPYWA', 'HPZC', 'HP', 'HGIJIJIYWAIGYPWYBLPLPLPYYWVPY', 'HGIJIJIYWPLPMLPLPIJIYWAIJIQPPHPYAWY', 'HPOPQPVHIY', 'HYYAIJIJIJIJIJIJIGP', 'HYOPQPOPYWAIJIJIJIJIPJI', 'HIJIPQPYPBLPLPLPLPLPQPOPQOPOYWA', 'ZDWCA', 'AHYYWAIG', 'HHYPWAGJIJIJIYJIFIJIPYWYWAPFG', 'HIJIJIJIPNYHTYPQOPYWA', 'ZWYDGIJIJIJIYTCHYUPHPHPOPY', 'PYAIYTYWYALPLPLP', 'ZDYBCVY', 'HAIHJIJIJIJIJIJFIPYAWPYYDNYAW', 'HPYWAIJIJIJIJIJIJIY', 'ZDTHCYB', 'YG', 'ZDWYAWAGFGIWTCAGY', 'ZYWYBTLPLPLPLPCZYCWYYGYDWA', 'ZDYWYTAWTAPLPYYACWAIJIJIJIP', 'YTWYGY', 'ZWAYWCAIY', 'YWYGIJIJIJIPYWYWAIY', 'HIJIGYWAWPHPHPYWA', 'HPLPLPLPUPHPOPYWYB', 'PYLPLPLPLPYWAQPOPWYB', 'PY', 'HPHPHPUYWYGT', 'HPOYBPHNHP', 'HVPNPHHPOPOPYWYB', 'HWYIJIJIPOPQOPYWDTA', 'YWAIJIJIJIJIJ', 'HYGIJIJIJIJIPHYPOPOPYWANW', 'HPNIYWYHPYBLPLPLPLPLPO', 'YWDY', 'ZYC', 'HPQOPYWATY', 'YAGYWYBPLPLPLPLPLPYWYTBYBLPLPYVYW', 'YAIPYWYBPLPLPBGYW', 'YDYWDTYGPY', 'PDYHHWPAPY', 'HPQOPYTWA', 'HLPLPYWAIPJIFIJIYWYVOYWALPLPLP', 'HHWPYBHPYCYBVYP', 'HWAGYPIJIJIYNHPHPYVY', 'Y', 'YWAIJI', 'HQPOPOPYOP', 'HALPLPYLPLPPHYWYTNAW', 'YTAWLUBVYWY', 'YYZCWNHY', 'YCZ', 'HPOPOPYTWYUZ', 'HAYCIJIJIPYWYYABLPLPLPLPLYZPQPOPYW', 'HUNHPHPHPOPYBLPLPLPLPY', 'YCZ', 'HYNHWNHAH', 'HJIJIJINYHWPALPLEPLUYBPYPI', 'YBVDWATWY', 'YWYBGYWA', 'NHBPYDTYWA', 'HPHPYWYNBPLPLPLPHU', 'PWYA', 'HAIPPJIYWYWAI', 'HWAPYNBHVY', 'HIJIJIJIYYWYAPLPIGYWYBLPLPLPYWTPYHGP', 'HFIJIJFIJIUHPHPHPYNWA', 'H', 'HUYHPHBPVPYHPWAGIJIPYWNAI', 'HVYPHPHPYZCWYB', 'HZCDYWANHHY', 'PYATIJIPIJIJIYWYBOPBVOPYWY', 'HAIJIJIJIJIJIPYWYTPYAW', 'HGPHPYWNAHI', 'YYCYWYGPZIJIJIJIYW', 'YCYDYT ...
#
#
# Recording Date: 2024-10-11 00:00:00
# 1xN cell array of mapped syllable orders for the day:
# [['HYZCYB', 'ZDC', 'HPHP', 'YB', 'HHYNTY', 'HYAPIJIGYOPWDYQBPOPLPLPLPLPYYWAIJIJIJIFIJ', 'HPOPHYTYWNY', 'ZYWDAIJIPOPYYWABTCAG', 'HWYYWAIJIFIJIJIPY', 'HLPLPMLPLYWAIJIJIPHPYDTYB', 'YTYD', 'HPYWYPHPHPOPYWAI', 'HIJIJIJIGOPOPOPYWYBPLPLPLPYWPAHPIJIJIPYBOPYWA', 'HWYAIOPJIJIJIYOUVPYQDOWYPGJFIJOIJIPQPOPPYDTYYTY', 'HJIYBPLPLPLPLPYPYWYTPOPGQPOPOPOPYWAI', 'OTAPIJIJIJIJGPYWYABLPLPLPYDYTYWOAPIJIJIFIJFIJIYY', 'HYVYUYAW', 'HNIJIJIJIJIJIJIJIPYHTPHPYWA', 'HZWAICPYDYWAYIJIJIJIY', 'YWYTAGY', 'HWLPLPLPLPNLPHLPLYUYBPLPLPLPYPHPOPQPOPOPIJIJIYT', 'HYTYPGYW', 'HPJIJIJIYQOPWVYDYOPOPYTWAPLPLPOG', 'HJIJIJIJIYPHPHPYWAG', 'HOPOPYWYTPA', 'HPJFIJIJIYWYPQOPOPYWAIJIJIJIJIG', 'HYWAIJIJIJIJIGPYDYBV', 'POPY', 'HGPLPLPHLPLPPUHPYTWYP', 'HDYPTHYY', 'HY', 'HVYWYTWLPLPLPPLPYHPHPHYDYTYB', 'HAWLPLPLPLPYPHPHPYWYT', 'HPVYDYYAPPLPLPLPYYWAI', 'H', 'YBVYZCY', 'HPYU', 'HPOPYC', 'ZWAIGYDYTAGIJIFIJIGYWACYPHPHPYD', 'VGYDWYBPLPLPLPYWYCTWYAGYI', 'YZCCYTHPZY', 'HYWYP', 'ZDTYC', 'ZWADTCYPHPHPY', 'HYPZCDYHPBHPHY', 'HTYALPLPLPLPYWAPBVY', 'HJIYYPWYYWLPLPLPLPLPYJIJFIJFIJFIJI', 'HZHCDTYBNLPLPLPULPLPEPE', 'YCYZ', 'PTAWLPLPLPLPY', 'HDAYLPPLPYPYWYYBPLPLPLPLPLPYWYALPLPLPYWAIJIFIJIJIY', 'HWTHPYYWAPLPLPLPYN', 'YDYZC', 'YBVYZCYT', 'HDPTALPLPLPYUPOPGIJIJIJIJIPYWYYWYVY', 'HPHPOPYWAIJI', 'HPNQYOPWHYYWYAIJIJIJIPJI', 'U', 'PQPOPYTALPLPLPLPLPYP', 'HPOPY', 'HCYDYTNZB', 'ZDTYC', 'ZDTYC', 'ZDVYPHPYTCHYB', 'HYPWHYPHPYBVG', 'PFIGYWPLPLPLPLPQOPYWAYWAIGIG', 'YAGYWALPLPLPYDTYWYGJIFIJIPBVYW', 'YBPDYWAGIJGPYWAAYIGIGIZPYC', 'HJIJIYPYWAGI', 'ZGYDTCYWA', 'ZDTYC', 'HWPYBLPLPLPLPLPYYBVY', 'YWCDYTWALPLPLPY', 'HFGIJIJIJIJIJIPYWYPHPHPYWA', 'HPLPYAPJIJIJIJIYWYTYPOPYWALPLPL', 'HIJPYWYBPLPLPYPHPYWTYA', 'HYAHYNHPHPOYNWYT', 'HBVGYWPAPOPJIJIJIOPOPYWY', 'YYAWAGJIJIJIYWYBVYW', 'HHPHPYBNV', 'HU', 'HYBPLPLPLPLPYPHPNOPOYHWAW', 'ZDTC', 'ZDTCYWA', 'YWY', 'ZADGYWAWGACGYW', 'HWBPHPYWY', 'HLPLPLPLPYPHPYPYDYB', 'HPHPYPNH', 'HNHPUYDYTAP', 'ZWAGDIYWAYWTAGIFIJIJIJIYHCPHPY', 'YPYWAWYWAIG', 'HVPYWAIJIJIJIJIJIYNHPHPYWYB', 'HYPPQOPYHPUYBHPVYYWAIGIGIFIJIJIJIJIQPTWLPLPLPMLPMLP', 'HJIJIPYWDYHPHPHPYWANI', 'HJIJIPYWAGYWOPYOPYWTYIJI', 'HBVPLPPOPOPOYWTAY', 'HHPHPNOPQOPQOPOPYWYA', 'HHPLPLPYHP', 'HHNPHP', 'PPDWQOYPYO', 'HFIJIJIJIJIJIPQOPPIYOWPAIJIJIJIGYTA', 'ZDC', 'PYOPWTQPYOP', 'HPQPIJIJIYU', 'Y', 'ZDYTWCAY', 'HPTYHPYDYBVPYH', 'HP', 'ZDC', 'ZDYTYCBVY', 'HPYBPLPLPLPLPY', 'ZDTC', 'ZWYBVYWATGYHCPHPYD', 'HIJIJIJIJIYWYHYWTYPGHNJGPP', 'HIGIZYYWYBLPLPLCPLPYWYADLPLPLPLPIJIPYWYTTIJIJFIJIJIYWYYWA', 'HNHPHPHPOPYTY', 'YWAWYAGYBVY', 'HWYAGIJHIJIJIGPHPYNWA', 'HYPHPHPYWTYW', 'YYTAWYBPLPLPLPLPBVYW', 'ZWYDGYBWTALPLPLPLPYWYCBVY', 'HPOPYPO', 'HVNHPOPOPOPYWYB', 'POPYOPOPQ', 'HYWPQOPIJIJIJIJIPYWLPLPLPYPQPOPOPOYWA', 'HKHPHOPYBVN', 'ZYDBYPLPLPLPLPYTYCWYBLPLPLPLP', 'HHPOPOQOPOPOPOPYN', 'ZTYBCD', 'YTY', 'CCD', 'HYPYPNHBP', 'ZYBDVYWAGYTWAGIHPHPCYW', 'HJIJIPYWYPBPLPLPLPLPYPIJIJIYWAIJIJI', 'HYTYBDLPLPLPYTZYWACG', 'ZDWYCBVY', 'PPUWAYG', 'CTHPYD', 'ZDTC', 'ZDC', 'YWCAWDYBLPLPYPYWYYBVZY', 'HPNYUYPWYHYWAGFIJIJI', 'ZPDIJFIUYYTCHYZWYB', 'HYWYTWYP', 'ZDTCC', 'YYTAWYWYBPYW', 'YJIWAGI', 'CTD', 'ZDWAGYWYTGYCHPHPHPY', 'HPHPHPYZCDWAIJIJIJIP', 'ZYWADIJIJIYUTCHPGVY', 'YTAGFIJIJIPQBVYWY', 'ZYWYVYZCCWAULPMLPLPLP', 'HLPLPYVPIJIJIYGWTYPBLPLPLPLP', 'HUHPOPYWAINJIP', 'HGYDTYWAPHPHPYWA', 'YYCDYWYYWAZWYG', 'HPYWYPBHPLPPLPLPLPLPYWYALPLPLPYDYYBPLPLPLPL', 'ZDTYWACG', 'HQOPQOPYWYPYBPLPLPLPLP', 'QDTYWVYZC', 'YHLPLPLPLPYWYPHPYAWY', 'HOPNHQOPYP', 'ZDWYAIGJFIJIWAIJICYD', 'ZDBTCHPHPYPHPHPY', 'YAGYWAGIJGIGIJIGIJGFIGJIFIGIGJRGPBYAPLPLPYWYBPLPLPVVYW', 'ZAIDJIUTHPHPCHPYW', 'Y', 'ZDTYC', 'ZDTC', 'ZGYBTACWAD', 'YWYWATYBVY', 'HYPWAQP', 'ZDC']]
#
#
# Recording Date: 2024-10-12 00:00:00
# 1xN cell array of mapped syllable orders for the day:
# [['ZLPYDTYALPLPLPLPLPYTAWYWAGJFIJIPIPIPIPIYWDYBLPLPLPLPYCAWYB', 'HTYBPHPHPYWY', 'HAIJIPOPYNHPTHWPYBLPLPLPLPLPYWYTBUYTWY', 'YWTY', 'HPPYNWAHLPL', 'POWPYY', 'HPHPHPY', 'ZDCTY', 'HIGIJIJIPYWYDPHPYWA', 'HYCYDYDYWY', 'HWYWYPIGYPOPYNWALPLPLPLPYH', 'CDTHY', 'HPHPYB', 'YLPLPUYZWYCYTAWALP', 'HJIGYHWYGIPYPBOPOVPYWOPAPLPLPLPYYWAIJIJIJIPYDTYWALPLPYNAIJIYWWYAI', 'HYDAHLPLPLPYPHPYNWYT', 'ZDWYTCAIJIJIY', 'ZWDYYTCYPHPHPY', 'HYZBLPLPLPLPLPCYWAIJIGYYYWAPLPLPLPYW', 'HJIOPOPYWYYTYBLPLPNLHPLPYTWAPI', 'Y', 'ZWTDAGIGJFIJIJIFIPYYWAWYVPLPLPLPLPYDYWYTALPLPLPLPBYWYCVY', 'YC', 'HAPWOLPLPPLPYYWYBLPLPLPY', 'ZATYWDYBPLPLPLPYYDTAGIJIJPYWALPLPLPLPYBCVYW', 'HPHPHPYDTYWLP', 'YBPLPLPLPLPYYWAIJFIGYWYGIJIJIJIJIJIYWABLPLPLPZVYWCY', 'HGIJIYPWYOPTYLPLPLPYYTAWY', 'HQPOPOPOOPYTPYOPYBVYP', 'HY', 'ZTADGYTHCYDY', 'YAGIPYWAGYBVYDT', 'ZYDBPLPLPYWYBPLPTLPYYCWAG', 'YGIYWYBPLPLPLPYWYBLPWAYDTY', 'YTCPLPDYUWAGZY', 'H', 'ZDTHCY', 'YBVYPHP', 'ZWAIDJIJIGJPYWYYBVYCPHPHPHY', 'HWYOPYBLPLPLPLPYP', 'ZDTYC', 'UWYTYDWZAGIYC', 'YAIJFIJIJIPYWYBPLPLPLPUWYGVYDT', 'HYPHPYDWYT', 'PWYVGIJIJIJIPYYBPLPLPLPLYWYAGIJIJIY', 'HOPOPOPQOPOYDWY', 'HAWLPLPLPLPOYPWYOYBVPPY', 'PPYWTALPLPUYWAIG', 'YP', 'HTOYPVYYBPYD', 'HGFIJIJIJIJIPYWYHNHPHPYWNA', 'ZDTC', 'U', 'HPNHYWYT', 'HWQYOAPIJIPYIPJPQPYPAGIJOIJIJIYP', 'PYWY', 'PU', 'U', 'HWHYPHPYNWYTA', 'UWAWYOBPVYYGY', 'HPLPYHPWYAFGJGIGIJIJGIPYBLPLPLPLPLPLPYPIJIYVDTYPBHLPPLPLPLPL', 'VTYY', 'HOPP', 'HHPWALPLPLPLPYIJIGPQPOPYYWYTDYBVYP', 'P', 'YTYGYDY', 'PVYYUZCY', 'HYWAPIJIJIJIJIYYWDTYG', 'YZ', 'HGHPUYTAP', 'HPYCYPNH', 'Y', 'HQOPOPYWOYAPWOYP', 'HIJIGPP', 'YWYTYWAGBYVYPHPHPY', 'HHGPIJIJIYYHPYPNHWPA', 'ZDYGCY', 'Y', 'HPOPOPYWAFIFIJIP', 'Q', 'ZTCHD', 'YDWAWTYCVZ', 'YCZ', 'PYBVY', 'HPQPOPYWAHY', 'HYHPDNYAWYHYWYPHGP', 'YLPLPLPLPCYBLPLPLPLPLPDYTWYUZA', 'HJIPPYUOYWAI', 'HPYWY', 'CWAGYTWAWYGIJIYWALPLPLPYYBDVY', 'YWYWAIGTWAGY', 'YUYDTYWYB', 'VWAYGIJIJIJIYOPYWYBYBVZY', 'HJIJIPOPYWAI', 'YPHPYCWAGDIYWYGIGTPYWYBLPLPLPLPLPYYALPLPBZVY', 'Y', 'PWAGY', 'HIYYWYNHPHPHPYPWHPA', 'HBVYWYNAHPHPYT', 'HPWYHPBPLPLPLPLPYTYYWAIY', 'YB', 'ZDTYC', 'HNPBHPLPPLPLPLPHLPHYPWYVYYWAIY', 'HPYBLPLP', 'HPLPY', 'ZTDCTHPHPY', 'PYBWAIGYYW', 'VTYGIBYLPLPLPLPLPYD', 'ZYDTYWCAG', 'PWYY', 'HWNYHKHPYTYA', 'ZWADWAGYTCHPHPY', 'YWYBLPLPLPYWAFIJIWAGY', 'YCDWYBZ', 'HWNTYVYHAGIPHPHPYWA', 'HJIJIUPOPPYOPOPUYDWAIJIJIJI', 'ZDC', 'ZDWAC', 'HQYODPYAQOWPTOYWAIOJIGP', 'HQPYBVYKH', 'ZBVGDYTHPYCZCWY', 'YTY', 'HAGJIJGNYHBVYP', 'HAIJIPZYBW', 'ZDTC', 'YCYDTYZWAG', 'YPYCDWAWYZB', 'Y', 'ZDCT', 'HGPYWAWY', 'PWYYGYWALPLPLPLPLPYOPBPYD', 'PYWYAPLPLPYWYLPLPLPLPLPLPYWAIJIP', 'ZYTYCD', 'HAWYUPYWTY', 'ZDTC', 'YTYCBTYWAYD', 'ZYWDAIPYWALPLPWLPLPLPYWYYAWAGCIJIJIP', 'HPYANWYGHPYB', 'ZYDWYBCTYWAG', 'ZDCTYWA', 'HPHPHPYW', 'YCDTZ', 'HAWAIJIGPHPYWY', 'U', 'HOPOPYBPQP', 'UYAFIGYWYUPTYWAIPP', 'YVYCWAIGDYWAZTY', 'ZDAWYWYBCVYW', 'ZDWAC', 'YCDTYBZ', 'YB', 'ZDC', 'ZDC', 'Y', 'HWYAYQPYGIFIJIPJPY', 'NZDWYAWYC', 'YHPYZVY', 'YJIJIPJIGPOPYYWYHTAIJZFI', 'YCZ', 'ZDTC', 'ZDWAWYYTCHPHPHY', 'HPOPYWAWYU', 'ZDTYCB', 'YWAIGDYBPY', 'YJIYCDTYWAGJI', 'PPIYALPLPLPLPYWYTWYAI', 'YCDYBPHPZHPY', 'ZDTCA', 'HPHPHPYWAWY', 'ZDTWYWAWCYBLY', 'ZYC', 'PYWTYGB', 'YDZYWAC', 'HPHPHPYDWY', 'ZDTC', 'HPLPLPLPLPYYWAHLPMLPLPYUDWYPBHNP', 'HOHPQOPUPYWAN', 'ZDYBC', 'ZDTAC']]
#
#
# Recording Date: 2024-10-13 00:00:00
# 1xN cell array of mapped syllable orders for the day:
# [['HYBLPLPLPLPYWTYGPHYPWYAWYLPLPLPLPYYBLPLPLPLPYWYBLPLPLPLPYBLPLPLPLPYWAGJIJAYWWYTAWYBLPLPLPLPLYAY', 'YCTYWYZA', 'HPOPYW', 'HPOPOPOPYWYTWY', 'HPDYOPYTAGPY', 'HYWTQPYQP', 'HIJIJFIJIYHDWYOPOPOPOYWYAGN', 'HOPOPYTWYUZCY', 'Y', 'HWYIHJIJIJIPOPYALPLPLPYWPYBPLPLPLPLPYGOPYNTWYTWA', 'HU', 'HOPYHAWYPOPYWANIJIPOPOP', 'HNIPHJIPJIOPOHPYHPBHLPLPPLPYYTWDYAPN', 'HWQYUPPOPOOIPJIJIGYWYHPYZCYDYOPTQOYPA', 'ZWADWYTHCYPHPY', 'YTDWAWY', 'HYWYBPLPYWYTPALPLPLPYIFIFIJIJIPYWYWAG', 'HIGIJINJIYHWYGPHIPPYWHYPALPLPLPLPYYBLPLPLPYWYAWYDBLPLPLPYDTYWA', 'ZDWYTYCBVY', 'HPGHYPHPNHBLPLPLPLPHYPWDYWAI', 'YIJIJIJIGYAWYGPOPYWA', 'HIJIJIJIGYPYTYWA', 'HAYHPOPNHIJIYWYNHPYTYW', 'ZYDYDYDYTCYWYGY', 'PYWAGIPOPYWYALPLPLPLPYAIPYWWYBLPLPIYADLPLPLPLPYWYAUTQOPYBPLPYLPLP', 'HPLPLPYDTYAWYYBL', 'ZADWYBPJGITGYWAGIJIPYYCWYBPY', 'HPWHPAPLPLPLPYNHDQTOYPWPIJIJIYYWALPLPLPLPYBVPY', 'HPOPYBLPLPLPYPPHPQ', 'ZDC', 'U', 'PYGYALPLPLPYWYBPLPLPLPLWPLPYTWALPLPTLPYIPIJIYWYBLPLPLPLPYPYYD', 'PJIYAIJIPYWWYBLPLPLPLPLPYYYTWAGI', 'HNHPHPYWYTY', 'HUYBVYWATYWYWYNHGPY', 'YCYWYBYTYDVGJIGYNHZPQOPUYUYUZC', 'H', 'HPOPOYWA', 'HOPOPYTY', 'ZGYDWAWYBYCWATY', 'PYWAWYYUWTAYUG', 'ZWYDGYWATWYBPLPLPYWYBCHPHPHPY', 'ZCTBVD', 'YVWATWY', 'HBPLPLPLPYYDTAY', 'YJIWAWYGI', 'HIJIYDWOYYAWPLPLPLPYTPWHYPG', 'ZDTYC', 'YB', 'YDWAY', 'PIPYDWYAWYOBPLPLPLPYBWPLPLPLPYPAOYYG', 'HPYHPGIJIJIJIJIYWAYIJIJIPOPOPIGYWYGIJIJIJIJYWAIP', 'HZWYGYCWYBDTHPY', 'HHYPWYAHPWYBLPLPLPLPYQPOPAGJFIJFIJIPYWYYBPLPLPLPYWYBPP', 'ZDTC', 'ZDTC', 'ZDTYC', 'YVGYWAYGIFIJIJIYWWYBLPLPLPYAIJIJIPAYWAGYWDTYYB', 'HWAOYGYWYABVPPYOP', 'ZWDYBVYWATWYGIPYBPLPLPLPYCHPHPYPHPY', 'ZDTYGCP', 'ZDTC', 'HQOPOPIYDYPTHWPY', 'PWAIJIJIJIYTHPHPY', 'HJIJIYVGIJIOPYWYNHZCDTYWAI', 'ZTYCD', 'HPNDHWPAUY', 'HPHPYUYDWNYHBV', 'YTYWAIGWAGIY', 'YCDZ', 'YWAGCYWYBLPLPLPLPYWAYIPYWTAY', 'YYGPDIJIYWYGYWTZYWAC', 'ZDTHC', 'PWYBHPWAUYY', 'ZDTC', 'PPWOAYOIGY', 'PYWA', 'HYGYDPYWAIJIYP', 'HPAWYYBPLPYWYAGIJPOPYWTYLPLPLPLPLPYTYGY', 'ZDATC', 'HNHPYDYW', 'YDYGYWYTHYPHPY', 'Y', 'YYCVDWYZWAG', 'Y', 'YCGYWADTYZWAY']]
#
#
# Recording Date: 2024-10-14 00:00:00
# 1xN cell array of mapped syllable orders for the day:
# [['ZBLPLPYDAWYTYLPTLPLPYWYBLPLPLPLPYWALPLPLPLPYPJIGYCHPHPHPY', 'H', 'ZGYDWYLPLPYPYWYATYBLPLPLPYCWYYWAY', 'HOBPWYOPTIJIYPYGIJIPQPOPOPYWYBLPLPLPLPYBPLPLPLPWLPYDYTAIPAYWAIJIYWYGIYLPLPLPLPPOPYQ', 'HYOQOPOPOYTYAYW', 'ZYPRVYWYADGPYBLPLPLPLPTYWYBLPLPLPLPYWAIJIJIAYDYPLPLPLPLPYWCYTYWAIPYT', 'PIJGOPYDYBYLPLPLPLPYWAYWA', 'HIFIJIJIYWYOPOPYWTYG', 'ZWADYGIJIJIJIJPYWYTBLPLPLPLPYWAYCBVY', 'HWYBPLPYWYALPLPLPLPYWAIJIJIJIJIJIGPYWAPIJIPIYBPLPYLPLPLPYAYWYBPLPLPLPOPYDTA', 'ZAGYDWALPLPLPLPYTWAIJFIGIJGPYWYBLPLPLPLPYWTYYALPLPYWPYHPCHPYW', 'YBCPLPLPLPLPYDTYZWAY', 'YYWYGIJIPYDWALPLPLPLPLPYWYTGIPOPOPQOPYWYYTLPLPLPYBZPLPLPLPLPLPLPYWAIJIC', 'PYGIJIJIJIYALPLPLPLPYWTAYWYBVGIPAYWYAIJIJIPOPYYDT', 'ZYDWAIJFIJIJIJIYPVYTWYBLPLPLPLPYTYYCWAIG', 'YB', 'HJIGYWPYWAIJI', 'HAWYOPGIJOIJIJIPJIJIPOPYOYALPLPLPLPLPYWYBVY', 'ZWADIJIJIGPYTAYBYCBVGY', 'HCDTYPHZPHPHY', 'PPQPOPIGYYWTAWAGIY', 'YAGJIWYGBVYGYW', 'YTWAY', 'PWYYPQBOOPVYQODPT', 'HYTAIJIJIJIGPBVYOPDOY', 'HJIPYBPHPLPPLEPLPLPYHPAIJIJIPYYWTAIJIJI', 'HJIJIPOHOIPJIJIYBYLPLPLPLPLPWNTYPAQOPI', 'ZDTYC', 'Y', 'U', 'HPOPOPOPY', 'ZGYDBLPLPYWYBPLPTLPLPMPYWYBVAYCWA', 'ZWADGYTCHYPHPHPY', 'PBWYGIJIJIJIJIYY', 'ZDTC', 'HJIJIJPIPYHPQOPYWTYNGH', 'PDY', 'ZDTC', 'Y', 'HIJIYTALPLPLPLPLPLYWPYBQPLOPMPLPLPLPUYWTYVG', 'HP', 'HPOPYBHPLPLPLPOPOPY', 'HTYWDUFIPPOPYBPLPLPLPLPYYAIJIJIPYBLPLPLPQPIYWA', 'YIGYCWYBPLPDLPLPYWAGIJIJIYTWAPLPLPLPLPLPUAYZWA', 'POYDTYBV', 'HPGIJIJIJIJIGPYHVGIJFIJIJIGQOYPYWYAPNNH', 'ZWAYDGYWAIGYTHPHPHPHYCZCY', 'QDTYWAZYC', 'HVGIYWALPLPLPYWAIPPYYWTY', 'ZYWADGPYWALPLPYTBPLPLPLPYWYBPLPLPYACHPHPYW', 'ZTADWYGITCHPHPY', 'ZJIYPYDAWAIPTYWAPLPLPYDTALPLPLPLPLPYIJIJYWYAWCAI', 'HJIHAPHPOPYWAIJIPJNI', 'OOPPY', 'ZWAGDYTBCVY', 'HPOPYWYPYWAIJIJIJIG', 'HIJIJIJIJIJIJIJIPOYPYTYWAP', 'HPHPHPY', 'PYWAPLPLPLPLPYWYWAQOYPT', 'ZDTCHPHPY', 'YAGYWYBVYPYW', 'HOPAWYVYYBPLPQOPY', 'HYTWPLPLPLPQOPIYPHBPLPLPLPYHPWAIYBPQPOP', 'VWACGYDGIJIYWAPYTPLPLPYWYYYBVZY', 'ZDTYCB', 'ZBDTHCPHPHPY', 'ZADIJIPYBPTIJQYWYAYGYCHPHPHPYW', 'HPTAYIGAPBVGYQO', 'ZCYDWAIGTPYWAWYBPLPLPYGIPYCAHWYPHPHPYGYZ', 'HZAIJIJIYNHCDTYAY', 'HGIJFIPQIOYPBPLPLPLPLYPYWAYDTYP', 'ZACYGYDWAWYTHPYDW', 'HJIYOPWQOAPIJIGPYYWAI', 'HOPOPOPYTWYG', 'ZWDAGPYBCVTAGY', 'ZAGYAWTAGYDWYBPLPLPYHCVYWD', 'HDTZC', 'HNBPLPLPQPYAHWPPLHPLPLPLPPYDYALPLPLPIJIJIYPYBLPLPLPLPYWYBVY', 'YBVDYWYTAGTIJIJIPYWYPLPLPLPLPYWAIGIJIJIJIJIPHYWYPHPHPY', 'HAIJIJIPYBPLPYZCDTYW', 'YT', 'ZJIADTYCWAIJIJI', 'UDTZC', 'HWAOPQOPOPYWAIFIGY', 'HJOIPOJIPJIPYOPYWAPIJIJI', 'ZDC', 'ZDTC', 'YJFIJIJIGYDTYVYBPUWAIGI', 'PYIPYIGIYWAYBPLPLPLPYPYWAIJIJIYDTYGPYGQOYPWA', 'ZDYCB', 'ZPYYDAWAGCYB', 'HWTYPHPYWAY', 'Y', 'HVPYPOPOPYTWDY', 'ZDGYBTPYWAIGYGYHAWCYPYWA', 'HY', 'ZWYTHPHPCYWAD', 'YATHPHPYDW', 'YPLPLPLPUVPYWYB']]
#
#
# Recording Date: 2024-10-15 00:00:00
# 1xN cell array of mapped syllable orders for the day:
# ...
#
#
# Recording Date: 2024-10-26 00:00:00
# 1xN cell array of mapped syllable orders for the day:
# [['ZBVYDWALPTZTZTZHPHPCY', 'YDTYWAIJIJIPYTUWYGIJIJIJIY', 'YJIUCDTYWAIJI', 'HYHPTAHPPG', 'HDTYALPLPYLPLPYWAIJIYDYBLPLPLPLPLYTAPIY', 'PTY', 'YCZ', 'ZDYC', 'HPHPHPYDTY', 'HIJIJIPYAPLPLPHUPYCDTYG', 'HHBPPLPLPLPLPYYDTHPYP', 'YGIPYDTALPLPLPLPLPYIJIGPYWTAY', 'H', 'HPHPYC', 'GDTYBYLPLPLPY', 'HOPOYTPOLPPLPLPLPQYOP', 'XUCHXZHY', 'ZDTCHPYT', 'YDTY', 'YUHZPHPYDC', 'YT', 'HYPHP', 'ZTDATCHPGVYD', 'PY', 'HDWIAIJIJIGJIPYYUYPLPLPPLPY', 'HHPYCDTYP', 'AIJIJIPY', 'Y', 'HPHPYCYWAIJI', 'YDTYWCALPLPUDTAIGPYZ', 'YPOPQYV', 'ZDTUYC', 'HWAPHIPGYHPDTAWYYGIJIJIJIPYBPLPLPLPLPYDCDCDYBVY', 'HAPLPLPLPYPHPIYDPHPYT', 'HYGYPHPYCDTAW', 'HYZDTALPYDPGPYWAPLPLPLPYTQDYAIGYBVC', 'YTYGY', 'HIPJFIJIPOPHYNPYHDTYWA', 'ZDTACG', 'GGYWYBLPLPLPUYWAPLPLPYPHPHPYDTAYI', 'PWALPLPHLPLPMPYGIJIPYALPLPLPLPHPYGYDTY', 'HIPYWAPPLPHLPLPPLPOPYBYPLPLPLPYWALPLPLPLPYTA', 'HPOPYGIFIJIJIY', 'YB', 'VPHPHPYDTYYA', 'HYWAPHPYDWYG', 'YD', 'ZBVYDGIJIYWATPLPLPYHCY', 'HPHPHPYD', 'HDPOPYAW', 'YIPYDTYTGYBPIYWAPLPLPYHYWDA', 'ZBVYDTCWAGIJIPY', 'PY', 'YHPHPYWAGYBGIYDTYWAYLPLPYPHPHPYT', 'HNPHHPHPYZC', 'HPYDYBPLPLU', 'HDAIJIJIGVYPHPYGY', 'HYDTYPHPYBVPOP', 'HIJIJIJIJIJIPOPYPUHYPOYWA', 'HDTAIJIUOQOPOPYBVY', 'HPU', 'HQOPQOPYP', 'HOYALPLPLPYWYTWPAIJIJIY', 'OPY', 'GPOYY', 'Y', 'HHYCPN', 'YB', 'ZPYIPYDWALPLPLPYTGCHYWA', 'YALPLPLPFIPYBGPLPLPLPLPLY', 'YDTYG', 'GWALPUY', 'YDT', 'HYAP', 'YWYAG', 'YPLPLALPLPLPLPYDYBPL', 'GAIAIAIDTYGYYW', 'YYGIJIPYBPLPLPLPLYWAIJIJIPYBAIJIJIYAWAYPHPYW', 'HPHPYT', 'HOPIYDTYG', 'YT', 'GWYALPLPLPYWYGPY', 'YAIJIPYDYGIBJIJIJIYWAVYPHPZCDT', 'YC', 'HTYPBLPLPLPLPYYDYGY', 'GWAY', 'GDTYY', 'U', 'PBYPLPU', 'YALPLPYAPLPLPLPYWYBLPLPLPLPYAGYPYW', 'YWAIDYBVY', 'ZBVYDAWYGYTALPLPLPYACWY', 'YWADTYGPYZC', 'HPYWALPLP', 'YDYAC', 'AAIJIJIPW', 'ZDTYC', 'HPBY', 'VGY', 'Y', 'YWPLPALPLPY', 'PIJIJIJIYWADTYYGY', 'YTHPHP', 'ZDTCAIA', 'GWABVYY', 'Y', 'HCDNHZ', 'ZYBCD', 'AWTY', 'YLPLPLPYTAWYBPLP', 'YDTYGIJIJIY', 'YB', 'YAIGT', 'Y', 'HPYWO', 'YBLPLPYWAAIJIPY', 'ZDTC', 'YWAA', 'HPYDY', 'YWALPLPLPLY', 'YGIFIJIJIYWALP', 'ZDTCAW', 'PYDTHPWALPLPLPU', 'ODPY', 'PDYY', 'AWA', 'GPHPOPYDY', 'HPYWAIPHPOPYWAIJIFIJI', 'YB', 'CAIJIPYWATPLPLPLPLPYHPHPYDW', 'ZDTCWA', 'ZDYBC', 'GYWYAVIJIJIJIJIFIJI', 'YTWA', 'PAIJIJIJIJIPYOAOPPLPLPLPYPWY', 'HWYGYPWHAPSHPYDTA', 'HPOPYG', 'HIJIPYYBVYALPLPLPLPLPYPDYHPTWAHP', 'HPHPHPY', 'GLPLPUIJIJIJIOPOPYWA', 'HGIJIOPOPOPYDTY', 'HWYDTYYAIJIJIY', 'HPY', 'PPDYOWOYALPLPLPLPY', 'HZDTAGC', 'GPHPHPYWAY', 'HPHPYWYBPU', 'YALU', 'HNHOPOPYD', 'HCUYPHPYDNTYZ', 'HPHPY', 'HPOPYWAWY', 'ZDTC', 'YCZ', 'OPBYVY', 'YLPUA', 'HPHPYTYG', 'YD', 'HHZCN', 'YB', 'YQPYGBLPLPLPLPLPU', 'PJIPDTYAWAIJIFIJIJI', 'HPLPUPHPL', 'HOPIY', 'YDYBLPLPLP', 'HLPUPYWALPLPLP', 'HPY', 'Y', 'YTYCAPLPDTYGZY', 'YALPLPMLPLPLPLPYBVYWY', 'HPYCAWUYYZTYAI', 'YUGIYVIJI', 'YYCDTYZWAIJIJIJI', 'ZBVDYWAIJFIJIPTUYCPHPY', 'YGIJIJIGYBLPLPLPDLPLPYYBLPLPLPY', 'HWPTYHPBLPMLPLPLPYYDTYGIJIY', 'YCYBZPLPLPU', 'YWAIPY', 'ZDTWCY', 'ATYWAIGIJIJIPY', 'HUPHPYBPLPLP', 'ZADIPYWALYPLPLPUBCVYW', 'HYWALPLPLPPYYGIFIP', 'CWATHYPHPDY', 'ZDYGDYBLPLPYDTTYGYYTCAWY', 'YGIGIJIJIPYWALPLPLPLPBPYDTY', 'YGIJIJIJIYDWYBLPLPLBLPLPLPLPY', 'YCYDYBVY', 'HHDPTYPY', 'YBLPLPLPLPYWAAIJIJIPY', 'YB', 'AYW', 'CD', 'PDYT', 'ZWAGDTYCWA', 'YB', 'GBLPLPLPYWAPLPLPLPUYUDTYGYY', 'YTWAL', 'YB', 'HYWALPLPLPLPPLPHYPBLPYDTYG', 'Y', 'YAWY', 'POPBOVYYP', 'ZYWAPLPDLPLPYGIJIYTWYALPLPLPOPYALPLPLPYBPLPLPLPLPYAICYP', 'HOPQOPYBLPLP', 'ZDC', 'HAWPPLPLPOPIJIJIYOPYBLPLPLPLPY', 'ZDWATCAGY', 'ALPY', 'YDTY', 'YYIJIYWGAIJIG', 'VYWA', 'ALPLPLPY', 'YBVYDTY', 'Y', 'PYGJIJIYUBVYDTY', 'AJIJIPYDTYI', 'PTWAY', 'HPYBV', 'YVDTAWYB', 'YWA', 'IYWALPLPLP', 'ZCTYD', 'YLPLPLBVYDWA', 'HPHPHPYDYBVY', 'HPYB', 'OYOPPI', 'GALPLPLPLYIWALPLPLPLPLY', 'HPHPYDYGIU', 'YPIJIJIPYTYA']]
#
#
# Recording Date: 2024-10-27 00:00:00
# 1xN cell array of mapped syllable orders for the day:
# [['HBPDZTUHPHPYC', 'YBTHPY', 'DT', 'HCPDTYGY', 'GIIJIJIJIJYDYTA', 'HHPYP', 'HYTYP', 'YBVYBTLPLPLPLPYBPLPLPLPLPYAPLPLPLPLPLPYTYGIJIAGY', 'ZIJIJIJIGYDGJIJIJIJIJIYYTCHOPOPYWA', 'HC', 'PYALPLPLPLPQOPOPYYTWYGIJFIJI', 'HYPBOPLPLPLPLPUYTYAIG', 'HCDTZYB', 'YCY', 'YBLPLPLPLPYGBLPLPLPLUYDYAIY', 'YDWAIJIJFIJIJIOPUTAFIFIJIGY', 'HIGYAPIHJIPGYYDYTA', 'WIJIJIFIA', 'YYAIJIJIGTYWALPLPLPLUYGIJIJFIJIYD', 'YDTYGPY', 'ZDTDYTACGY', 'HDZTYBVYCU', 'HCNHDYWAZIJIJI', 'HWAYIJIJIPYDYGIJIUBLPLPLPY', 'NJIJIPYGHIJIOPOPOYNHWAIJIJIJIJI', 'ZBDVYAITYWAPLPLPLPLPYCAGYPQOPY', 'YJIGYTYWAI', 'YIPYBLPLPLPYBAIJIYYPHPYWA', 'YDYGIJIJIPYWYWAIJIJIPY', 'YCGDYTUZAIJIJIY', 'HIJIYBLPLPLPLPLPYBPYTYG', 'ZDTYCWAIG', 'ZCTHYD', 'YWAIJIY', 'U', 'U', 'ZYYALPLPLPYDYBLPLPLPLPLYWYTCAIJIJIJIG', 'YYGYHPTYTW', 'AWYIPYBVY', 'ZWADIJIJIJIYATYCBVY', 'U', 'YB', 'YCDT', 'YB', 'YBVY', 'AWAIJIJIP', 'YYAIBVYPOP', 'HIYAPLPLPHPYTWYG', 'HPYWAIJI', 'HAIJIPOPYHYWAINJIPPY', 'HPHPYDWYB', 'Y', 'HYHBPLPLPLPLPMLPUQOPYBLPLPLPLYTP', 'HYWAPIHQPYDTYGP', 'HPOPYWAIJIJ', 'ZYWDTCYPHP', 'IYGWALPLPLPY', 'HGYAWY', 'HYHBPLPLPLPYYWAIGYAWYGRIDYAWP', 'ZDYC', 'AI', 'HDYDPIJIJIJIYGIY', 'YDYAWLU', 'YDY', 'YBLPLPLPLPUY', 'ZDTYALPCLP', 'HPHPYDTYIJIJI', 'HWAIJIJIJIPYPHPHPYNHDT', 'NDHTAIGPYNHOPOPOPYWAIJIJIPY', 'HPQYDTYG', 'ZYDAWYGTCAIJIJIP', 'CTD', 'HPHPYTB', 'YAPYWAIJIJIY', 'U', 'YDYA', 'OBVYPY', 'HPHPYA', 'Y', 'ABPLWPLPBAIJIJIJIJIJIJIPYDY', 'APYIBLPLPLP', 'YWYG', 'GYYWAWLPILPLPLP', 'ZDTYCG', 'YBPLPLPLPLPYWAIPY', 'HPOPYB', 'ZDTCWA', 'PBPUVYYDTY', 'ZDTC', 'YLPWLPLPLPQPOPYAB', 'ZDDTAIJIJIPYWLPLPLTCAIJIJIJIJIGY', 'HDTYP', 'AYIALPLPLPY', 'HPHPYDY', 'GIJIJIYDTA', 'HPLPUPHPHPYBL', 'PTYYOP', 'YAIIAIAJIOPGYWALPLPLPLY', 'YDTYAVYBVY', 'ALPLPLP', 'YYDYV', 'YWTY', 'APLPLPLPLU', 'HTYOPAOPYBVYD', 'YB', 'TPYWYBH', 'CTAID', 'IY', 'YB', 'YU', 'ZDTCHY', 'ZYBDVGYWAWATPLPLPYAIPCYDT', 'HOPQOPOYBVY', 'ZYDWAIPYWATIYBPLPLPLPYCYG', 'HBLPLPLPYPHPYDTY', 'HOPOPYAWB', 'HIGPWAYWA', 'PDTYAYLPLPY', 'ZDYBC', 'ZDTYCB', 'WBPLPLPLPLPYA', 'YTWYG', 'GJIJIJIYDYI', 'AWLPLPLPY', 'ZTYCAWAD', 'HIJIPJIJIPLYDPTYOPVYYHPAWA', 'ZDTCBVY', 'PY', 'YB', 'YPYWATY', 'YBPLPLPLPY', 'ZWLPUCY', 'ZDTYDAWYGTACWYGIJIY', 'HPYBLPLPLPLPY', 'ZDTYC', 'AWAIJIJIJI', 'ZCD', 'AWYG', 'YTYAWYBLPMLPLPYTWAHPYD', 'YDWY', 'GY', 'ZTCD', 'HYCYPBHP', 'YLPLPLPUDYGIPYB', 'HPHPYDTY', 'YWLPLPLPUA', 'HIJIJIYWAIJIJIPHPYG', 'PY', 'HHPGIJIYWPAHPY', 'YBLPLPLPY', 'Y', 'U', 'CBPLPLPYTWALPLPLPYAIDGY', 'YDY', 'YTD', 'YTAW', 'GAPLPLPLPYY', 'YB', 'AIYWIGA', 'HYGIJIFPYZCDTAW', 'YPDTYZBVCY', 'AAIJIJIPWYBPLPLPLPYW', 'Y', 'YIGYYDTYAWYBLPLPLPYPYWYAPHIPJ', 'ZVYPIGIYTAWYBCWYDB', 'ZDTACIJIJIYWA', 'HYWAPLPLPLPU', 'PDTYAWY', 'YWA', 'HHPHPHPYDTNH', 'GYDT', 'AIJIJIA', 'PAGYWYBYGYDTY', 'PZCDYWYA', 'QDTBY', 'POWAYPYG', 'HUPHPOPYDYALPLPLPMLPY', 'YDYBC', 'HWPY']]
#
#
# Recording Date: 2024-10-28 00:00:00
# 1xN cell array of mapped syllable orders for the day:
# [['YBLUBVYPHPY', 'CWAIJIJIJIPOPYGIJIJITYAGIJIJIYD', 'ZDDWALPLPLPYBTPLPLPLPLPYCDWYBLPLPAIY', 'YWTAGY', 'GBY', 'PYTYALPU', 'ZWYAPIJITJIOYBPLPLPLPLPLYWYALPLPLPLPCYBPLPLPLPHYPHPYD', 'YTWA', 'Y', 'AIJIJIPOPOPYWALPLPLPY', 'GDTYAIJIJIY', 'PDYTYAI', 'HCDHTPYYP', 'GJIJIYWYBPLPLPLPLIPLY', 'IDYY', 'GAIFIJJIJIIYJIYAIJIJIFTALPLPLPYIJWFI', 'AIJIJIJ', 'YBPLPU', 'TYH', 'GGWAPLPLPYY', 'YDYB', 'YDTY', 'YYDYAIJIJIJIJIJIGPOP', 'YWA', 'ZYCYCYCYCDTACWY', 'VDTYVPCDTYGYY', 'YAIJIJITYWAGY', 'HCDTZAVY', 'CTAID', 'ZDTACIJIJIJY', 'HLPLPLPYPHPWAIJIJIJIYBLPLP', 'HIJIPOPOPYAPHPLPLPPLPLPLPLYAGIJIJIJFIYYBPUZCDTA', 'ZDC', 'HPHYDYBVY', 'HOPOPYTV', 'ZGDYDYALPLPLPLPLPLYTCHYDY', 'YTWALPLPLPLPLPLY', 'HLPLPLPLPLPQOPYOPGIJIJIYHPTWAPLPLP', 'PTYOGYPLPLPLPLPUYUY', 'CTBVD', 'CYBTLPLPLPYDTALPLPLPYADWAG', 'YWAGY', 'YWAIGIJIJIGY', 'PBYLB', 'ZYCD', 'AIJIJIYWYBLPLP', 'CTD', 'YB', 'PYDYAWLP', 'POGIJIJIPAIYJIPY', 'PYOPDYTYYGIJIJIJIG', 'HYCDTZYWAG', 'Y', 'ALPLPLPYUYBLPLPLPYPOPYWB', 'VYAIJIGYWYBPLPLPLPLPQPOPYTPAWYYG', 'HPHPYC', 'HPTYQOPYHPWAIGY', 'IY', 'YGYABLPLPLPYLPLPLPLPLPY', 'OWYYA', 'AI', 'HBPLPLPLPLPYOPYTWLPPLPHLPLPLPYP', 'PY', 'YTWYG', 'GGYWPAHGPIJIHPYDYTAI', 'ZWDAGYTCAYPHPY', 'HDTPYYGIYWYGYBPLPLPY', 'HWALPLPLPCDTYGYPZY', 'HYCDTA', 'HOPYGP', 'HWAIJIJIJIJIJIFPYWANIHY', 'HYCNHDTYPBHPZVP', 'ZDYC', 'YGYTHPY', 'ZDTAYCB', 'PWZYBDTHYC', 'HHPOPYWYGIPJIY', 'ZBDVGYDYAWYTCAIY', 'YALPLPLPYWALPLPLPYBVYW', 'HGOIPJIYYAWY', 'ZDTAC', 'YB', 'GWAIYY', 'OWAPLPMLPYPWAYY', 'PPYWAIJFIJIJI', 'ZDYC', 'PWAIJIFIJIJIPYAWYGIBUVYY', 'HPHPYDY', 'HIJIUNHPYDTWA', 'HPOPQOPOYWYGY', 'HPHPY', 'YT', 'YPHPYCD', 'ZDTC', 'THPHPYWY', 'GY', 'YJIJIJIPIJIYAIBPLPJLPILPLPYJIPYGI', 'CYWAIJIYJIJID', 'HPOPYCY', 'HPY', 'AAY', 'AYBG', 'ZDTYDBPLPLPLPYWYTCHIPHPY', 'U', 'HJIPIYDTYPPOPYWAI', 'HYYBVYP', 'HPOPY', 'HWPLPLPLPWPYDYA', 'YCDTUYYZBUYLPLPLPU', 'HPHPY', 'YBVGY', 'YDYTHPHPY', 'AIJIJIGP', 'YAIDTYGIJFIJIYW', 'YDTAWYGBPYVYPHPHPY', 'AWAILPLPLPLPQOPOPIJIJIPY', 'YWYPBHPHPNHPYDTY', 'HY', 'YB', 'AWYGP', 'ZCD', 'YB', 'AYIG', 'YWA', 'HPNYHDTWPH', 'YYDYAA', 'PYB', 'AWYGIJIPY', 'HOPOPYP', 'HPYW', 'YT', 'OOPGOYPOPQOPPYOPQY', 'HYDYP', 'U', 'TPHPYDYT', 'YWALPLPCDYBVZYY', 'YBVY', 'H', 'ZDCTHPHPYD', 'YAIYBVYDW', 'AWYWA', 'YB', 'PDTWYYVY', 'YAWYTWAIJIJIFIFIJIJIY', 'YDTHPHPY', 'YDZTAC', 'ADYGIJIJIJIP', 'YB', 'YYWUG', 'PUTYGY', 'YDYA', 'HOQOPQOPY', 'YDYVCIJIYY', 'YWYA', 'CYTYD', 'HYDYBLPLPLPLPU', 'ZDAIJIJICJIYY', 'YAWY', 'YUWYAYB', 'ZDTHCY', 'AFGYWYB', 'YYWAG', 'Y', 'AY', 'PYDTA', 'HPHP', 'OPTLPMLPLPYY', 'YDYVGV', 'UY', 'HPQOPYWAIFIF', 'ODYTY', 'GTAYBVYD', 'ZDC', 'YCDTY', 'Y', 'AJIGYWYAIJII', 'Y', 'YAIJIJIFIJIPYWYABVY', 'HYPQPOPYWTYA', 'OPOBPOPY', 'PDYY', 'AWY', 'YT', 'AIJIJIY', 'ZYADWYBTCHPHPOPYD']]
#
#
# Recording Date: 2024-10-29 00:00:00
# 1xN cell array of mapped syllable orders for the day:
# [['YYPDHTPYBYLPLUWAG', 'Y', 'HGYBLPLPLPYPYDYAIJFIJIJI', 'YBPHPYWYBTLPLPLPYHPHPY', 'HYPHPALPLPLPLPLYPYBLPLPLYTYA', 'HYDTYAIJIJIJIPOPYWYPOPOPYDTYG', 'HWYGPOPYDYALPLPLPLOPOYDYGPHPHPYT', 'HLPLPLPLYDTYNHGPYTYPHBLPPLPLPUYA', 'ZADIJIJFIJIJIPYTCHPYDY', 'HVYPHPOPYAFIJIJIJIJIOPOPYPHBPLPLPLPLPYHPGYDTYB', 'ZYCU', 'HJIJIJYWAPLPLPLQPLPOPYTYNHGIJI', 'HOPOPVY', 'PYCY', 'HYP', 'U', 'CTHYPDY', 'TPHPYDWHYT', 'HPHPYDTYA', 'ALPLPLPY', 'YIJIOPYBG', 'YYTWATLD', 'YCZ', 'HIJIJIPYYDYAIJITYG', 'YPTWAIJIJIJIJIJIG', 'YLPUB', 'ZDYYTCAIJIJIJIJIJIJIJIP', 'HPHPY', 'AWY', 'YTYDA', 'YDYDWALPLPLPLPOPYTWYAIJIJIJIGIGYGIJIJIJIY', 'YYTZ', 'YGYDTYTAIJIJIPYWALPLPLPLPLPYBLPLPLPYWAIJIJIY', 'HQOPYTWOP', 'HLPYOPYDYAPLPLPLPQLP', 'VZCY', 'H', 'YYGIJIYALPLPLPLPYWTAIGYD', 'YIJIJIPYDTYGTAWYG', 'YAIJIJIJIPYTYGFIJIJIY', 'HIJIPOPQOPYAWYG', 'ZDTC', 'ZCTD', 'ZDTYCB', 'ZWADIJIYGYTBPLPLPYCHYPHPY', 'YWYBPLPLPLPYWATBYBVY', 'YTYGIFIJIJIJFIJIJIJIY', 'YBVY', 'ZDC', 'U', 'YWA', 'HYPHPHP', 'HYBLPLPLPPY', 'HPDYALPLPLPLPYYWYWYGIJIY', 'H', 'HPIJIJIJIJIJIPHYPYWYA', 'Y', 'AYBJIPYPYDTYIG', 'YDYA', 'YTWY', 'GDTYYA', 'HGIJIYDTWOLPYDYBV', 'ZTAIFIJIPIPOPOPYTCHPHPYDD', 'AFIJIJIYI', 'YB', 'PDYTVYB', 'APVYI', 'YCT', 'PCYDTYBVZY', 'ZDTC', 'Y', 'YA', 'YBLPLPLPLPLPLYLPLPLPLPOPY', 'YTYGYU', 'HGIJIYYWAWYP', 'Y', 'YA', 'Y', 'YTYBD', 'HPHPYW', 'OYPDY', 'YW', 'YW', 'QOWPYBYPLPLPLY', 'ZDYC', 'HGHYPYWAOPOPOPOPPOPNYHDPY', 'PPBLPLEPUOY', 'YWAFIFIJIJIPY', 'HQOPOYDYPGHP', 'HOYWYGPOPYDYAIJIJIJIJIP', 'YGYWTAIJIJIGYAPLPLPLPLPYAYDTY', 'YLPUCDTYAWYB', 'HBLPLPLPLPLYDPTYYALPLPLPLPLPY', 'HYPNHWYPBLPLP', 'PALPLPLPLPQOPIJIJIYTYYVGIJIJIJIY', 'HIOPOPYDYWAIJ', 'Y', 'YTAWY', 'Y', 'POPOY', 'YALPLPLPYWYDYGIAJIY', 'HPQOPYBNH', 'OTYYP', 'YBLPLPLPLYYAIJIJIJIPYW', 'HPHPYWA', 'PWYAGIFIYY', 'YDTY', 'HNCHYNZ', 'YZCU', 'YPHPYV', 'YCYZ', 'ZDWAGYDTTYGIPYCBVGYBPUUYPHPHPY', 'ZDTDAIPYWATYCBVY', 'YB', 'A', 'U', 'HCNDTZ', 'YDTYGY', 'HOPVYB', 'HPYPH', 'AIJFIJFIJIJIJIJIGP', 'YB', 'YGY', 'UDTYY', 'PDYY', 'YFIJIPIJIJIJIJIYAWAIJIJ', 'HYZYDTY', 'YU', 'HAWPLPLPPYDYWTY', 'YDWY', 'YCDWYAI', 'U', 'YWYA', 'HIJIJIJIPPYWYA', 'HBDPHPTYGYY', 'AIJIJIU', 'HIJIJIJIJIYAPHPYDTYA', 'PYWYGIJIJIPYBLPLPYWAYIPOPOPIG', 'HDTCYNGDYHALPLPLPLPLYTNHHZPHPY', 'PYWA', 'PYAPBOYVYODT', 'HPHPY', 'HPYWAIJFIJFIJIJIJIJIP', 'HOPYDY', 'YPHPYDY', 'YWA', 'HPHPY', 'YTAIJIJIJIJIY', 'YIPAYBV', 'HOPOYTNH', 'HPHPYWY', 'HPYTYA', 'HCDTNZ', 'GY', 'ZTCD', 'HHPHPYP', 'YDUTYYB', 'YIYUWAWYG', 'PADTYAIY', 'ZTYCD', 'GDTYYA', 'CBTHPYD', 'ALPLOYDTYGB', 'HYYDTYPNHAPIG', 'YBVYDY', 'YPLPLPLLPLPLPLPLPYAALPL', 'Y', 'ZYCYD', 'OBLPLPLPLPYAIWPYTYGY', 'YDTYB', 'YB', 'YDTA', 'OWY', 'HHPHPYDYN', 'GIPYWAIJI', 'PDYZC', 'HPHPYBLPLPLPLY', 'PCDYTYAZ', 'YDT', 'YDTY', 'HLPLYPLPLYPALPLPLPLPYHDPTWYB', 'AWY', 'AYIJFIPYBLPLPLP', 'YALPLPLPY', 'HXPXNBXPHPHY', 'HWCDTNZHPHPHPY', 'YB', 'ZCD', 'HYAIJIPHPYDTAIG', 'YABVYDY', 'YAW', 'CTAD', 'YBVYU', 'YWYAIJIJI', 'YBVY', 'Y', 'YWDTY', 'YB', 'ZYBCD', 'YYAA', 'YFIJIJIYIPDTAYAIFI', 'YALPLPLPLPYBBLPLPLPLPLPLPLPLPY', 'YC', 'YAIJIGYTYBVYW', 'ZYC', 'YDYG', 'HPYNH', 'YWAT', 'HOPQOPYDT']]
#
#
# Recording Date: 2024-10-30 00:00:00
# 1xN cell array of mapped syllable orders for the day:
# [['HU', 'ZLPLPUYPYDGYBTPLPLPLPLPYPYTYLPLPLPLPYWYALPLPLPLPLPYDACHPYB', 'ZDGYDYBLPLTPLPYWYALPLPLPLPLYCHPHPY', 'HVPNYPYTHYB', 'HOPOYTYA', 'APLPLPLUIJIYPQPOPYDALPL', 'HPLPLPLPLYYDTYAL', 'PYBHLPPLPU', 'HAIJIJIJIPYPYWDT', 'P', 'HPLPLPLPLYWYAPHPHPOYTY', 'YIJIJIA', 'HLPLPLPLPYWTYPHGPIFIJIJIJQOPYDYAYLPLPLPLPYBPLPLPLPLPYPYB', 'HHIJIJIYDTYAUPYBLPLPYTYNG', 'HWYGIJIJIPYOPOPDAOIYTYA', 'YTYDYB', 'HNIJIPOPYDWYHOPQPOPYDTYA', 'HYHPHPOYBLPLPPLPLPLUOPYNTAIJIJI', 'PDTYY', 'ZWAIGDYWYALPTLPLPLPYCHPHPYPY', 'HGIJIJIYWAOPIJIOGYPYTWY', 'ZDTACGYP', 'VDTYGIYBPLPLPLPYYTHYPHPHPY', 'PYGIJIJIPYBPLPLPLPTLPLPYYAYW', 'ZDTYCB', 'ZGYTYCTAY', 'PBLPLPLPLPYDTYGIJIJYIGY', 'ZDYDTCHPHPY', 'HYPYWYV', 'YYBVYV', 'YTY', 'YWYG', 'Y', 'HDYYAIFIJFIJIJIGY', 'HALPLPLPLYQPOPOYDTYW', 'HBLPLPLPLPYPPIJIGYTYWY', 'PAIJIJIJIOPYTYAYYW', 'YWAGYAIGYWAIBYPHPY', 'ZDC', 'AIJIJIJIJIJIJIPYWYGI', 'ZTACID', 'PAIJIJIJIJIJIPYBLPLPLPLPLPLPLPYBLPLPLPLPYY', 'PIJIYWALPLPLAWYYG', 'HAIJIJIJIJIPYPOPYTWY', 'HHGPYWAYDPY', 'ZDTCHYU', 'HYHPWPY', 'HIJIJIJIPOPYDTYA', 'HYBVP', 'ZYCD', 'ZDTCHPHPY', 'HYALPPHPYDTYW', 'ZTDYGIJIJIPYGIJIJIYTYGCIJIJIJIYD', 'HOPOPYYDTYALPLPLPLDTWYGOPIGI', 'HPHPHPY', 'HPYDYAIJIJIYWAIJIGPYTH', 'U', 'HAOIJIJIPJIJIYOPNYHTAW', 'HNIJIHJIJIJIPOPYDYGIJIJIPHPOPYDTYA', 'HIJIJIGPHPOPYDTYA', 'HHPYDYPALPLHPLPPLPLPLU', 'TPHHPYDTYG', 'YB', 'YBVY', 'AIJIJIJIJIJIPYDY', 'YWALPLPLPLPY', 'QIJIJIJICOVYOPUYPHPYYWPA', 'YBLPLPLPLPLYWAIJIGYDY', 'ZCTAYIY', 'TIGYBPLPLPYIDPTYHGIIPYHYWAPLPLPLPLPLPYBPLPLPLPLPYWAH', 'YYALPLPLPLPLPLPOPYWYWVYAIJIP', 'HIJFIJIFIJIFIJIJIYYNHDNTHYPA', 'YYBPEPHPHPYDYAIGYWYPZCDTA', 'HBY', 'HPHPY', 'PTYY', 'HHPWALPLHPLPPLPYYDTYGIJIYP', 'PWYYGIFIJIJIOJIPYDPYBPLPLPLPLPLPY', 'YVY', 'YPHPHPOPOPYT', 'HPHPY', 'YAIJIJFIJIJIP', 'HTAIJIJIPPYHPUPIPIPIJIJIFIJIPYWTYYBLPLPLPY', 'PYDY', 'GLPLPUIJIJIJIYDYAVPLPLPLP', 'HPHPY', 'HYDYBLPLPLBP', 'ZDCC', 'YWAIGYWALPLPLPYDTBYVYPHIPHPY', 'PGIPYWALPLPLPLPYWYAWY', 'HBLPLPLPLPYPHPHPYDTY', 'YHNHPHPYUZ', 'HCDZ', 'HHPHPHPHYCDYTP', 'HWYY', 'HYYPHPUPIHJIPJIP', 'HNHYDYBP', 'HCZ', 'PYTHY', 'YDTZHYPHPHPCY', 'HYZCNDTNZAWYH', 'YLPYWYYALPLPLPLPLYAPLPLPLPLPLPLYAYWYDBLPLP', 'YTYBVYWA', 'YIJIJIPYWAGIJIJIJI', 'YYUZ', 'YTYG', 'GY', 'YIJFIJIOPOPOPA', 'HNHOPYBLPLPLPLPLY', 'YDTYWACY', 'HOPYBPHP', 'YBPLPLPLPLPY', 'ZTYDTCHPHPYD', 'HBLPMLPLPYWAIGIJIJIYCADIJIYTHYPHPY', 'YBVYWYG', 'YTBLPLPLPLPLPYYWAIJIPY', 'AY', 'AYGYDTYG', 'PWYGIJIYBLUDYBYPLPLPLPLPY', 'AJIPI', 'ZWDYTHCPHPYD', 'YGDTYAIJIJIJI', 'ALPLPLPLPY', 'YDWYGIJIJIJIOPOPY', 'ZACIJIPYTAIPYD', 'PYCDTYWAYIJIJIJIJIP', 'PTY', 'YT', 'HIHPYDYPHAP', 'YB', 'YWAGYJIJIYW', 'HYDPTHPWAI', 'YBDLPLPLPLPLPYBLPMLPLPTLPLPLPLYAIGYGY', 'HPHPHPYTWA']]

# %% [markdown]
# ### Save each day's syllable cell arrays into separate .mat files (I don't recommend this, there are too few songs for PST to find a pattern from canary song, since it's so probabalistic):

# %%
# import pandas as pd
# import scipy.io as sio
# import os

# # Function to get the unique dates in the DataFrame
# def get_unique_dates(organized_data_frame):
#     return sorted(organized_data_frame['Date'].unique())

# # Function to generate and save .mat files for each day's recording
# def generate_and_save_mat_files(organized_data_frame, save_dir):
#     # Ensure the save directory exists
#     os.makedirs(save_dir, exist_ok=True)
    
#     # Get all unique dates
#     unique_dates = get_unique_dates(organized_data_frame)
    
#     # Get the animal ID from the first row (assuming it's consistent across the dataset)
#     animal_id = organized_data_frame['Animal ID'].iloc[0]
    
#     # Iterate through each unique date
#     for date in unique_dates:
#         # Filter the DataFrame for the current date
#         day_data = organized_data_frame[organized_data_frame['Date'] == date]
        
#         # Extract the mapped syllable orders into a list (which acts as a cell array for MATLAB)
#         mapped_syllable_orders = day_data['mapped_syllable_order'].tolist()
        
#         # Prepare the data as a dictionary for saving to .mat format
#         data_dict = {'mapped_syllable_order': mapped_syllable_orders}
        
#         # Generate a file name based on the animal ID and date
#         date_formatted = date.replace('.', '_')  # Replace dots with underscores for the file name
#         file_name = f"{animal_id}_{date_formatted}.mat"
#         file_path = os.path.join(save_dir, file_name)
        
#         # Save the .mat file
#         sio.savemat(file_path, data_dict)
        
#         # Print confirmation
#         print(f"Saved {file_name} to {file_path}")

# # Directory where .mat files will be saved (change this path as needed)
# save_directory = "/Users/mirandahulsey-vincent/Desktop/USA5288_song_cell_arrays"

# # Assuming organized_data_frame_with_orders contains the data
# generate_and_save_mat_files(organized_data_frame_with_orders, save_directory)

# %%
# import pandas as pd
# import scipy.io as sio
# import os

# # Function to get the unique dates in the DataFrame
# def get_unique_dates(organized_data_frame):
#     return sorted(organized_data_frame['Date'].unique())

# # Function to generate and save .mat files for each day's recording
# def generate_and_save_mat_files(organized_data_frame, save_dir):
#     # Ensure the save directory exists
#     os.makedirs(save_dir, exist_ok=True)
    
#     # Get all unique dates
#     unique_dates = get_unique_dates(organized_data_frame)
    
#     # Get the animal ID from the first row (assuming it's consistent across the dataset)
#     animal_id = organized_data_frame['Animal ID'].iloc[0]
    
#     # Iterate through each unique date
#     for date in unique_dates:
#         # Filter the DataFrame for the current date
#         day_data = organized_data_frame[organized_data_frame['Date'] == date]
        
#         # Extract the mapped syllable orders and store them as a cell array (list of lists)
#         mapped_syllable_orders = day_data['mapped_syllable_order'].tolist()
        
#         # Ensure the mapped_syllable_orders are formatted as a MATLAB cell array (list of cells in Python)
#         mapped_syllable_orders_cell = [[order] for order in mapped_syllable_orders]  # Wrap each string in a list
        
#         # Prepare the data as a dictionary for saving to .mat format
#         data_dict = {'mapped_syllable_order': mapped_syllable_orders_cell}
        
#         # Generate a file name based on the animal ID and date
#         date_formatted = date.replace('.', '_')  # Replace dots with underscores for the file name
#         file_name = f"{animal_id}_{date_formatted}.mat"
#         file_path = os.path.join(save_dir, file_name)
        
#         # Save the .mat file
#         sio.savemat(file_path, data_dict)
        
#         # Print confirmation
#         print(f"Saved {file_name} to {file_path}")

# # Directory where .mat files will be saved (change this path as needed)
# save_directory = "/Users/mirandahulsey-vincent/Desktop/USA5288_song_cell_arrays"

# # Assuming organized_data_frame_with_orders contains the data
# generate_and_save_mat_files(organized_data_frame_with_orders, save_directory)

# %% [markdown]
# ### Save ALL data into one cell array

# %%
# import pandas as pd
# import scipy.io as sio
# import os

# # Function to get the unique dates in the DataFrame
# def get_unique_dates(organized_data_frame):
#     return sorted(organized_data_frame['Date'].unique())

# # Function to generate and save one .mat file with all mapped syllable orders
# def generate_and_save_combined_mat_file(organized_data_frame, save_dir):
#     # Ensure the save directory exists
#     os.makedirs(save_dir, exist_ok=True)
    
#     # Get all unique dates
#     unique_dates = get_unique_dates(organized_data_frame)
    
#     # Get the animal ID from the first row (assuming it's consistent across the dataset)
#     animal_id = organized_data_frame['Animal ID'].iloc[0]
    
#     # Initialize a list to store all mapped syllable orders from each day
#     all_mapped_syllable_orders = []
    
#     # Iterate through each unique date
#     for date in unique_dates:
#         # Filter the DataFrame for the current date
#         day_data = organized_data_frame[organized_data_frame['Date'] == date]
        
#         # Extract the mapped syllable orders and store them in the list
#         mapped_syllable_orders = day_data['mapped_syllable_order'].tolist()
        
#         # Ensure the mapped_syllable_orders are formatted as a MATLAB cell array (list of lists)
#         mapped_syllable_orders_cell = [[order] for order in mapped_syllable_orders]  # Wrap each order in a list
        
#         # Append the day's syllable orders to the overall list
#         all_mapped_syllable_orders.extend(mapped_syllable_orders_cell)
    
#     # Prepare the data as a dictionary for saving to .mat format
#     data_dict = {'all_mapped_syllable_order': all_mapped_syllable_orders}
    
#     # Generate a file name based on the animal ID
#     file_name = f"{animal_id}_all_mapped_syllable_orders.mat"
#     file_path = os.path.join(save_dir, file_name)
    
#     # Save the .mat file
#     sio.savemat(file_path, data_dict)
    
#     # Print confirmation
#     print(f"Saved combined syllable orders to {file_name} at {file_path}")

# # Directory where the combined .mat file will be saved (change this path as needed)
# save_directory = "/Users/mirandahulsey-vincent/Desktop/USA5288_song_cell_arrays"

# # Assuming organized_data_frame_with_orders contains the data
# generate_and_save_combined_mat_file(organized_data_frame_with_orders, save_directory)

# %% [markdown]
# ### Save 2 groups: pre-lesion, and post-lesion

# %%
# import pandas as pd
# import scipy.io as sio
# import os

# # Function to get the unique dates in the DataFrame
# def get_unique_dates(organized_data_frame):
#     return sorted(organized_data_frame['Date'].unique())

# # Function to split and save pre-surgery and post-surgery syllable orders
# def generate_and_save_pre_post_surgery_mat_files(organized_data_frame, surgery_date, save_dir):
#     # Ensure the save directory exists
#     os.makedirs(save_dir, exist_ok=True)
    
#     # Get all unique dates
#     unique_dates = get_unique_dates(organized_data_frame)
    
#     # Get the animal ID from the first row (assuming it's consistent across the dataset)
#     animal_id = organized_data_frame['Animal ID'].iloc[0]
    
#     # Initialize lists to store pre-surgery and post-surgery mapped syllable orders
#     pre_surgery_orders = []
#     post_surgery_orders = []
    
#     # Iterate through each unique date
#     for date in unique_dates:
#         # Filter the DataFrame for the current date
#         day_data = organized_data_frame[organized_data_frame['Date'] == date]
        
#         # Extract the mapped syllable orders and store them in a list
#         mapped_syllable_orders = day_data['mapped_syllable_order'].tolist()
        
#         # Ensure the mapped_syllable_orders are formatted as a MATLAB cell array (list of lists)
#         mapped_syllable_orders_cell = [[order] for order in mapped_syllable_orders]  # Wrap each order in a list
        
#         # Compare the current date with the surgery date and store accordingly
#         if date < surgery_date:
#             pre_surgery_orders.extend(mapped_syllable_orders_cell)
#         elif date > surgery_date:
#             post_surgery_orders.extend(mapped_syllable_orders_cell)
    
#     # Prepare the data for saving in .mat format
#     data_dict_pre = {'pre_surgery_mapped_syllable_order': pre_surgery_orders}
#     data_dict_post = {'post_surgery_mapped_syllable_order': post_surgery_orders}
    
#     # Generate file names based on the animal ID and pre/post surgery
#     file_name_pre = f"{animal_id}_pre_surgery_mapped_syllable_orders.mat"
#     file_name_post = f"{animal_id}_post_surgery_mapped_syllable_orders.mat"
    
#     # Save the .mat files
#     file_path_pre = os.path.join(save_dir, file_name_pre)
#     file_path_post = os.path.join(save_dir, file_name_post)
    
#     sio.savemat(file_path_pre, data_dict_pre)
#     sio.savemat(file_path_post, data_dict_post)
    
#     # Print confirmation
#     print(f"Saved pre-surgery syllable orders to {file_name_pre} at {file_path_pre}")
#     print(f"Saved post-surgery syllable orders to {file_name_post} at {file_path_post}")

# # Directory where the .mat files will be saved (change this path as needed)
# save_directory = "/Users/mirandahulsey-vincent/Desktop/DECODER_cell_arrays"

# # Define the surgery date (change this to the actual surgery date as needed)
# #Format like so: 03.15.2024 MMDDYYY
# # surgery_date = '04.30.2024'

# # Assuming organized_data_frame_with_orders contains the data
# generate_and_save_pre_post_surgery_mat_files(organized_data_frame_with_orders, surgery_date, save_directory)

# %% [markdown]
# ## Save into three groups with an equal number of songs in each:
# 1) 3.5k songs post-lesion
# 2) 3.5k songs from immediately pre-lesion
# 3) 3.5k songs from earlier pre-lesion recordings
#
# From TG: "Any comparison should have a balanced number of songs."

# %% [markdown]
# ### First, make sure each song contains at least 2 syllables (there will be no syntax trees if you just have songs with one syllabe. Plus this is likely just a trill that's been marked as a song).

# %%
# Assuming the syllables for each song are stored in a column named 'syllable_order'
# Replace 'syllable_order' with the actual column name if different.

# Define a function to count the number of syllables in each song
def count_syllables(row):
    # Assuming the syllable order is stored as a list in the 'syllable_order' column
    return len(row['syllable_order'])

# Apply the function to create a new column with the syllable count
organized_data_frame_with_orders['syllable_count'] = organized_data_frame_with_orders.apply(count_syllables, axis=1)

# Filter the DataFrame to only include rows with 2 or more syllables
filtered_data_frame = organized_data_frame_with_orders[organized_data_frame_with_orders['syllable_count'] >= 2]

# Drop the 'syllable_count' column if it's no longer needed
filtered_data_frame = filtered_data_frame.drop(columns=['syllable_count'])

# Display the filtered DataFrame
filtered_data_frame
# Out:
#                                      file_name  song_present  \
# 0       USA5508_45548.32222481_9_13_8_57_2.wav          True
# 1       USA5508_45548.32654069_9_13_9_4_14.wav          True
# 3     USA5508_45548.45040250_9_13_12_30_40.wav          True
# 4     USA5508_45548.45118581_9_13_12_31_58.wav          True
# 7      USA5508_45548.45186354_9_13_12_33_6.wav          True
# ...                                        ...           ...
# 4572  USA5508_45595.54203032_10_30_15_3_23.wav          True
# 4573  USA5508_45595.54213990_10_30_15_3_33.wav          True
# 4574  USA5508_45595.54229930_10_30_15_3_49.wav          True
# 4575   USA5508_45595.54247739_10_30_15_4_7.wav          True
# 4576  USA5508_45595.54294520_10_30_15_4_54.wav          True
#
#                              syllable_onsets_offsets_ms  \
# 0     {'9': [[0.0, 666.5079365079365], [7226.3492063...
# 1     {'30': [[0.0, 331.9047619047619], [844.6031746...
# 3     {'16': [[0.0, 747.4603174603175]], '8': [[747....
# 4     {'8': [[0.0, 1122.5396825396826]], '3': [[1122...
# 7     {'8': [[0.0, 304.92063492063494], [2207.301587...
# ...                                                 ...
# 4572  {'8': [[0.0, 2703.809523809524]], '1': [[2703....
# 4573  {'8': [[0.0, 1845.7142857142858], [5191.746031...
# 4574  {'16': [[0.0, 412.8571428571429], [504.6031746...
# 4575  {'8': [[0.0, 1146.8253968253969], [3812.857142...
# 4576  {'16': [[0.0, 2361.1111111111113], [2482.53968...
#
#                        syllable_onsets_offsets_timebins Animal ID       Date  \
# 0     {'9': [[0.0, 247], [2678.0, 2949]], '8': [[246...   USA5508 2024-09-13
# 1     {'30': [[0.0, 123], [313.0, 502], [966.0, 1017...   USA5508 2024-09-13
# 3     {'16': [[0.0, 277]], '8': [[277.0, 1128]], '3'...   USA5508 2024-09-13
# 4     {'8': [[0.0, 416]], '3': [[416.0, 809]], '0': ...   USA5508 2024-09-13
# 7     {'8': [[0.0, 113], [818.0, 1114], [1865.0, 196...   USA5508 2024-09-13
# ...                                                 ...       ...        ...
# 4572        {'8': [[0.0, 1002]], '1': [[1002.0, 1513]]}   USA5508 2024-10-30
# 4573  {'8': [[0.0, 684], [1924.0, 2014], [2305.0, 37...   USA5508 2024-10-30
# 4574  {'16': [[0.0, 153], [187.0, 241]], '24': [[153...   USA5508 2024-10-30
# 4575  {'8': [[0.0, 425], [1413.0, 2195], [2668.0, 38...   USA5508 2024-10-30
# 4576  {'16': [[0.0, 875], [920.0000000000001, 958], ...   USA5508 2024-10-30
#
#      Hour Minute Second                    syllable_onsets_offsets_ms_dict  \
# 0      08     57     02  {'9': [[0.0, 666.5079365079365], [7226.3492063...
# 1      09     04     14  {'30': [[0.0, 331.9047619047619], [844.6031746...
# 3      12     30     40  {'16': [[0.0, 747.4603174603175]], '8': [[747....
# 4      12     31     58  {'8': [[0.0, 1122.5396825396826]], '3': [[1122...
# 7      12     33     06  {'8': [[0.0, 304.92063492063494], [2207.301587...
# ...   ...    ...    ...                                                ...
# 4572   15     03     23  {'8': [[0.0, 2703.809523809524]], '1': [[2703....
# 4573   15     03     33  {'8': [[0.0, 1845.7142857142858], [5191.746031...
# 4574   15     03     49  {'16': [[0.0, 412.8571428571429], [504.6031746...
# 4575   15     04     07  {'8': [[0.0, 1146.8253968253969], [3812.857142...
# 4576   15     04     54  {'16': [[0.0, 2361.1111111111113], [2482.53968...
#
#                                          syllable_order  \
# 0       [9, 3, 0, 15, 24, 8, 18, 17, 9, 8, 11, 5, 8, 1]
# 1        [30, 16, 30, 9, 8, 30, 8, 30, 3, 0, 30, 30, 8]
# 3                                         [16, 3, 0, 8]
# 4                 [8, 3, 0, 15, 17, 28, 13, 17, 24, 30]
# 7                       [8, 3, 30, 8, 1, 10, 11, 8, 30]
# ...                                                 ...
# 4572                                             [8, 1]
# 4573             [8, 5, 0, 15, 8, 18, 17, 18, 17, 8, 5]
# 4574               [16, 8, 11, 24, 3, 16, 24, 5, 0, 17]
# 4575  [8, 1, 11, 2, 24, 2, 24, 2, 24, 2, 24, 2, 24, ...
# 4576               [16, 24, 16, 24, 16, 24, 8, 3, 5, 0]
#
#                       mapped_syllable_order
# 0                            ZTAGPYJIZYDWYB
# 1                             UHUZYUYUTAUUY
# 3                                      HTAY
# 4                                YTAGIRFIPU
# 7                                 YTUYBCDYU
# ...                                     ...
# 4572                                     YB
# 4573                            YWAGYJIJIYW
# 4574                             HYDPTHPWAI
# 4575  YBDLPLPLPLPLPYBLPMLPLPTLPLPLPLYAIGYGY
# 4576                             HPHPHPYTWA
#
# [4361 rows x 12 columns]

# %% [markdown]
# ### Figure out how many songs to include in each group: (!!! Line 25 needs to be updated witht the surgery date!!!)
# 1) Check the number of post-lesion songs, and the number of pre-lesion songs.
# 2) If the number of post-lesion songs is less than 1/2 of the number of pre-lesion songs, use that as the group size.
# 3) If the number of post-lesion songs is greater than 1/2 of the number of pre-lesin songs, use 0.5*the number of pre-lesion soongs as the group size.

# %%
# Function to calculate group size based on pre- and post-lesion song counts
def calculate_group_size(organized_data_frame, surgery_date):
    # Filter the DataFrame for songs recorded before and after the lesion date
    pre_lesion_songs = organized_data_frame[organized_data_frame['Date'] < surgery_date]
    post_lesion_songs = organized_data_frame[organized_data_frame['Date'] > surgery_date]
    
    # Count the number of pre-lesion and post-lesion songs
    num_pre_lesion_songs = pre_lesion_songs.shape[0]
    num_post_lesion_songs = post_lesion_songs.shape[0]
    
    # Determine the group size based on the condition
    if num_post_lesion_songs < 0.5 * num_pre_lesion_songs:
        group_size = num_post_lesion_songs  # Use the number of post-lesion songs as the group size
    else:
        group_size = int(0.5 * num_pre_lesion_songs)  # Use half the number of pre-lesion songs as the group size
    
    # Print the results
    print(f"Number of pre-lesion songs: {num_pre_lesion_songs}")
    print(f"Number of post-lesion songs: {num_post_lesion_songs}")
    print(f"Calculated group size: {group_size}")
    
    return group_size

# Example usage
group_size = calculate_group_size(filtered_data_frame, surgery_date)

# Function to calculate group size based on pre- and post-lesion song counts
def calculate_group_size(organized_data_frame, surgery_date):
    # Filter the DataFrame for songs recorded before and after the lesion date
    pre_lesion_songs = organized_data_frame[organized_data_frame['Date'] < surgery_date]
    post_lesion_songs = organized_data_frame[organized_data_frame['Date'] > surgery_date]
    
    # Count the number of pre-lesion and post-lesion songs
    num_pre_lesion_songs = pre_lesion_songs.shape[0]
    num_post_lesion_songs = post_lesion_songs.shape[0]
    
    # Determine the group size based on the condition
    if num_post_lesion_songs < 0.5 * num_pre_lesion_songs:
        group_size = num_post_lesion_songs  # Use the number of post-lesion songs as the group size
    else:
        group_size = int(0.5 * num_pre_lesion_songs)  # Use half the number of pre-lesion songs as the group size
    
    # Print the results
    print(f"Number of pre-lesion songs: {num_pre_lesion_songs}")
    print(f"Number of post-lesion songs: {num_post_lesion_songs}")
    print(f"Calculated group size: {group_size}")
    
    return group_size

# Example usage
group_size = calculate_group_size(filtered_data_frame, surgery_date)
# Out:
# Number of pre-lesion songs: 2961
# Number of post-lesion songs: 1374
# Calculated group size: 1374
# Number of pre-lesion songs: 2961
# Number of post-lesion songs: 1374
# Calculated group size: 1374

# %%
def filter_post_surgery_songs(organized_data_frame, lesion_date, group_size):
    # Filter the DataFrame for songs recorded after the lesion date (post-lesion)
    post_lesion_songs = organized_data_frame[organized_data_frame['Date'] > surgery_date]
    
    # If the number of post-lesion songs is greater than or equal to the group size,
    # select the first 'group_size' number of rows (songs)
    filtered_songs = post_lesion_songs.head(group_size)
    
    # Print the results for verification
    print(f"Filtered {group_size} post-surgery songs:")
    print(filtered_songs)
    
    return filtered_songs

# Example usage
group_size = calculate_group_size(filtered_data_frame, surgery_date)  # Calculate group size
post_surgery_songs = filter_post_surgery_songs(filtered_data_frame, surgery_date, group_size)
# Out:
# Number of pre-lesion songs: 2961
# Number of post-lesion songs: 1374
# Calculated group size: 1374
# Filtered 1374 post-surgery songs:
#                                      file_name  song_present  \
# 3138  USA5508_45587.32362304_10_22_8_59_22.wav          True
# 3139  USA5508_45587.32378803_10_22_8_59_38.wav          True
# 3140    USA5508_45587.32408585_10_22_9_0_8.wav          True
# 3141   USA5508_45587.32417841_10_22_9_0_17.wav          True
# 3142   USA5508_45587.32455362_10_22_9_0_55.wav          True
# ...                                        ...           ...
# 4572  USA5508_45595.54203032_10_30_15_3_23.wav          True
# 4573  USA5508_45595.54213990_10_30_15_3_33.wav          True
# 4574  USA5508_45595.54229930_10_30_15_3_49.wav          True
# 4575   USA5508_45595.54247739_10_30_15_4_7.wav          True
# 4576  USA5508_45595.54294520_10_30_15_4_54.wav          True
#
#                              syllable_onsets_offsets_ms  \
# 3138  {'8': [[0.0, 2253.1746031746034], [5140.476190...
# 3139  {'8': [[0.0, 1700.0000000000002]], '1': [[1700...
# 3140  {'24': [[0.0, 855.3968253968254]], '8': [[855....
# 3141  {'8': [[0.0, 806.8253968253969], [3105.8730158...
# 3142  {'8': [[0.0, 1011.9047619047619], [2795.555555...
# ...                                                 ...
# 4572  {'8': [[0.0, 2703.809523809524]], '1': [[2703....
# 4573  {'8': [[0.0, 1845.7142857142858], [5191.746031...
# 4574  {'16': [[0.0, 412.8571428571429], [504.6031746...
# 4575  {'8': [[0.0, 1146.8253968253969], [3812.857142...
# 4576  {'16': [[0.0, 2361.1111111111113], [2482.53968...
#
#                        syllable_onsets_offsets_timebins Animal ID       Date  \
# 3138  {'8': [[0.0, 835], [1905.0, 2271]], '1': [[835...   USA5508 2024-10-22
# 3139          {'8': [[0.0, 630]], '1': [[630.0, 1124]]}   USA5508 2024-10-22
# 3140          {'24': [[0.0, 317]], '8': [[317.0, 623]]}   USA5508 2024-10-22
# 3141  {'8': [[0.0, 299], [1151.0, 1762]], '11': [[29...   USA5508 2024-10-22
# 3142  {'8': [[0.0, 375], [1036.0, 1363], [2572.0, 38...   USA5508 2024-10-22
# ...                                                 ...       ...        ...
# 4572        {'8': [[0.0, 1002]], '1': [[1002.0, 1513]]}   USA5508 2024-10-30
# 4573  {'8': [[0.0, 684], [1924.0, 2014], [2305.0, 37...   USA5508 2024-10-30
# 4574  {'16': [[0.0, 153], [187.0, 241]], '24': [[153...   USA5508 2024-10-30
# 4575  {'8': [[0.0, 425], [1413.0, 2195], [2668.0, 38...   USA5508 2024-10-30
# 4576  {'16': [[0.0, 875], [920.0000000000001, 958], ...   USA5508 2024-10-30
#
#      Hour Minute Second                    syllable_onsets_offsets_ms_dict  \
# 3138   08     59     22  {'8': [[0.0, 2253.1746031746034], [5140.476190...
# 3139   08     59     38  {'8': [[0.0, 1700.0000000000002]], '1': [[1700...
# 3140   09     00     08  {'24': [[0.0, 855.3968253968254]], '8': [[855....
# 3141   09     00     17  {'8': [[0.0, 806.8253968253969], [3105.8730158...
# 3142   09     00     55  {'8': [[0.0, 1011.9047619047619], [2795.555555...
# ...   ...    ...    ...                                                ...
# 4572   15     03     23  {'8': [[0.0, 2703.809523809524]], '1': [[2703....
# 4573   15     03     33  {'8': [[0.0, 1845.7142857142858], [5191.746031...
# 4574   15     03     49  {'16': [[0.0, 412.8571428571429], [504.6031746...
# 4575   15     04     07  {'8': [[0.0, 1146.8253968253969], [3812.857142...
# 4576   15     04     54  {'16': [[0.0, 2361.1111111111113], [2482.53968...
#
#                                          syllable_order  \
# 3138                        [8, 1, 4, 24, 21, 2, 24, 8]
# 3139                                             [8, 1]
# 3140                                            [24, 8]
# 3141                                   [8, 3, 8, 0, 11]
# 3142  [8, 11, 5, 0, 17, 0, 3, 8, 1, 2, 24, 2, 24, 2,...
# ...                                                 ...
# 4572                                             [8, 1]
# 4573             [8, 5, 0, 15, 8, 18, 17, 18, 17, 8, 5]
# 4574               [16, 8, 11, 24, 3, 16, 24, 5, 0, 17]
# 4575  [8, 1, 11, 2, 24, 2, 24, 2, 24, 2, 24, 2, 24, ...
# 4576               [16, 24, 16, 24, 16, 24, 8, 3, 5, 0]
#
#                       mapped_syllable_order
# 3138                               YBVPMLPY
# 3139                                     YB
# 3140                                     PY
# 3141                                  YTYAD
# 3142                       YDWAIATYBLPLPLPY
# ...                                     ...
# 4572                                     YB
# 4573                            YWAGYJIJIYW
# 4574                             HYDPTHPWAI
# 4575  YBDLPLPLPLPLPYBLPMLPLPTLPLPLPLYAIGYGY
# 4576                             HPHPHPYTWA
#
# [1374 rows x 12 columns]

# %%
def filter_surgery_songs(organized_data_frame, surgery_date, group_size):
    # Filter the DataFrame for songs recorded after the lesion date (post-lesion)
    post_lesion_songs = organized_data_frame[organized_data_frame['Date'] > surgery_date]
    
    # Select the first 'group_size' number of rows from the post-lesion songs
    filtered_post_surgery_songs = post_lesion_songs.head(group_size)
    
    # Filter the DataFrame for songs recorded on or before the lesion date (pre-lesion)
    pre_lesion_songs = organized_data_frame[organized_data_frame['Date'] <= surgery_date]
    
    total_pre_lesion_songs = len(pre_lesion_songs)
    print(f"Total number of pre-lesion songs: {total_pre_lesion_songs}")
    
    if total_pre_lesion_songs < group_size * 2:
        raise ValueError(f"Not enough pre-lesion songs to split into two groups of size {group_size}. Total available: {total_pre_lesion_songs}")

    # Select the last 'group_size' number of rows for the latest pre-surgery songs
    latest_pre_surgery_songs = pre_lesion_songs.tail(group_size)
    
    # Select the 'group_size' rows just before the latest pre-surgery songs
    earlier_pre_surgery_songs = pre_lesion_songs.iloc[-(group_size * 2):-group_size]
    
    print(f"Number of latest pre-surgery songs: {len(latest_pre_surgery_songs)}")
    print(f"Number of earlier pre-surgery songs: {len(earlier_pre_surgery_songs)}")
    
    # Create cell arrays (lists) to hold the mapped syllable orders for each group
    mapped_syllable_orders_post = list(filtered_post_surgery_songs['mapped_syllable_order'])
    mapped_syllable_orders_latest_pre = list(latest_pre_surgery_songs['mapped_syllable_order'])
    mapped_syllable_orders_earlier_pre = list(earlier_pre_surgery_songs['mapped_syllable_order'])

    # Print the results for verification
    print(f"Filtered {group_size} post-surgery songs' mapped syllable orders:")
    print(mapped_syllable_orders_post)
    
    print(f"Filtered {group_size} latest pre-surgery songs' mapped syllable orders:")
    print(mapped_syllable_orders_latest_pre)
    
    print(f"Filtered {group_size} earlier pre-surgery songs' mapped syllable orders:")
    print(mapped_syllable_orders_earlier_pre)
    
    # Return the lists of mapped syllable orders for each group
    return mapped_syllable_orders_post, mapped_syllable_orders_latest_pre, mapped_syllable_orders_earlier_pre

# Example usage
group_size = calculate_group_size(filtered_data_frame, surgery_date)  # Calculate group size
mapped_post, mapped_latest_pre, mapped_earlier_pre = filter_surgery_songs(filtered_data_frame, surgery_date, group_size)
# Out:
# Number of pre-lesion songs: 2961
# Number of post-lesion songs: 1374
# Calculated group size: 1374
# Total number of pre-lesion songs: 2987
# Number of latest pre-surgery songs: 1374
# Number of earlier pre-surgery songs: 1374
# Filtered 1374 post-surgery songs' mapped syllable orders:
# ['YBVPMLPY', 'YB', 'PY', 'YTYAD', 'YDWAIATYBLPLPLPY', 'PWADYTYGYCIJIYD', 'AWLPYBLLPLPPULPLPLUPYVPY', 'ADTHPLPLYY', 'PDTYWOYA', 'AGYIA', 'AYBWLPLPLPY', 'HAZDTYPHPHPYDCY', 'YCDWY', 'HGYGIPJIJYHDPTYNBLPLPLPLPYYBLPLPUDTYWAI', 'PWYGIJIIJIPYDTOYAGPBPLPLPY', 'YCDTYBLPLPLPU', 'HPYNHDTHOPHPLYQO', 'HPHPOPOYDYBLPLPLU', 'OAPWDTYWAYIFIJIJIJIPOPY', 'HAIJIFIJIJIPOPOPHPOPYDYTW', 'POPY', 'HAPHPHPYVYDY', 'AAGW', 'GBLPLPY', 'YB', 'VWAWPAHPHPYY', 'YDTUAYCG', 'HPQPOPYDTYBU', 'GYBVPLPLPUY', 'YYAWYWGIJI', 'HUNCHDTAWZYGP', 'HYPW', 'ZLPLPLPOPYWDYAWYTAYCWYB', 'HCDNZ', 'ZYBCVPD', 'PIPYWYWATYYG', 'HHPYWAP', 'HNHYCY', 'ZBLPLPLDPTHPHPYC', 'ZTCD', 'YBVZV', 'HCDTYWAUZ', 'HCDTYZB', 'ZDTYCWA', 'YCDTYWAIZJIGYDY', 'ZWACD', 'YDZTHPC', 'YCDTYZ', 'YBLUCDTHPYZWY', 'HQOPNHY', 'AYBLPLPLPYW', 'HZCDY', 'AWYWYBLPLPLPY', 'YWYYAIGPY', 'WBLPLYYA', 'PWAIPLPLPYLPLPYW', 'YAIJIPYTYWDT', 'PU', 'AAIPYDTYBIPLPLPLPY', 'PIBVYYWA', 'PDTYAIJIYJIPY', 'ZYTCYAIPD', 'IPY', 'HPHPYBLPLPLPLU', 'HPHPYDTYU', 'GYI', 'IAPIJIPYDTYLPLPLPLPYW', 'YUYZC', 'AYYAIJIJIJIJIYWDTYG', 'YCDTGZY', 'HPHPYBVY', 'HYDTYG', 'ZWACY', 'YALPLPUW', 'ZTYZCCD', 'ADYGYWAY', 'YGYWAW', 'ZGTCHPHPYDTDY', 'ZTYCBVPUD', 'ZTNHPCYPYYD', 'ZTYBCVGID', 'YDTYWAI', 'HPNHPHPHYDYTYBV', 'ZTCD', 'AYBPLPLPWLPYDYA', 'AWALPLPLPOPYG', 'ZDYTHUPHPYY', 'ZTYCWAD', 'AYV', 'YCD', 'AYBILPLPU', 'YTYGD', 'YLPLPLPLPUYBPLPLPLPLPYAWATB', 'ZDTC', 'ZBTYBCVYD', 'HWACDTAZIJIYPHPY', 'HZDTYWALPLC', 'HUYHDPTPYV', 'HPHPYB', 'YDZTAWU', 'YYDYVB', 'YDYBLPLPLPUPYWY', 'HCUZ', 'YBVYWAIFIUTYWAWY', 'QAWDTHZPHPYDYC', 'YDTZYBC', 'CTDYWAIY', 'HHPYDTYWP', 'ZDTYWAC', 'PYOPDWAI', 'ZTCHPHPYDWDY', 'TWYGYBLPLPLPYWYTPYBHYPYDYWAH', 'HCDTYWNAZ', 'HCYDWYBNZ', 'HYHNPNHP', 'YDZTHPYBC', 'AWTYBLPLPLPLPLUPY', 'ZTCD', 'HCDTAWAZ', 'PWTAY', 'ZDTYCZCDYB', 'YDTYB', 'ZC', 'GWTAGIJIYAIGIYBDTYBLPLPYDTYAIJIGPYBLPLPLPYVWALPLPLPMLPYWDPTYDYYA', 'AWIJIJIYYBPLPLPLPYWA', 'PAGIJIJIPYYWYBLPLPLPYTAGY', 'APYWYALPLPLPYAIJIYBYLPLPLPLPYDYBPLPLPIL', 'HGYOYZCDTAIJIJI', 'YALPLPLPOPCYTYGDIJIJIJIYWAITJIGYALPLPLPLPYAZIJIJIY', 'HJIJIGYPQOPQOPYTAIJIJIJI', 'HYZCDTGP', 'GVPY', 'YDTAIG', 'GWALPYYAIJIJIGIPY', 'ZYAYGYDTTYGIPYWAPLPLPYBPLPLPLPYDYALPLPLCPYHWYBLPLPLPYPYW', 'HCZ', 'UDTYYG', 'GGYALPLPLPYWYBPLPLPLPLPYDYWAYIJI', 'VTPYGY', 'GIJIJIYDWAIP', 'HYNBVPHGHPYWYAPLPLPLPLP', 'HOPOPYT', 'HPY', 'ZADTHCPY', 'ADYAWIJIJIJIPYTYYGYWAIJIJIYBALPLPLPLPYWYAIJIPOPOPOPYVGIJIY', 'UDZTC', 'PTAIJIYJIJIJIY', 'ZWAGYWYDTHPHPCY', 'ZADWYGIJIJIPYWATGIGIJIJIYYCPHPHPYT', 'VGYDYDYWDCDYALPLPLPLPLPYDYYTAWPY', 'HPHPHPYDYBP', 'PYWLPLPLPTAWAGYIJIP', 'ZYDWAIGYBTLPLPLPYWYVCAIYIPHIPHP', 'AWYGI', 'YCDTYALPYBLPWTHPHPY', 'HPLPLPQOPYTAWYLPLPLPYPHPHPYCDTYWA', 'HIJIJIYDYBLPLPLPLOPHPYQOPAWYIJIJIJIPOPYYWYNGH', 'HPYPHPOPOPOPOYDYBLPLPLPML', 'POPWAIJIYJIJIPY', 'PPLPLDTAYYWLPLPL', 'PLY', 'HLHPLPLPLPPYHPOPOPYDTAP', 'ZVDBTUCYPHPHPYB', 'HLYPWAYIJIGYWYBPLPLPLPYDYDYDYDTYBPPLPLPH', 'PDTAWYWAYGY', 'PYWAHP', 'AWDY', 'HCDTZAIJIJIJIJI', 'PPLPLPLPUWAQPYIJIPYB', 'HZY', 'ZDTC', 'PTAGYWAIBVYYD', 'YYDYAIJIPYWTAIP', 'HPHPYPOPYBVPLPLP', 'YBVYDYG', 'HYAWYPB', 'YWAIGYWYDBLPLPLPUTAIPY', 'PCDTHZY', 'YBVYCDTYGYHPZHPY', 'VWAIPYWALPLPYWYAYY', 'UYVGCDTAWYZB', 'ZUHYCUYPHP', 'YYDYCAWYGDIJFIJIFIPOPIYWYTGYYWUAZYPOP', 'HOPOPYT', 'HHPYGYP', 'YB', 'YPO', 'AIYWAPLPLPLPLPY', 'ZBDTHCPHPY', 'ALPLPLPYBPLPLPLPLPUGYDYBI', 'YB', 'AWYG', 'HIJIJIJIPYDPTYHPGIYYDWYWA', 'IJIYAI', 'YAWYBPLPLPY', 'AYWBVYTA', 'ZYDAWYTHPHPCYV', 'YDTZYBLPLPLPCL', 'HBPLPLPLPQOPOPOYWAGIGIJIPHPYDT', 'GLPLPLPOPYWAIYY', 'ZPOPDTYWCAIJIJIJIFI', 'PYBVOPY', 'YDTZHC', 'ZIJIJIDYWYYBCVYDWA', 'ZTCUYD', 'HYGYDCWAIJIYDTYPZYD', 'ZYBC', 'YWTAG', 'GDTYGYY', 'HWYACPLPLPLPYDWYBPLPLPLPYAYLEPLPLPLWAZIGY', 'YTYALYPLPLPLPYWYBLPLPLPLPYWALPLPLPBLPYVUPY', 'HVPYHPYDYTYB', 'HJIPHPHPYWAI', 'YAWYAIJIJIJIPYBPLPLPLPLPTYWAIJIJIHPHPYDY', 'HYPOPYWALPLPLPQPOPOP', 'YIFIJIFIJIJIYWAA', 'ZDDTYGIJFIJIJIYBYTYCWAIY', 'HNHCDTNHZ', 'YYVDWYB', 'AYI', 'YIYWAAIY', 'YDTYWAZIJIJIC', 'HPYPH', 'HCNHYZNZ', 'ZAIDGYTYBCVYW', 'AIJIPOPY', 'HPHPHPYWY', 'YB', 'GWYBY', 'ZADTCHPHPYW', 'CYDAWYBLPLPUYATYPHPYW', 'HYTAIJYPU', 'ZYWADIJIJIJIPYDYGYTWAPUCHPYT', 'YBVYWALPLPLPYTTYAIJIJIJIAGY', 'HYDPHP',  ...
# Filtered 1374 latest pre-surgery songs' mapped syllable orders:
# ['YGYDBPLPLPLPYWAIJITJIGPYZWAGFICJI', 'HCDZ', 'HYYWYVYBLPLPLPYPIFIJIJIJIJIGPYWYTWLPLPLPLP', 'HPQOPNHOPQPOPOPYBPLPLPMLPLPY', 'ZYYAOPIJIJIJIQPYWABTCAIJIJIJIP', 'HJIJHIPPIGHYPQOPTYTYTYTYHPYPNHWAPIJI', 'HPYPIYDYLPLNPOLPPLPLPUQOPHIYDYGIJIJIJIJIJIG', 'HPOPOPY', 'OYWYVPIYWOPTYGYIJIJIJIPP', 'HIJIJIJIYDYAJIJIJIPOPYPYWYG', 'HLPYPHWYAIJIJIJIPOPYWYYTYNBLPLPLPLP', 'HYZCDTY', 'HOPYDYPQOPYWAIFIJIJIP', 'YWYT', 'HYWYPYDYBV', 'HLPLPLPLPLPYWPAHLPPLPLPLPYYTWA', 'ZADIJIJIGYWAGIPYTBPLPLPLPYCWYBPLPLPLPYAGYW', 'HLPLPNLPYPHHPYDYTYWA', 'HHPHPYDYN', 'HNHPHOPOPYPHP', 'HPOPYWYBLPLPLPLPLPLPLY', 'HJIJIJIJIJIJIGPNPHYPWYOPQOPOPYWAI', 'HOP', 'PJIPPOPYOWYYWTOPAIJIJIJIJIJIO', 'HPLPLPQPIUYWYPHPOPYWNTHB', 'HNHPHPYZCY', 'HPIPIYWAU', 'HJIYWYPYWAIJIJIJIJI', 'HIFIJIJIYPHPHPOPOPYWVG', 'HP', 'NHIPYWYAPLPLPLPLPLPUPOPNYHWTYA', 'YAFIJICPOPDYVHNHUYUZDWT', 'HHPYWYNPH', 'CYD', 'ZDIGYBLPLPYTWYBPLPLPLPLPLPYWAGIGIGIJIJIYCHYWA', 'ZDTC', 'ZDYCBVY', 'HNHPHYWAPIJIU', 'HPIJIPHPYBYLPLPLPYWYAZIJFIJFIJIJIJIJYCYTWPAH', 'HIPYWYALPLPLPLPPYWA', 'HPZC', 'HP', 'HGIJIJIYWAIGYPWYBLPLPLPYYWVPY', 'HGIJIJIYWPLPMLPLPIJIYWAIJIQPPHPYAWY', 'HPOPQPVHIY', 'HYYAIJIJIJIJIJIJIGP', 'HYOPQPOPYWAIJIJIJIJIPJI', 'HIJIPQPYPBLPLPLPLPLPQPOPQOPOYWA', 'ZDWCA', 'AHYYWAIG', 'HHYPWAGJIJIJIYJIFIJIPYWYWAPFG', 'HIJIJIJIPNYHTYPQOPYWA', 'ZWYDGIJIJIJIYTCHYUPHPHPOPY', 'PYAIYTYWYALPLPLP', 'ZDYBCVY', 'HAIHJIJIJIJIJIJFIPYAWPYYDNYAW', 'HPYWAIJIJIJIJIJIJIY', 'ZDTHCYB', 'YG', 'ZDWYAWAGFGIWTCAGY', 'ZYWYBTLPLPLPLPCZYCWYYGYDWA', 'ZDYWYTAWTAPLPYYACWAIJIJIJIP', 'YTWYGY', 'ZWAYWCAIY', 'YWYGIJIJIJIPYWYWAIY', 'HIJIGYWAWPHPHPYWA', 'HPLPLPLPUPHPOPYWYB', 'PYLPLPLPLPYWAQPOPWYB', 'PY', 'HPHPHPUYWYGT', 'HPOYBPHNHP', 'HVPNPHHPOPOPYWYB', 'HWYIJIJIPOPQOPYWDTA', 'YWAIJIJIJIJIJ', 'HYGIJIJIJIJIPHYPOPOPYWANW', 'HPNIYWYHPYBLPLPLPLPLPO', 'YWDY', 'ZYC', 'HPQOPYWATY', 'YAGYWYBPLPLPLPLPLPYWYTBYBLPLPYVYW', 'YAIPYWYBPLPLPBGYW', 'YDYWDTYGPY', 'PDYHHWPAPY', 'HPQOPYTWA', 'HLPLPYWAIPJIFIJIYWYVOYWALPLPLP', 'HHWPYBHPYCYBVYP', 'HWAGYPIJIJIYNHPHPYVY', 'YWAIJI', 'HQPOPOPYOP', 'HALPLPYLPLPPHYWYTNAW', 'YTAWLUBVYWY', 'YYZCWNHY', 'YCZ', 'HPOPOPYTWYUZ', 'HAYCIJIJIPYWYYABLPLPLPLPLYZPQPOPYW', 'HUNHPHPHPOPYBLPLPLPLPY', 'YCZ', 'HYNHWNHAH', 'HJIJIJINYHWPALPLEPLUYBPYPI', 'YBVDWATWY', 'YWYBGYWA', 'NHBPYDTYWA', 'HPHPYWYNBPLPLPLPHU', 'PWYA', 'HAIPPJIYWYWAI', 'HWAPYNBHVY', 'HIJIJIJIYYWYAPLPIGYWYBLPLPLPYWTPYHGP', 'HFIJIJFIJIUHPHPHPYNWA', 'HUYHPHBPVPYHPWAGIJIPYWNAI', 'HVYPHPHPYZCWYB', 'HZCDYWANHHY', 'PYATIJIPIJIJIYWYBOPBVOPYWY', 'HAIJIJIJIJIJIPYWYTPYAW', 'HGPHPYWNAHI', 'YYCYWYGPZIJIJIJIYW', 'YCYDYTAZWA', 'HY', 'YYBVYW', 'HYPHPOPYBV', 'YJIPOPYWYWAIGIJFIJI', 'ZC', 'HPHPHPOPVZCYD', 'YWYTY', 'ZYCWATYD', 'YWAIJQPIYWYDYTYGIJIY', 'ZDTC', 'YW', 'HYWPNAHP', 'GY', 'YBV', 'HYWA', 'HPYBV', 'HPYDTYNYHGYWA', 'ZDTC', 'YB', 'ZDWAC', 'ZBPYDWYAGJFIJIWPYWYTBACHY', 'HHIJIJIJIJIPQOPIYWYPOPQOPOPYNWYA', 'HYWAP', 'HQPQPOPOPYBVY', 'HPQPOPOPYBVY', 'YTAWY', 'HHPP', 'YUYBZ', 'HYZCYB', 'ZDC', 'HPHP', 'YB', 'HHYNTY', 'HYAPIJIGYOPWDYQBPOPLPLPLPLPYYWAIJIJIJIFIJ', 'HPOPHYTYWNY', 'ZYWDAIJIPOPYYWABTCAG', 'HWYYWAIJIFIJIJIPY', 'HLPLPMLPLYWAIJIJIPHPYDTYB', 'YTYD', 'HPYWYPHPHPOPYWAI', 'HIJIJIJIGOPOPOPYWYBPLPLPLPYWPAHPIJIJIPYBOPYWA', 'HWYAIOPJIJIJIYOUVPYQDOWYPGJFIJOIJIPQPOPPYDTYYTY', 'HJIYBPLPLPLPLPYPYWYTPOPGQPOPOPOPYWAI', 'OTAPIJIJIJIJGPYWYABLPLPLPYDYTYWOAPIJIJIFIJFIJIYY', 'HYVYUYAW', 'HNIJIJIJIJIJIJIJIPYHTPHPYWA', 'HZWAICPYDYWAYIJIJIJIY', 'YWYTAGY', 'HWLPLPLPLPNLPHLPLYUYBPLPLPLPYPHPOPQPOPOPIJIJIYT', 'HYTYPGYW', 'HPJIJIJIYQOPWVYDYOPOPYTWAPLPLPOG', 'HJIJIJIJIYPHPHPYWAG', 'HOPOPYWYTPA', 'HPJFIJIJIYWYPQOPOPYWAIJIJIJIJIG', 'HYWAIJIJIJIJIGPYDYBV', 'POPY', 'HGPLPLPHLPLPPUHPYTWYP', 'HDYPTHYY', 'HY', 'HVYWYTWLPLPLPPLPYHPHPHYDYTYB', 'HAWLPLPLPLPYPHPHPYWYT', 'HPVYDYYAPPLPLPLPYYWAI', 'YBVYZCY', 'HPYU', 'HPOPYC', 'ZWAIGYDYTAGIJIFIJIGYWACYPHPHPYD', 'VGYDWYBPLPLPLPYWYCTWYAGYI', 'YZCCYTHPZY', 'HYWYP', 'ZDTYC', 'ZWADTCYPHPHPY', 'HYPZCDYHPBHPHY', 'HTYALPLPLPLPYWAPBVY', 'HJIYYPWYYWLPLPLPLPLPYJIJFIJFIJFIJI', 'HZHCDTYBNLPLPLPULPLPEPE', 'YCYZ', 'PTAWLPLPLPLPY', 'HDAYLPPLPYPYWYYBPLPLPLPLPLPYWYALPLPLPYWAIJIFIJIJIY', 'HWTHPYYWAPLPLPLPYN', 'YDYZC' ...
# Filtered 1374 earlier pre-surgery songs' mapped syllable orders:
# ['YDWYADBLQPIPIPIPIGZYYBZGIJIGPYTC', 'HGYBPUYNWYHTAP', 'YB', 'YB', 'HPYTDY', 'YBUYTAY', 'YB', 'YB', 'YAGPUYBBGVHPHPYDW', 'ZIJIPVYBUYUAJIJGBTPHPHPHPHYUYYPGPGJ', 'VYUTAWYDYJGIJIGQUYWYTBAGJAPYU', 'HGYTNHABP', 'YBUYW', 'ZWYAPFGJFPYUWYTAPJFATACYGIGJFIJUYDBY', 'HHFJIFIGDYAIGFGFIJIJQJPYPYHVYTAN', 'HPFPGVQVPUYTAP', 'YYBUYUDB', 'HPV', 'VYATWYAPJIJIPS', 'ZGIVPYHUYDTAOGJFPTBPHPYHYUA', 'HNHNH', 'YTADYAB', 'YABUHPYT', 'UDYY', 'HZC', 'YBWAGIGJGAYPQPQYA', 'YTAGQIPY', 'YTDAUYT', 'YB', 'ZTACD', 'HYB', 'HYDTAB', 'HPHPYTAFGFIJFIJIFIJPIRIPIJIG', 'YYWYTPUAWYTBPLPLPGI', 'HPHPY', 'HUYTAYDWYPOPLUNYPUH', 'YDTAZPYATC', 'HPHP', 'DC', 'CU', 'PYTAGJPYB', 'YTAGPYB', 'HYTAPGHIPIFIPP', 'HDTAGJIJILIJPLPYTAGJRPYW', 'PUYPTGHPPHYDTA', 'YCDGYAGAGAGYJYY', 'YUATYGIFGFGJGJPYBAY', 'YB', 'YCDTAZ', 'HNHPUYGYTA', 'ZTD', 'GHPHUYP', 'YATAYHT', 'YDTW', 'YUB', 'ZTYBCD', 'ZTAWYBCAGPDU', 'HUZCDTAGJFJIJIJIGPYT', 'ZWYWYWACD', 'TYGJGA', 'HHZCDYN', 'HBUY', 'YB', 'ZYTBCD', 'YTA', 'WAT', 'YBPLP', 'YAGJPYBD', 'ZDWAGJFYCY', 'YWB', 'ZTCD', 'ZCY', 'YWDWDWAWAG', 'YUDYBAZ', 'YDWYTAGIGIG', 'CDY', 'YB', 'YGB', 'YTB', 'ZYBCD', 'ZYWTAACGYBDGV', 'YGIJGJGBGYWA', 'HPHPHPYTAGIJI', 'UCYYWUAYUZ', 'HNHPHPGYUYTBP', 'HGYWYDNYHP', 'YBT', 'ZWYBYCUZVYDB', 'ZTYCAIGYD', 'HYQPUYDWYAYPTAJIGJGJFIJIFIJIP', 'ZAWYBGCYDT', 'YB', 'HPHPHPYDTBLPLPHPI', 'HYV', 'HGIJIDGYYBZHPGYCA', 'HYPYWYAIFIGJIJIP', 'ZTAGCD', 'NYZNHCDTHBWYTAU', 'YCDTALPZ', 'YBY', 'ZYWYTTACGYBDGI', 'HAHGPYNBHVPYNHPT', 'ZYBCYDTA', 'HGYPPHPHYPWAH', 'VWDTAIJIGY', 'YYDTAGU', 'PPHUHPL', 'UYUYUY', 'OYWYAP', 'HYPBNHYPGVU', 'YT', 'HOPOPOPY', 'HOPQOPYDYB', 'ZACFIJFIPIPIGDPYWDYY', 'HNHPYAGA', 'YTYG', 'YAIFIFIJFIJIPYWYB', 'YBY', 'HUYTAGJFIPIU', 'HHYWDVGN', 'YGPHPHPHZDTYHZ', 'YW', 'HGPVYZCDTAIJIGPYWYWA', 'ZCYTD', 'PWDTYB', 'VPUYA', 'YBPHPHPYWYTB', 'PBUY', 'HPHPYWYTB', 'PTY', 'PTY', 'PUHWYWYWYWYWDTY', 'ZTYCBD', 'CTYHVD', 'ZYCD', 'ZBYDCY', 'ZTACD', 'YWAGIJIJPJPYDYBVAIGIJIJFIJFY', 'VAFIJIJFGIJGPYGIR', 'HYTPAQGJPOIPIP', 'PYPWYTQP', 'YTAY', 'HFIJPQGYUWYOPQPOPVUYPFIJIYDYTA', 'YGIJFGYBULUPGPYBWYAGIJIJFIPYYGYWDTA', 'HTYANHPYBGVYD', 'YBUY', 'YPOPGYDYTA', 'HPNYHWYWYANHFIJFIJFI', 'HPLPLPYTAPYATYB', 'PWQYOAOPPY', 'YYWYAB', 'PAGYAGVYWT', 'ZGTYBCYDA', 'ZAYBCYUPVYWDT', 'HWAGPJHPYTGY', 'HYAJAJPFGP', 'HPQPUZCDYA', 'YDTW', 'CTD', 'YYDTZCYC', 'YB', 'YT', 'CBYWDYAY', 'YTAG', 'YT', 'HPHPHPOYWDPH', 'PUYBQAOPGIJFIJFIU', 'YAYTBYUYU', 'VGJIJIJFIJIGGTLPLPLYPFIJFJYWYYA', 'GBY', 'HPOPOPQPQPIYWY', 'OWYWYDWODAPIJIJPFGPGJIJIJIYY', 'HOQOPQOPYBNH', 'PTAQPOPIJIJIJGYQY', 'YTDWYWYAB', 'YGPUTAIGPYWYA', 'QPDYTABY', 'PWYDYBPWYTYAYGJIJIPQPY', 'PDTOBPOPOPY', 'HPHPHPOPY', 'PYPQTOVO', 'POPAIFIJIPYIGYDY', 'PYODPAQOP', 'HYT', 'HDYY', 'ZDYYTA', 'YBWTABLPLPLPLPLPYDY', 'PTABOYYPHPHPYD', 'YAW', 'YDYTAGVY', 'YBY', 'HOPQGYDYBNH', 'YOPHPHPYTDYBLPUU', 'HPHPHPLPQPYBY', 'YLPLPLPYDTAAIPYDWYB', 'PDYOPTAOYGIJIJIJFIPQPY', 'HPHPYTYGYGY', 'YTAFIJFIJFIGJIPQPYBPLPLPLPTDYWYAJIJIJIJIPLPLPLPLPY', 'PY', 'YBY', 'YTBCGYD', 'YPYTAHZ', 'YB', 'YYBUVYWYB', 'PPQOPYPQTOOAPYQO', 'HGPYTAIJFIPJPFIPU', 'ZTAGCYDWAB', 'OIYWPDYAG', 'PFIJIJIPYDYPNHPHPHYGYDWAFJ', 'YB', 'YYBT', 'ZAGYTBCPHNHDPNHPYW', 'YYBD', 'PYYW', 'YB', 'HTYBGJIGIAYBGYD', 'YU', 'YB', 'YWYTAPHPLPLPJIJIJIGVY', 'ZTCYGUGUGUD', 'HGIJGIPYDTYBLPLPLPLPLYWAGJIJIYBPHPHPHPYWA', 'HBY', 'YT', 'YTB', 'YTDAIG', 'HYNH', 'YTAGYDWA', 'ZWYBLPLPLPLYPYTAIJIJIJIJIJIUYUYUWDTBLPTACGDJIJIJIPY', 'VZCY', 'PTYYBPHPG', 'HHIYPPDYAB', 'YB', 'YIJIJFIPYBPLPLPLPTAGIPIYWA', 'YAGYWBDYZHNHYT', 'YB', 'YTAG', 'YAGJIJAIFIJPJLJPLPLPLPYPUPY', 'YB', 'ZIJIGTYWAGADGYDWYAGJFIJ', 'HPHPHPHUYB', 'YB', 'CTYBD', 'YTWAGYB', 'HPHPYWALPLP', 'HIJFIJFIPYDYBPPHPYWAG', 'HYHPHPHPNHYWT', 'YTAGJQ', 'HP', 'HYUWAGJIJIGIJGYDWPAIJFIJFIP', 'YUYWYT', 'PGYIJFGIJ', 'PYTAQOIJIJIPOPJIPYQOP', 'YBTAGYWAPLPLPLPYYZCDTAGY', 'HTPDWAY', 'YYDYDAZC', 'HPYT', 'YTABYWAGIJIY', 'YBUY', 'YTYB', 'YCYZ', 'YTAGJFIJFIFIPY', 'HYTAIGIAIJIJIJGU', 'YBYPHPHPHPHY', 'YT', 'ZTCD', 'HPHPHPYWYBPU', 'HNHPYTDWAGY', 'HDYYBLPUZCYDAIJIJIGYT', 'YTAGIJIPYWYAGIJIJIJFIJIADTAGY', 'ZDYBYC', 'PTUYDYYAIJIJIJIP', 'YB', 'YBY', 'YB', 'HPZYTGIJIA', 'HNHPHPLPYTAI', 'HNHPYTIJIJIGYWYD', 'HQDWA ...

# %%
# print(len(mapped_post))
# print(len(mapped_latest_pre))
# print(len(mapped_earlier_pre))

# import pandas as pd
# import scipy.io as sio
# import os

# import pandas as pd
# import scipy.io as sio
# import os

# # Function to save each group into separate .mat files
# def save_group_to_mat(mapped_syllable_orders, group_name, animal_id, save_dir):
#     # Ensure the save directory exists
#     os.makedirs(save_dir, exist_ok=True)
    
#     # Prepare the data as a dictionary for saving to .mat format
#     data_dict = {'mapped_syllable_order': mapped_syllable_orders}
    
#     # Generate a file name based on the animal ID and group name
#     file_name = f"{animal_id}_{group_name}.mat"
#     file_path = os.path.join(save_dir, file_name)
    
#     # Save the .mat file
#     sio.savemat(file_path, data_dict)
    
#     # Print confirmation
#     print(f"Saved {file_name} to {file_path}")

# # Example animal ID (assuming it's consistent across the dataset)
# animal_id = "USA5443"

# # Directory where .mat files will be saved (change this path as needed)
# save_directory = "/Users/mirandahulsey-vincent/Desktop/DECODER_cell_arrays"

# # Save the post-lesion data
# save_group_to_mat(mapped_post, 'post_lesion_songs', animal_id, save_directory)

# # Save the latest pre-lesion group
# save_group_to_mat(mapped_latest_pre, 'latest_pre_lesion_songs', animal_id, save_directory)

# # Save the earlier pre-lesion group
# save_group_to_mat(mapped_earlier_pre, 'earlier_pre_lesion_songs', animal_id, save_directory)

# %%
import pandas as pd
import scipy.io as sio
import os

# Function to save syllable orders as cell arrays
def save_group_to_mat(mapped_syllable_orders, group_name, animal_id, save_dir):
    # Ensure the save directory exists
    os.makedirs(save_dir, exist_ok=True)
    
    # Wrap each mapped syllable order in a list (for MATLAB cell array compatibility)
    mapped_syllable_orders_cell = [[order] for order in mapped_syllable_orders]
    
    # Prepare the data as a dictionary for saving to .mat format
    data_dict = {f'mapped_syllable_order_{group_name}': mapped_syllable_orders_cell}
    
    # Generate a file name based on the animal ID and group name
    file_name = f"{animal_id}_{group_name}.mat"
    file_path = os.path.join(save_dir, file_name)
    
    # Save the .mat file
    sio.savemat(file_path, data_dict)
    
    # Print confirmation
    print(f"Saved {file_name} to {file_path}")

# Function to process and save pre- and post-surgery syllable orders
def filter_surgery_songs(organized_data_frame, surgery_date, group_size, save_dir):
    # Filter the DataFrame for songs recorded after the lesion date (post-lesion)
    post_lesion_songs = organized_data_frame[organized_data_frame['Date'] > surgery_date]
    
    # Select the first 'group_size' number of rows from the post-lesion songs
    filtered_post_surgery_songs = post_lesion_songs.head(group_size)
    
    # Filter the DataFrame for songs recorded on or before the lesion date (pre-lesion)
    pre_lesion_songs = organized_data_frame[organized_data_frame['Date'] <= surgery_date]
    
    total_pre_lesion_songs = len(pre_lesion_songs)
    print(f"Total number of pre-lesion songs: {total_pre_lesion_songs}")
    
    if total_pre_lesion_songs < group_size * 2:
        raise ValueError(f"Not enough pre-lesion songs to split into two groups of size {group_size}. Total available: {total_pre_lesion_songs}")

    # Select the last 'group_size' number of rows for the latest pre-surgery songs
    latest_pre_surgery_songs = pre_lesion_songs.tail(group_size)
    
    # Select the 'group_size' rows just before the latest pre-surgery songs
    earlier_pre_surgery_songs = pre_lesion_songs.iloc[-(group_size * 2):-group_size]
    
    print(f"Number of latest pre-surgery songs: {len(latest_pre_surgery_songs)}")
    print(f"Number of earlier pre-surgery songs: {len(earlier_pre_surgery_songs)}")
    
    # Create lists to hold the mapped syllable orders for each group
    mapped_syllable_orders_post = list(filtered_post_surgery_songs['mapped_syllable_order'])
    mapped_syllable_orders_latest_pre = list(latest_pre_surgery_songs['mapped_syllable_order'])
    mapped_syllable_orders_earlier_pre = list(earlier_pre_surgery_songs['mapped_syllable_order'])

    # Get the animal ID (assuming it's consistent across the dataset)
    animal_id = organized_data_frame['Animal ID'].iloc[0]
    
    # Save each group of syllable orders into a separate .mat file
    save_group_to_mat(mapped_syllable_orders_post, 'post_lesion_songs', animal_id, save_dir)
    save_group_to_mat(mapped_syllable_orders_latest_pre, 'latest_pre_lesion_songs', animal_id, save_dir)
    save_group_to_mat(mapped_syllable_orders_earlier_pre, 'earlier_pre_lesion_songs', animal_id, save_dir)

save_directory = "/Users/mirandahulsey-vincent/Desktop/DECODER_cell_arrays"
# Assuming organized_data_frame_with_orders contains the data
filter_surgery_songs(organized_data_frame_with_orders, surgery_date, group_size, save_directory)
# Out:
# Total number of pre-lesion songs: 3138
# Number of latest pre-surgery songs: 1374
# Number of earlier pre-surgery songs: 1374
# Saved USA5508_post_lesion_songs.mat to /Users/mirandahulsey-vincent/Desktop/DECODER_cell_arrays/USA5508_post_lesion_songs.mat
# Saved USA5508_latest_pre_lesion_songs.mat to /Users/mirandahulsey-vincent/Desktop/DECODER_cell_arrays/USA5508_latest_pre_lesion_songs.mat
# Saved USA5508_earlier_pre_lesion_songs.mat to /Users/mirandahulsey-vincent/Desktop/DECODER_cell_arrays/USA5508_earlier_pre_lesion_songs.mat
